# %% [markdown]
# <a href="https://colab.research.google.com/github/Thitichaya2000/data_viz_2022/blob/main/%E0%B8%97%E0%B8%94%E0%B8%AA%E0%B8%AD%E0%B8%9A%E0%B8%97%E0%B8%B3%20Final_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # โจทย์

# %% [markdown]
# Final Exam: งานกลุ่ม Final ที่อาจารย์สุ่มให้
#
#
# ให้นักศึกษาสร้าง Dashboard แสดงรายงานเกี่ยวกับข้อมูลการตรวจโรค(ov) จาก ไฟล์ alldb.csv และ hospital_list.xlsx
#
#
# ( ดาวน์โหลดจาก https://drive.google.com/drive/folders/1D_Z0fjTki6U6ECbgh2V3wBOSdOXS81YT?fbclid=IwAR3KK7jaRTK1DI3hfBq--qsME4ScgtNdrEbo2yvE2rn08tOTfmXED5kAEB8)
#
#
# โดยข้อมูลหลักจะอยู่ใน ตาราง alldb.csv (ข้อมูลที่สมบูรณ์ที่สามารถนำมาใช้งานได้ต้องมีค่าใน column ต่อไปนี้ดังนี้
#
#
# * user เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)
# * RowKey เป็น String
# * date เป็น YYYY-MM-DD
# * phone เป็น String
# * site เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)
# * time เป็น hh-mm-ss
# * urine มีค่า String
# * ov เป็นตัวเลข มีค่าตั้งแต่ 0-4 (0 คือไม่พบโรค 1-4 คือพบโรคที่ระดับความรุนแรงต่างๆ)
# * PartitionKey เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น))
#
#
# ไฟล์ alldb.csv และ hospital_list.xlsx สามารถถูกเชื่อมโยงกันโดย site ในไฟล์ alldb.csv คือ hcode ในไฟล์ hospital_list.xlsx
#
#
# โดยข้อมูลสำคัญที่ต้องแสดงคือ
#
#
# * จำนวนการตรวจในแต่ละพื้นที่ (จังหวัด-อำเภอ ในไฟล์ hospital_list.xlsx) เทียบกับ จำนวนที่พบโรค (column ov ในไฟล์ alldb.csv)
# * ช่วงเวลาที่ตรวจ (date ในไฟล์ alldb.csv)
# * อื่นๆที่นักศึกษาเห็นว่าเป็นประโยชน์ (phone (ชนิดโทรศัพท์ที่ใช้บันทึก), title (คำนำหน้าชื่อ), age (อายุ))
#
#
# (คิดคะแนนตามกลุ่ม final โดยไฟล์ที่ทุกคนในกลุ่มต้องมีคือไฟล์ data pre-processing และ link ไปที่ Dashboard ที่สร้่างโดยเปิดให้สามารถเข้าไปดูและใช้งานได้)
#
#
# ส่งไม่เกิน 23.59 วันจันทร์ที่ 11 เมษายน 2565

# %% [markdown]
# # รายชื่อสมาชิกภายในกลุ่ม triturate

# %% [markdown]
# 1. นางสาววัชราภรณ์ บุญจวง 613020615-8
#
# 2. นางสาวฐิติชญา ไกรวงค์ 623020520-0
#
# 3. นางสาวสุพิชญา ตั้งกิจวานิชย์ 623020542-0
#
# 4. นายดิษพงษ์ นาทองห่อ 623020999-5

# %% [markdown]
# # การเชื่อมไดร์ฟเพื่อดึงข้อมูลจากไดรฟ์

# %%
import pandas as pd #เพื่อใช้ทำงานกับข้อมูลที่เป็นรูปแบบตาราง
import os           #เพื่อจัดการกับไฟล์ และ ตัว path ที่เราจะนำเข้า

# %%
from google.colab import drive#เชื่อมข้อมูล เพราะเราจะทำการนำเข้าข้อมูล โดยให้ดึงมาจาก google drive ของเรา
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/ovrdt_data'
#โดยเราจะทำการระบุให้ชี้ไปที่ โฟลเดอร์ที่เราเซฟไฟล์ไว้ หรือก็คือ โฟลเดอร์ Project

# %%
# เชื่อม library
from datetime import datetime as dt # ใช้สำหรับเกี่ยวกับวัน
from datetime import time # ใช้สำหรับเกี่ยวกับวัน
import matplotlib.pyplot as plt # ใช้สำหรับเกี่ยวกับการวาดกราฟ
import numpy as np # ใช้สำหรับเกี่ยวกับตัวเลข
import datetime as dt # ใช้สำหรับเกี่ยวกับวัน

# %% [markdown]
# ## ข้อมูลหลัก ตาราง alldb

# %%
alldb = os.path.join(path,'alldb.xlsx')
alldb = pd.read_excel(alldb)
alldb
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-136-035c55fa0734> in <module>()
#       1 alldb = os.path.join(path,'alldb.xlsx')
# ----> 2 alldb = pd.read_excel(alldb)
#       3 alldb
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1194                 if ext is None:
#    1195                     raise ValueError(
# -> 1196                         "Excel file format cannot be determined, you must specify "
#    1197                         "an engine manually."
#    1198                     )
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.

# %% [markdown]
# ## ข้อมูลรอง ตาราง hospital_list.xlsx

# %%
hospital_list = os.path.join(path,'hospital_list.xlsx')
hospital_list = pd.read_excel(hospital_list)
hospital_list
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5  code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อท           ATG
# ...                         ...    ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
#
# [17103 rows x 16 columns]

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# ## จัดการข้อมูลหลัก ตาราง alldb.csv

# %% [markdown]
# ### เลือกข้อมูลจากตารางหลัก แค่คอลัมน์ที่ต้องการใช้งาน

# %%
alldb_new = alldb[['user','RowKey','date','phone','site','time','urine','ov','PartitionKey']] 
alldb_new
# Out:
#                 user                                    RowKey        date  \
# 0               test                                       NaN         NaN
# 1              04857      136FD222-FD9F-4E54-AE1F-7282A276B085  2022-02-24
# 2                NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png         NaN
# 3      3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE  2022-02-23
# 4      3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21  2022-02-23
# ...              ...                                       ...         ...
# 40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C         NaN
# 40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1         NaN
# 40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9         NaN
# 40033            NaN                            bbuogxulur.png         NaN
# 40034            NaN                            zttpqogiso.png         NaN
#
#                   phone   site      time            urine   ov  \
# 0                   NaN    NaN       NaN              NaN  NaN
# 1            iPhone10,4  05310  10:50:32              NaN  NaN
# 2                   NaN    NaN       NaN              NaN  NaN
# 3            iPhone13,4  05087  09:59:47  ปกติ (เหลืองใส)    0
# 4            iPhone13,4  05087  09:44:06  ปกติ (เหลืองใส)  NaN
# ...                 ...    ...       ...              ...  ...
# 40030        iPhone13,4  01234       NaN              NaN  NaN
# 40031        iPhone10,5  01234       NaN  ปกติ (เหลืองใส)    2
# 40032        iPhone13,4  01234       NaN  ปกติ (เหลืองใส)    1
# 40033  Samsung SM-A115F  01234       NaN              NaN  NaN
# 40034  Samsung SM-A115F  01234       NaN  ปกติ (เหลืองใส)    1
#
#                  PartitionKey
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 40030     เกษศิรินทร์  ไชยลาภ
# 40031  เถลิงเกียรติ เสริฐเลิศ
# 40032                    เสรี
# 40033                    เสรี
# 40034                    เสรี
#
# [40035 rows x 9 columns]

# %% [markdown]
# ### ตรวจสอบค่า Missing

# %%
alldb_new.isnull().any() 
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# user            True
# RowKey          True
# date            True
# phone           True
# site            True
# time            True
# urine           True
# ov              True
# PartitionKey    True
# dtype: bool

# %% [markdown]
# ### ใช้ .dropna ซึ่งจะใช้ตัดแถวข้อมูลที่มีค่า missing

# %%
alldb_drop = alldb_new.dropna() #ใช้ dropna เพื่อต้องการลบข้อมูลทั้งแถวออกเมื่อมีคอลัมน์ใดคอลัมน์หนึ่งเป็น NaN
alldb_drop
# Out:
#          user                                RowKey        date  \
# 185     85879                        shmpdrmtgc.png  2022-03-24
# 186    45-161  D2CABB8C-533B-450A-AFA6-B693749CC1C6  2022-02-23
# 187    45-161  57A5F06C-C840-49EA-9514-A30D3C897CC8  2022-02-23
# 188     27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 190     06223                        kfpwuaqldj.png  2022-03-23
# ...       ...                                   ...         ...
# 40013   ttest                        crqcufokmn.png  2022-02-21
# 40014   ttest                        gzxgflnowr.png  2022-02-21
# 40016     xxx                        jytlopevha.png  2022-02-17
# 40022     yyy                        ivccsksowb.png  2022-02-17
# 40023     zzz                        psudrnccsh.png  2022-02-17
#
#                    phone   site      time            urine ov PartitionKey
# 185         OPPO CPH2293  05194  13:08:39          มีตะกอน  0         0000
# 186           iPhone11,8  04312  09:45:28  ปกติ (เหลืองใส)  0       0-1528
# 187           iPhone11,8  04312  10:06:45  ปกติ (เหลืองใส)  0       0-1544
# 188           iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0         0000
# 190    Xiaomi 21081111RG  13777  16:31:45  ปกติ (เหลืองใส)  0        00000
# ...                  ...    ...       ...              ... ..          ...
# 40013   Samsung SM-G998B   test  14:23:45             ขุ่น  2         x001
# 40014   Samsung SM-G998B   test  14:23:43             ขุ่น  2         x001
# 40016   Samsung SM-N950F    xxx  00:01:06  ปกติ (เหลืองใส)  3          xxx
# 40022   Samsung SM-N950F    yyy  08:41:05   มีเม็ดเลือดแดง  2          yyy
# 40023   Samsung SM-N950F    zzz  08:41:04          มีตะกอน  2          zzz
#
# [38663 rows x 9 columns]

# %%
alldb_drop.shape #ตรวจสอบขนาดของตารางใหม่
# Out:
# (38663, 9)

# %%
removes = alldb_new.shape[0] - alldb_drop.shape[0]
print(f'size before drop = {alldb_new.shape[0]}')
print(f'size after drop = {alldb_drop.shape[0]}')
print(f'% from drop = {(removes/alldb_new.shape[0])*100}')
 # จากการคำนวณพบว่ามีข้อมูลที่หายไปเพียงแค่ 3% ดังนั้น จึงสามารถใช้การ .dropna() ได ้
# Out:
# size before drop = 40035
# size after drop = 38663
# % from drop = 3.427001373797927

# %%
alldb_drop.isnull().any() 
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# user            False
# RowKey          False
# date            False
# phone           False
# site            False
# time            False
# urine           False
# ov              False
# PartitionKey    False
# dtype: bool

# %% [markdown]
# ### ทำการเปลี่ยน type ของข้อมูลให้เป็น type ที่ถูกต้อง

# %%
alldb_drop.dtypes # เช็คว่าข้อมูลมี่ความตรงกับที่ต้องการหรือไม่
# Out:
# user            object
# RowKey          object
# date            object
# phone           object
# site            object
# time            object
# urine           object
# ov              object
# PartitionKey    object
# dtype: object

# %% [markdown]
# พบว่ามีข้อมูลที่ไม่ตรงกับสิ่งที่ต้องการ
#
#  * user ปัจจุบันยังเป็นข้อมูล type string ควรเปลี่ยนเป็น int
#  * site ปัจจุบันยังเป็นข้อมูล type string ควรเปลี่ยนเป็น int
#  * ov ปัจจุบันยังเป็นข้อมูล type string ควรเปลี่ยนเป็น int
#  * PartitionKey ปัจจุบันยังเป็นข้อมูล type string ควรเปลี่ยนเป็น int

# %% [markdown]
# #### คอลัมน์ user

# %%
set(alldb_drop['user']) # เพื่อดูข้อมูลทั้งหมดใน column user
# Out:
# {
#  '47656',
#  '46566',
#  '36593',
#  '99734',
#  '39638',
#  '22099',
#  '11361',
#  '74103',
#  '79817',
#  '00324',
#  '03562',
#  '39079',
#  '63852',
#  '46333',
#  '00031',
#  '52520',
#  '02091',
#  '97965',
#  '51060',
#  '47938',
#  '29379',
#  '00203',
#  '16144',
#  '00271',
#  '83900',
#  '37607',
#  '46948',
#  '39537',
#  '03080',
#  '19265',
#  '00206',
#  '00207',
#  '65254',
#  '86474',
#  '22692',
#  '00053',
#  '76011',
#  '00143',
#  '19808',
#  '21955',
#  '65555',
#  '00139',
#  '89394',
#  '00171',
#  '92893',
#  'yyy',
#  '98260',
#  '87802',
#  '21831',
#  '45736',
#  '68317',
#  '00065',
#  '16085',
#  '00191',
#  '00235',
#  '00180',
#  '12561',
#  '69556',
#  '13312',
#  '19920',
#  '38522',
#  '55300',
#  '00781',
#  '03381',
#  '73381',
#  '19273',
#  '48646',
#  '01183',
#  '74369',
#  '67241',
#  '50911',
#  '12003',
#  '02663',
#  'qqq',
#  '25829',
#  '45641',
#  '00132',
#  '94295',
#  '59128',
#  '68006',
#  '12413',
#  '17916',
#  '32666',
#  '58845',
#  '62459',
#  '08242',
#  '00352',
#  '78257',
#  '31011',
#  '73876',
#  '79066',
#  '51403',
#  '19699',
#  '81293',
#  '88135',
#  '98519',
#  '88023',
#  '76386',
#  '67961',
#  '00153',
#  '09582',
#  '45914',
#  '57954',
#  '3450100940367',
#  '17564',
#  '31114',
#  '00285',
#  '27529',
#  '05047',
#  '25804',
#  '65632',
#  '92691',
#  '60909',
#  '66708',
#  '00130',
#  '11808',
#  ...}

# %% [markdown]
# เเก้ไขให้มีข้อมูลที่ถูกต้อง
#
# โดยกำหนดให้ข้อมูลที่ไม่ใช่เลข 5 หลัก เท่ากับ ข้อมูลว่าง

# %%
alldb_drop['user'].replace({'3450101325119':None,
'34501009308':None,
'71378\n71378':'71378',
'yyy':None,
'7197':None,
'rrr':None,
'745-61':'74561',
'uuu':None,
'3450100810285':None,
'jjj':None,
'11111111':None,
'3450100805222':None,
'zzz':None,
'3450101556129':None,
'3450101325593':None,
'4':None,
'6724100235':None,
'17536\n\n17536':'17536',
'3450101229373':None,
'Testtohn':None,
'  noknoi2601@gmail.com\n':None,
'3451100324624':None,
'40591\n40591\n':'40591',
'6724-':None,
'test':None,
'3450101536268':None,
'3450100543961':None,
'ppp':None,
'xxx':None,
'3451100451758':None,
'hhh':None,
'ttohn':None,
'fff':None,
'ggg':None,
'ccc':None,
'5600190011969':None,
'testtohn':None,
'3451400598487':None,
'3':None,
'3400900747146':None,
'5450100026807':None,
'iii':None,
'5799':None,
'aaa':None,
'3451100141252':None,
't006':None,
'5450500072920':None,
'bbb':None,
'hu':None,
'3450101323370':None,
'ttest':None,
'test1':None,
'tttt':None,
'eee':None,
'qqq':None,
'ttt':None,
'45-161':None,
'sss':None,
'tt':None,
'u789':None,
'3451100241281':None,
'3451100324713':None,
'3450101514299':None,
'3451100451251':None,
'1450700099250':None,
'3450100836420':None,
'3450500541443':None,
'www':None,
'5451100055352':None,
'3451100146637':None,
'3450100940367':None,
'mmm':None,
'3460500500020':None,
'vvv':None,
'lll':None,
'3450101325097':None,
'aiov0001':None,
'kkk':None,
'mks':None,
'aiov0002':None,
'3459900286317':None,
'3451100150251':None,
'3450101576642':None,
'  67241\n':'67241'
},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
set(alldb_drop['user']) # เพื่อดูข้อมูลทั้งหมดใน column user
# Out:
# {
#  '76011',
#  '00143',
#  '19808',
#  '21955',
#  '65555',
#  '00139',
#  '89394',
#  '00171',
#  '92893',
#  '98260',
#  '87802',
#  '21831',
#  '45736',
#  '68317',
#  '00065',
#  '16085',
#  '00191',
#  '00235',
#  '00180',
#  '12561',
#  '69556',
#  '13312',
#  '19920',
#  '38522',
#  '55300',
#  '00781',
#  '03381',
#  '73381',
#  '19273',
#  '48646',
#  '01183',
#  '74369',
#  '67241',
#  '50911',
#  '12003',
#  '02663',
#  '25829',
#  '45641',
#  '00132',
#  '94295',
#  '59128',
#  '68006',
#  '12413',
#  '17916',
#  '32666',
#  '58845',
#  '62459',
#  '08242',
#  '00352',
#  '78257',
#  '31011',
#  '73876',
#  '79066',
#  '51403',
#  '19699',
#  '81293',
#  '88135',
#  '98519',
#  '88023',
#  '76386',
#  '67961',
#  '00153',
#  '09582',
#  '45914',
#  '57954',
#  '17564',
#  '31114',
#  '00285',
#  '27529',
#  '05047',
#  '25804',
#  '65632',
#  '92691',
#  '60909',
#  '66708',
#  '00130',
#  '11808',
#  '97860',
#  '16214',
#  '22119',
#  '00030',
#  '94406',
#  '00020',
#  '76819',
#  '96699',
#  '59326',
#  '20454',
#  '39539',
#  '87029',
#  '01088',
#  '05154',
#  '04193',
#  '00026',
#  '08998',
#  '44199',
#  '47354',
#  '44364',
#  '41937',
#  '47844',
#  '25331',
#  '85379',
#  '43791',
#  '93189',
#  '25923',
#  '34829',
#  '98530',
#  '01883',
#  '68081',
#  '72364',
#  '40059',
#  '05353',
#  '00313',
#  '26779',
#  '28627',
#  '14884',
#  '30041',
#  '00210',
#  '11007',
#  '96081',
#  '09072',
#  '22354',
#  '18318',
#  '03617',
#  '01637',
#  '00115',
#  '04854',
#  '23416',
#  ...}

# %%
alldb_drop2 = alldb_drop.dropna() # ทำการ drop ค่าว่างออก 
alldb_drop2 # แสดงผลลัพธ์
# Out:
#         user                                RowKey        date  \
# 185    85879                        shmpdrmtgc.png  2022-03-24
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 190    06223                        kfpwuaqldj.png  2022-03-23
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30
# ...      ...                                   ...         ...
# 39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  2022-03-11
# 39813  99999                        lnlohgqckf.png  2022-03-10
# 39814  99999                        vkdocpmjiv.png  2022-03-10
# 39815  99999                        vrvyfnvayq.png  2022-03-10
# 39816  99999                        zuhbtvyrce.png  2022-03-10
#
#                    phone   site      time                 urine ov  \
# 185         OPPO CPH2293  05194  13:08:39               มีตะกอน  0
# 188           iPhone13,1  04999  14:22:22       ปกติ (เหลืองใส)  0
# 190    Xiaomi 21081111RG  13777  16:31:45       ปกติ (เหลืองใส)  0
# 191           iPhone12,3  06307  14:46:08       ปกติ (เหลืองใส)  4
# 192           iPhone14,3  05328  15:27:45       ปกติ (เหลืองใส)  4
# ...                  ...    ...       ...                   ... ..
# 39812         iPhone14,2  99999  11:36:34                  ขุ่น  1
# 39813   Samsung SM-G998B  99999  18:10:29               มีตะกอน  0
# 39814   Samsung SM-G998B  99999  12:14:41  ขุ่น, มีเม็ดเลือดแดง  1
# 39815   Samsung SM-G998B  99999  13:58:01       ปกติ (เหลืองใส)  1
# 39816   Samsung SM-G998B  99999  13:57:58       ปกติ (เหลืองใส)  1
#
#       PartitionKey
# 185           0000
# 188           0000
# 190          00000
# 191          00001
# 192          00001
# ...            ...
# 39812        99999
# 39813        99999
# 39814        99999
# 39815        99999
# 39816        99999
#
# [37992 rows x 9 columns]

# %%
alldb_drop2['user'] = alldb_drop2['user'].astype(int) # เปลี่ยนข้อมูลจาก string เป็น int ในคอลัมน์ user
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
alldb_drop2.dtypes # เช็คว่า user ทั้งหมดเป็น int หรือไม่
# Out:
# user             int64
# RowKey          object
# date            object
# phone           object
# site            object
# time            object
# urine           object
# ov              object
# PartitionKey    object
# dtype: object

# %% [markdown]
# #### คอลัมน์ site

# %%
set(alldb_drop2['site']) # เพื่อดูข้อมูลทั้งหมดใน column site
# Out:
# {' 0502',
#  '00004',
#  '00006',
#  '00007',
#  '00008',
#  '00012',
#  '00016',
#  '00017',
#  '00018',
#  '00027',
#  '00028',
#  '00040',
#  '00052',
#  '00055',
#  '00061',
#  '00069',
#  '00070',
#  '00071',
#  '00081',
#  '00082',
#  '00090',
#  '00094',
#  '00096',
#  '00108',
#  '00109',
#  '00115',
#  '00120',
#  '00122',
#  '00127',
#  '00163',
#  '00164',
#  '00165',
#  '00166',
#  '00169',
#  '00170',
#  '00171',
#  '00173',
#  '00174',
#  '00176',
#  '00177',
#  '00178',
#  '00179',
#  '00180',
#  '00182',
#  '00185',
#  '00186',
#  '00187',
#  '00189',
#  '00190',
#  '00191',
#  '00192',
#  '00193',
#  '00194',
#  '00195',
#  '00196',
#  '00197',
#  '00198',
#  '00200',
#  '00202',
#  '00204',
#  '00205',
#  '00206',
#  '00207',
#  '00209',
#  '00213',
#  '00214',
#  '00217',
#  '00218',
#  '00219',
#  '00229',
#  '00232',
#  '00235',
#  '00240',
#  '00247',
#  '00266',
#  '00271',
#  '00279',
#  '00323',
#  '00331',
#  '00333',
#  '00346',
#  '00348',
#  '00381',
#  '00382',
#  '00385',
#  '00387',
#  '00388',
#  '00389',
#  '00390',
#  '00391',
#  '00394',
#  '00397',
#  '00400',
#  '00401',
#  '00404',
#  '00406',
#  '00408',
#  '00410',
#  '00411',
#  '00412',
#  '00413',
#  '00414',
#  '00415',
#  '00512',
#  '00513',
#  '00579',
#  '00580',
#  '00956',
#  '01151',
#  '02038',
#  '02414',
#  '02536',
#  '02759',
#  '03432',
#  '03616',
#  '03626',
#  '04275',
#  '04279',
#  '04280',
#  '04281',
#  '043.1',
#  '04302',
#  '04312',
#  '04313',
#  '04321',
#  '04322',
#  '04326',
#  '04337',
#  '04347',
#  '04348',
#  '04349',
#  '04351',
#  '04352',
#  '04355',
#  '04374',
#  '04376',
#  '04380',
#  '04384',
#  '04387',
#  '04388',
#  '04390',
#  '04391',
#  '04396',
#  '04399',
#  '04401',
#  '04402',
#  '04403',
#  '04404',
#  '04405',
#  '04406',
#  '04407',
#  '04408',
#  '04433',
#  '04434',
#  '04435',
#  '04436',
#  '04437',
#  '04438',
#  '04441',
#  '04443',
#  '04455',
#  '04456',
#  '04457',
#  '04458',
#  '04475',
#  '04478',
#  '04558',
#  '04936',
#  '04968',
#  '04970',
#  '04971',
#  '04973',
#  '04974',
#  '04977',
#  '04980',
#  '04981',
#  '04982',
#  '04983',
#  '04984',
#  '04985',
#  '04986',
#  '04989',
#  '04990',
#  '04992',
#  '04993',
#  '04994',
#  '04995',
#  '04996',
#  '04997',
#  '04999',
#  '05000',
#  '05001',
#  '05002',
#  '05003',
#  '05004',
#  '05005',
#  '05006',
#  '05007',
#  '05008',
#  '05009',
#  '05010',
#  '05011',
#  '05012',
#  '05013',
#  '05015',
#  '05016',
#  '05019',
#  '05021',
#  '05022',
#  '05023',
#  '05024',
#  '05025',
#  '05026',
#  '05027',
#  '05028',
#  '05029',
#  '05032',
#  '05033',
#  '05034',
#  '05035',
#  '05038',
#  '05040',
#  '05042',
#  '05044',
#  '05045',
#  '05047',
#  '05048',
#  '05049',
#  '05052',
#  '05054',
#  '05055',
#  '05058',
#  '05059',
#  '05060',
#  '05061',
#  '05062',
#  '05063',
#  '05064',
#  '05065',
#  '05066',
#  '05067',
#  '05068',
#  '05069',
#  '05072',
#  '05074',
#  '05075',
#  '05077',
#  '05080',
#  '05081',
#  '05082',
#  '05083',
#  '05084',
#  '05086',
#  '05087',
#  '05088',
#  '05090',
#  '05091',
#  '05094',
#  '05097',
#  '05098',
#  '05100',
#  '05101',
#  '05102',
#  '05103',
#  '05107',
#  '05111',
#  '05112',
#  '05113',
#  '05115',
#  '05116',
#  '05117',
#  '05119',
#  '05120',
#  '05123',
#  '05125',
#  '05126',
#  '05128',
#  '05129',
#  '05131',
#  '05132',
#  '05133',
#  '05135',
#  '05136',
#  '05141',
#  '05143',
#  '05144',
#  '05146',
#  '05147',
#  '05152',
#  '05154',
#  '05157',
#  '05158',
#  '05162',
#  '05166',
#  '05172',
#  '05173',
#  '05175',
#  '05177',
#  '05178',
#  '05180',
#  '05181',
#  '05182',
#  '05185',
#  '05187',
#  '05188',
#  '05192',
#  '05193',
#  '05194',
#  '05195',
#  '05196',
#  '05198',
#  '05200',
#  '05203',
#  '05205',
#  '05207',
#  '05210',
#  '05211',
#  '05213',
#  '05214',
#  '05215',
#  '05219',
#  '05220',
#  '05222',
#  '05223',
#  '05224',
#  '05225',
#  '05226',
#  '05228',
#  '05229',
#  '05233',
#  '05236',
#  '05237',
#  '05238',
#  '05240',
#  '05241',
#  '05242',
#  '05244',
#  '05245',
#  '05246',
#  '05247',
#  '05248',
#  '05249',
#  '05250',
#  '05250\n',
#  '05251',
#  '05252',
#  '05253',
#  '05254',
#  '05256',
#  '05257',
#  '05258',
#  '05259',
#  '05260',
#  '05261',
#  '05264',
#  '05265',
#  '05291',
#  '05298',
#  '05300',
#  '05304',
#  '05310',
#  '05311',
#  '05312',
#  '05313',
#  '05314',
#  '05315',
#  '05316',
#  '05322',
#  '05323',
#  '05324',
#  '05325',
#  '05327',
#  '05328',
#  '05332',
#  '05335',
#  '05337',
#  '05338',
#  '05339',
#  '05340',
#  '05343',
#  '05344',
#  '05345',
#  '05346',
#  '05349',
#  '05350',
#  '05350ยอ',
#  '05351',
#  '05352',
#  '05354',
#  '05355',
#  '05356',
#  '05357',
#  '05358',
#  '05359',
#  '05360',
#  '05361',
#  '05363',
#  '05365',
#  '05366',
#  '05367',
#  '05368',
#  '05370',
#  '05371',
#  '05373',
#  '05378',
#  '05386',
#  '05391',
#  '05392',
#  '05393',
#  '05394',
#  '05395',
#  '05396',
#  '05399',
#  '05413',
#  '05414',
#  '05415',
#  '05416',
#  '05418',
#  '05419',
#  '05422',
#  '05423',
#  '05424',
#  '05425',
#  '05428',
#  '05431',
#  '05432',
#  '05433',
#  '05434',
#  '05435',
#  '05436',
#  '05437',
#  '05439',
#  '05440',
#  '05441',
#  '05442',
#  '05541',
#  '06238',
#  '06251',
#  '06253',
#  '06254',
#  '06255',
#  '06256',
#  '06257',
#  '06259',
#  '06260',
#  '06261',
#  '06263',
#  '06265',
#  '06267',
#  '06268',
#  '06270',
#  '06271',
#  '06272',
#  '06273',
#  '06274',
#  '06275',
#  '06276',
#  '06277',
#  '06278',
#  '06279',
#  '06280',
#  '06281',
#  '06282',
#  '06283',
#  '06285',
#  '06286',
#  '06287',
#  '06288',
#  '06289',
#  '06290',
#  '06291',
#  '06292',
#  '06293',
#  '06294',
#  '06295',
#  '06296',
#  '06297',
#  '06298',
#  '06299',
#  '06300',
#  '06301',
#  '06302',
#  '06307',
#  '06308',
#  '06309',
#  '06310',
#  '06311',
#  '06312',
#  '06314',
#  '06315',
#  '06316',
#  '06318',
#  '06319',
#  '06320',
#  '06321',
#  '06322',
#  '06323',
#  '06324',
#  '06325',
#  '06326',
#  '06327',
#  '06328',
#  '06329',
#  '06330',
#  '06331',
#  '06332',
#  '06333',
#  '06334',
#  '06521',
#  '08485',
#  '10360',
#  '10673',
#  '11010',
#  '11055',
#  '11056',
#  '11057',
#  '11059',
#  '11060',
#  '11066',
#  '11069',
#  '11070',
#  '11072',
#  '11073',
#  '11084',
#  '11088',
#  '11111',
#  '11158',
#  '11159',
#  '11160',
#  '11161',
#  '11163',
#  '11164',
#  '11165',
#  '11740',
#  '11748',
#  '11749',
#  '11800',
#  '11887',
#  '13777',
#  '13937',
#  '13941',
#  '13943',
#  '13943\n\n',
#  '13944',
#  '13946',
#  '13947',
#  '13948',
#  '13949',
#  '13952',
#  '13953',
#  '13954',
#  '13955',
#  '13962',
#  '13963',
#  '13966',
#  '13984',
#  '13987',
#  '14005',
#  '14007',
#  '14280',
#  '14284',
#  '14843',
#  '20510',
#  '22222',
#  '24622',
#  '24650',
#  '27988',
#  '27990',
#  '27998',
#  '28017',
#  '28691',
#  '28789',
#  '44902',
#  '45972',
#  '49741',
#  '50210',
#  '75757',
#  '97255',
#  '99795',
#  '99999'}

# %% [markdown]
# เเก้ไขให้มีข้อมูลที่ถูกต้อง
#
# โดยกำหนดให้ข้อมูลที่ไม่ใช่เลข 5 หลัก เท่ากับ ข้อมูลว่าง

# %%
alldb_drop2['site'].replace({' 0502':None,
'05250\n':'05250',
'05350ยอ':'05350',
'13943\n\n':'13943',
'043.1':None
},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
alldb_drop3 = alldb_drop2.dropna() # ทำการ drop ค่าว่างออก 
alldb_drop3 # แสดงผลลัพธ์
# Out:
#         user                                RowKey        date  \
# 185    85879                        shmpdrmtgc.png  2022-03-24
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 190     6223                        kfpwuaqldj.png  2022-03-23
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30
# ...      ...                                   ...         ...
# 39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  2022-03-11
# 39813  99999                        lnlohgqckf.png  2022-03-10
# 39814  99999                        vkdocpmjiv.png  2022-03-10
# 39815  99999                        vrvyfnvayq.png  2022-03-10
# 39816  99999                        zuhbtvyrce.png  2022-03-10
#
#                    phone   site      time                 urine ov  \
# 185         OPPO CPH2293  05194  13:08:39               มีตะกอน  0
# 188           iPhone13,1  04999  14:22:22       ปกติ (เหลืองใส)  0
# 190    Xiaomi 21081111RG  13777  16:31:45       ปกติ (เหลืองใส)  0
# 191           iPhone12,3  06307  14:46:08       ปกติ (เหลืองใส)  4
# 192           iPhone14,3  05328  15:27:45       ปกติ (เหลืองใส)  4
# ...                  ...    ...       ...                   ... ..
# 39812         iPhone14,2  99999  11:36:34                  ขุ่น  1
# 39813   Samsung SM-G998B  99999  18:10:29               มีตะกอน  0
# 39814   Samsung SM-G998B  99999  12:14:41  ขุ่น, มีเม็ดเลือดแดง  1
# 39815   Samsung SM-G998B  99999  13:58:01       ปกติ (เหลืองใส)  1
# 39816   Samsung SM-G998B  99999  13:57:58       ปกติ (เหลืองใส)  1
#
#       PartitionKey
# 185           0000
# 188           0000
# 190          00000
# 191          00001
# 192          00001
# ...            ...
# 39812        99999
# 39813        99999
# 39814        99999
# 39815        99999
# 39816        99999
#
# [37989 rows x 9 columns]

# %%
set(alldb_drop3['site']) # เพื่อดูข้อมูลทั้งหมดใน column site
# Out:
# {'00004',
#  '00006',
#  '00007',
#  '00008',
#  '00012',
#  '00016',
#  '00017',
#  '00018',
#  '00027',
#  '00028',
#  '00040',
#  '00052',
#  '00055',
#  '00061',
#  '00069',
#  '00070',
#  '00071',
#  '00081',
#  '00082',
#  '00090',
#  '00094',
#  '00096',
#  '00108',
#  '00109',
#  '00115',
#  '00120',
#  '00122',
#  '00127',
#  '00163',
#  '00164',
#  '00165',
#  '00166',
#  '00169',
#  '00170',
#  '00171',
#  '00173',
#  '00174',
#  '00176',
#  '00177',
#  '00178',
#  '00179',
#  '00180',
#  '00182',
#  '00185',
#  '00186',
#  '00187',
#  '00189',
#  '00190',
#  '00191',
#  '00192',
#  '00193',
#  '00194',
#  '00195',
#  '00196',
#  '00197',
#  '00198',
#  '00200',
#  '00202',
#  '00204',
#  '00205',
#  '00206',
#  '00207',
#  '00209',
#  '00213',
#  '00214',
#  '00217',
#  '00218',
#  '00219',
#  '00229',
#  '00232',
#  '00235',
#  '00240',
#  '00247',
#  '00266',
#  '00271',
#  '00279',
#  '00323',
#  '00331',
#  '00333',
#  '00346',
#  '00348',
#  '00381',
#  '00382',
#  '00385',
#  '00387',
#  '00388',
#  '00389',
#  '00390',
#  '00391',
#  '00394',
#  '00397',
#  '00400',
#  '00401',
#  '00404',
#  '00406',
#  '00408',
#  '00410',
#  '00411',
#  '00412',
#  '00413',
#  '00414',
#  '00415',
#  '00512',
#  '00513',
#  '00579',
#  '00580',
#  '00956',
#  '01151',
#  '02038',
#  '02414',
#  '02536',
#  '02759',
#  '03432',
#  '03616',
#  '03626',
#  '04275',
#  '04279',
#  '04280',
#  '04281',
#  '04302',
#  '04312',
#  '04313',
#  '04321',
#  '04322',
#  '04326',
#  '04337',
#  '04347',
#  '04348',
#  '04349',
#  '04351',
#  '04352',
#  '04355',
#  '04374',
#  '04376',
#  '04380',
#  '04384',
#  '04387',
#  '04388',
#  '04390',
#  '04391',
#  '04396',
#  '04399',
#  '04401',
#  '04402',
#  '04403',
#  '04404',
#  '04405',
#  '04406',
#  '04407',
#  '04408',
#  '04433',
#  '04434',
#  '04435',
#  '04436',
#  '04437',
#  '04438',
#  '04441',
#  '04443',
#  '04455',
#  '04456',
#  '04457',
#  '04458',
#  '04475',
#  '04478',
#  '04558',
#  '04936',
#  '04968',
#  '04970',
#  '04971',
#  '04973',
#  '04974',
#  '04977',
#  '04980',
#  '04981',
#  '04982',
#  '04983',
#  '04984',
#  '04985',
#  '04986',
#  '04989',
#  '04990',
#  '04992',
#  '04993',
#  '04994',
#  '04995',
#  '04996',
#  '04997',
#  '04999',
#  '05000',
#  '05001',
#  '05002',
#  '05003',
#  '05004',
#  '05005',
#  '05006',
#  '05007',
#  '05008',
#  '05009',
#  '05010',
#  '05011',
#  '05012',
#  '05013',
#  '05015',
#  '05016',
#  '05019',
#  '05021',
#  '05022',
#  '05023',
#  '05024',
#  '05025',
#  '05026',
#  '05027',
#  '05028',
#  '05029',
#  '05032',
#  '05033',
#  '05034',
#  '05035',
#  '05038',
#  '05040',
#  '05042',
#  '05044',
#  '05045',
#  '05047',
#  '05048',
#  '05049',
#  '05052',
#  '05054',
#  '05055',
#  '05058',
#  '05059',
#  '05060',
#  '05061',
#  '05062',
#  '05063',
#  '05064',
#  '05065',
#  '05066',
#  '05067',
#  '05068',
#  '05069',
#  '05072',
#  '05074',
#  '05075',
#  '05077',
#  '05080',
#  '05081',
#  '05082',
#  '05083',
#  '05084',
#  '05086',
#  '05087',
#  '05088',
#  '05090',
#  '05091',
#  '05094',
#  '05097',
#  '05098',
#  '05100',
#  '05101',
#  '05102',
#  '05103',
#  '05107',
#  '05111',
#  '05112',
#  '05113',
#  '05115',
#  '05116',
#  '05117',
#  '05119',
#  '05120',
#  '05123',
#  '05125',
#  '05126',
#  '05128',
#  '05129',
#  '05131',
#  '05132',
#  '05133',
#  '05135',
#  '05136',
#  '05141',
#  '05143',
#  '05144',
#  '05146',
#  '05147',
#  '05152',
#  '05154',
#  '05157',
#  '05158',
#  '05162',
#  '05166',
#  '05172',
#  '05173',
#  '05175',
#  '05177',
#  '05178',
#  '05180',
#  '05181',
#  '05182',
#  '05185',
#  '05187',
#  '05188',
#  '05192',
#  '05193',
#  '05194',
#  '05195',
#  '05196',
#  '05198',
#  '05200',
#  '05203',
#  '05205',
#  '05207',
#  '05210',
#  '05211',
#  '05213',
#  '05214',
#  '05215',
#  '05219',
#  '05220',
#  '05222',
#  '05223',
#  '05224',
#  '05225',
#  '05226',
#  '05228',
#  '05229',
#  '05233',
#  '05236',
#  '05237',
#  '05238',
#  '05240',
#  '05241',
#  '05242',
#  '05244',
#  '05245',
#  '05246',
#  '05247',
#  '05248',
#  '05249',
#  '05250',
#  '05251',
#  '05252',
#  '05253',
#  '05254',
#  '05256',
#  '05257',
#  '05258',
#  '05259',
#  '05260',
#  '05261',
#  '05264',
#  '05265',
#  '05291',
#  '05298',
#  '05300',
#  '05304',
#  '05310',
#  '05311',
#  '05312',
#  '05313',
#  '05314',
#  '05315',
#  '05316',
#  '05322',
#  '05323',
#  '05324',
#  '05325',
#  '05327',
#  '05328',
#  '05332',
#  '05335',
#  '05337',
#  '05338',
#  '05339',
#  '05340',
#  '05343',
#  '05344',
#  '05345',
#  '05346',
#  '05349',
#  '05350',
#  '05351',
#  '05352',
#  '05354',
#  '05355',
#  '05356',
#  '05357',
#  '05358',
#  '05359',
#  '05360',
#  '05361',
#  '05363',
#  '05365',
#  '05366',
#  '05367',
#  '05368',
#  '05370',
#  '05371',
#  '05373',
#  '05378',
#  '05386',
#  '05391',
#  '05392',
#  '05393',
#  '05394',
#  '05395',
#  '05396',
#  '05399',
#  '05413',
#  '05414',
#  '05415',
#  '05416',
#  '05418',
#  '05419',
#  '05422',
#  '05423',
#  '05424',
#  '05425',
#  '05428',
#  '05431',
#  '05432',
#  '05433',
#  '05434',
#  '05435',
#  '05436',
#  '05437',
#  '05439',
#  '05440',
#  '05441',
#  '05442',
#  '05541',
#  '06238',
#  '06251',
#  '06253',
#  '06254',
#  '06255',
#  '06256',
#  '06257',
#  '06259',
#  '06260',
#  '06261',
#  '06263',
#  '06265',
#  '06267',
#  '06268',
#  '06270',
#  '06271',
#  '06272',
#  '06273',
#  '06274',
#  '06275',
#  '06276',
#  '06277',
#  '06278',
#  '06279',
#  '06280',
#  '06281',
#  '06282',
#  '06283',
#  '06285',
#  '06286',
#  '06287',
#  '06288',
#  '06289',
#  '06290',
#  '06291',
#  '06292',
#  '06293',
#  '06294',
#  '06295',
#  '06296',
#  '06297',
#  '06298',
#  '06299',
#  '06300',
#  '06301',
#  '06302',
#  '06307',
#  '06308',
#  '06309',
#  '06310',
#  '06311',
#  '06312',
#  '06314',
#  '06315',
#  '06316',
#  '06318',
#  '06319',
#  '06320',
#  '06321',
#  '06322',
#  '06323',
#  '06324',
#  '06325',
#  '06326',
#  '06327',
#  '06328',
#  '06329',
#  '06330',
#  '06331',
#  '06332',
#  '06333',
#  '06334',
#  '06521',
#  '08485',
#  '10360',
#  '10673',
#  '11010',
#  '11055',
#  '11056',
#  '11057',
#  '11059',
#  '11060',
#  '11066',
#  '11069',
#  '11070',
#  '11072',
#  '11073',
#  '11084',
#  '11088',
#  '11111',
#  '11158',
#  '11159',
#  '11160',
#  '11161',
#  '11163',
#  '11164',
#  '11165',
#  '11740',
#  '11748',
#  '11749',
#  '11800',
#  '11887',
#  '13777',
#  '13937',
#  '13941',
#  '13943',
#  '13944',
#  '13946',
#  '13947',
#  '13948',
#  '13949',
#  '13952',
#  '13953',
#  '13954',
#  '13955',
#  '13962',
#  '13963',
#  '13966',
#  '13984',
#  '13987',
#  '14005',
#  '14007',
#  '14280',
#  '14284',
#  '14843',
#  '20510',
#  '22222',
#  '24622',
#  '24650',
#  '27988',
#  '27990',
#  '27998',
#  '28017',
#  '28691',
#  '28789',
#  '44902',
#  '45972',
#  '49741',
#  '50210',
#  '75757',
#  '97255',
#  '99795',
#  '99999'}

# %%
alldb_drop3['site'] = alldb_drop3['site'].astype(int) # เปลี่ยนข้อมูลจาก string เป็น int ในคอลัมน์ site
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
alldb_drop3.dtypes # เช็คว่า site ทั้งหมดเป็น int หรือไม่
# Out:
# user             int64
# RowKey          object
# date            object
# phone           object
# site             int64
# time            object
# urine           object
# ov              object
# PartitionKey    object
# dtype: object

# %% [markdown]
# #### คอลัมน์ ov

# %%
set(alldb_drop3['ov']) # เพื่อดูข้อมูลทั้งหมดใน column ov
# Out:
# {'0', '1', '2', '3', '4', 'ติดเชื้อ +2 '}

# %% [markdown]
# เเก้ไขให้มีข้อมูลที่ถูกต้อง
#
# โดยกำหนดให้ข้อมูลที่ไม่ใช่เลข  เท่ากับ ข้อมูลว่าง

# %%
alldb_drop3['ov'].replace({'ติดเชื้อ +2 ':None},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
alldb_drop4 = alldb_drop3.dropna() # ทำการ drop ค่าว่างออก 
alldb_drop4 # แสดงผลลัพธ์
# Out:
#         user                                RowKey        date  \
# 185    85879                        shmpdrmtgc.png  2022-03-24
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 190     6223                        kfpwuaqldj.png  2022-03-23
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30
# ...      ...                                   ...         ...
# 39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  2022-03-11
# 39813  99999                        lnlohgqckf.png  2022-03-10
# 39814  99999                        vkdocpmjiv.png  2022-03-10
# 39815  99999                        vrvyfnvayq.png  2022-03-10
# 39816  99999                        zuhbtvyrce.png  2022-03-10
#
#                    phone   site      time                 urine ov  \
# 185         OPPO CPH2293   5194  13:08:39               มีตะกอน  0
# 188           iPhone13,1   4999  14:22:22       ปกติ (เหลืองใส)  0
# 190    Xiaomi 21081111RG  13777  16:31:45       ปกติ (เหลืองใส)  0
# 191           iPhone12,3   6307  14:46:08       ปกติ (เหลืองใส)  4
# 192           iPhone14,3   5328  15:27:45       ปกติ (เหลืองใส)  4
# ...                  ...    ...       ...                   ... ..
# 39812         iPhone14,2  99999  11:36:34                  ขุ่น  1
# 39813   Samsung SM-G998B  99999  18:10:29               มีตะกอน  0
# 39814   Samsung SM-G998B  99999  12:14:41  ขุ่น, มีเม็ดเลือดแดง  1
# 39815   Samsung SM-G998B  99999  13:58:01       ปกติ (เหลืองใส)  1
# 39816   Samsung SM-G998B  99999  13:57:58       ปกติ (เหลืองใส)  1
#
#       PartitionKey
# 185           0000
# 188           0000
# 190          00000
# 191          00001
# 192          00001
# ...            ...
# 39812        99999
# 39813        99999
# 39814        99999
# 39815        99999
# 39816        99999
#
# [37988 rows x 9 columns]

# %%
set(alldb_drop4['ov']) # เพื่อดูข้อมูลทั้งหมดใน column ov
# Out:
# {'0', '1', '2', '3', '4'}

# %%
alldb_drop4['ov'] = alldb_drop4['ov'].astype(int) # เปลี่ยนข้อมูลจาก string เป็น int ในคอลัมน์ ov
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
alldb_drop4.dtypes # เช็คว่า ov ทั้งหมดเป็น int หรือไม่
# Out:
# user             int64
# RowKey          object
# date            object
# phone           object
# site             int64
# time            object
# urine           object
# ov               int64
# PartitionKey    object
# dtype: object

# %% [markdown]
# #### คอลัมน์ PartitionKey

# %%
set(alldb_drop4['PartitionKey']) # เพื่อดูข้อมูลทั้งหมดใน column PartitionKey
# Out:
# {'00014',
#  '01035',
#  '00100',
#  '02177',
#  '08908',
#  '01045',
#  '56',
#  '01930',
#  '02702',
#  '04347',
#  '01522',
#  '00043',
#  '01790',
#  '01468',
#  '00520',
#  '00557',
#  '08949',
#  '05986',
#  '1022',
#  '01136',
#  '04735',
#  '02340',
#  '01581',
#  '08115',
#  '01025',
#  '00396',
#  '01655',
#  '01207',
#  '02375',
#  '01777',
#  '02783',
#  '08958',
#  '01351',
#  '00205',
#  '00632',
#  '06004',
#  '05248',
#  '00986',
#  '00027',
#  '01859',
#  '02272',
#  '05967',
#  '06060',
#  '00080',
#  '04648',
#  '02720',
#  '03075',
#  '02338',
#  '00423',
#  '00224',
#  '00612',
#  '01039',
#  '00798',
#  '01997',
#  '00928',
#  '08983',
#  '00700',
#  '01321',
#  '00675',
#  '01171',
#  '01481',
#  '08954',
#  '01936',
#  '02526',
#  '00399',
#  '01172',
#  '01675',
#  '03287',
#  '03359',
#  '04137',
#  '000167',
#  '03932',
#  '05124',
#  '03155',
#  '05290',
#  '04692',
#  '06012',
#  '00849',
#  '02678',
#  '02586',
#  '03313',
#  '08900',
#  '01865',
#  '00469',
#  '01643',
#  '02979',
#  '00016',
#  '02793',
#  '02139',
#  '03397',
#  '05266',
#  '03217',
#  '02077',
#  '00288',
#  '08984',
#  '01231',
#  '01639',
#  '08961',
#  '01938',
#  '05966',
#  '00605',
#  '09035',
#  '00328',
#  '09030',
#  '02578',
#  '01738',
#  '02823',
#  '01200',
#  '01322',
#  '134',
#  '02120',
#  '02257',
#  '05255',
#  '00466',
#  '05132',
#  '01069',
#  '00517',
#  '01153',
#  '01101',
#  '03977',
#  '08923',
#  '00655',
#  '00507',
#  '01238',
#  '02151',
#  '05116',
#  '10980',
#  '02417',
#  '04645',
#  '00387',
#  '01422',
#  '02379',
#  '02825',
#  '02336',
#  '01112',
#  '06037',
#  '03415',
#  '03983',
#  '00311',
#  '02666',
#  '00668',
#  '02643',
#  '08968',
#  '02188',
#  '00318',
#  '00935',
#  '00283',
#  '01306',
#  '03400',
#  '00863',
#  '02973',
#  '03002',
#  '08912',
#  '02106',
#  '01360',
#  '02997',
#  '000102',
#  '01996',
#  '00217',
#  '00684',
#  '00965',
#  '03548',
#  '08960',
#  '05292',
#  '08976',
#  '00732',
#  '04636',
#  '02028',
#  '10970',
#  '00539',
#  '01118',
#  '01385',
#  '04185',
#  '05195',
#  '00691',
#  '02704',
#  '00676',
#  '00992',
#  '01804',
#  '02196',
#  '03110',
#  '0030',
#  '01536',
#  '00074',
#  '00921',
#  '08995',
#  '00796',
#  '01946',
#  '00274',
#  '01459',
#  '02664',
#  '02356',
#  '00490',
#  '00069',
#  '00542',
#  '01833',
#  '02675',
#  '00625',
#  '05245',
#  '00343',
#  '02662',
#  '00624',
#  '00930',
#  '01618',
#  '01861',
#  '01093',
#  '00310',
#  '04012',
#  '10988',
#  '01705',
#  '06026',
#  '01751',
#  '10973',
#  '119',
#  '01525',
#  '00000',
#  '06029',
#  '00731',
#  '00247',
#  '01636',
#  '01038',
#  '03497',
#  '00412',
#  '00398',
#  '00792',
#  '00220',
#  '00522',
#  '05991',
#  '08069',
#  '02922',
#  '03197',
#  '00846',
#  '01487',
#  '03535',
#  '05105',
#  '02951',
#  '03335',
#  '03500',
#  '01211',
#  '01196',
#  '02534',
#  '02891',
#  '01721',
#  '02078',
#  '00382',
#  '01952',
#  '00865',
#  '02565',
#  '04679',
#  '02588',
#  '00560',
#  '00365',
#  '00825',
#  '00304',
#  '05974',
#  '09010',
#  '01460',
#  '09043',
#  '09013',
#  '01922',
#  '02903',
#  '00553',
#  '03133',
#  '03494',
#  '00802',
#  '00949',
#  '00583',
#  '01267',
#  '00500',
#  '04650',
#  '01272',
#  '03395',
#  '00810',
#  '02727',
#  '01995',
#  '00819',
#  '00953',
#  '00594',
#  '01754',
#  '02407',
#  '00663',
#  '01047',
#  '00497',
#  '03715',
#  '02387',
#  '00077',
#  '05989',
#  '00408',
#  '01860',
#  '01324',
#  '00534',
#  '02402',
#  '00956',
#  ...}

# %%
alldb_drop5['PartitionKey'] = alldb_drop5['PartitionKey'].astype(int) # เปลี่ยนข้อมูลจาก string เป็น int ในคอลัมน์ PartitionKey
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
alldb_drop5.dtypes # เช็คว่า PartitionKey ทั้งหมดเป็น int หรือไม่
# Out:
# user             int64
# RowKey          object
# date            object
# phone           object
# site             int64
# time            object
# urine           object
# ov               int64
# PartitionKey     int64
# dtype: object

# %% [markdown]
# ### ทำการเเก้ไขข้อมูลให้ถูกต้อง ในรูปแบบที่กำหนด

# %% [markdown]
# #### คอลัมน์ time

# %%
alldb_drop5['time'] = alldb_drop5['time'].replace(':','-', regex=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## ตาราง alldb.csv หลังจัดการข้อมูลแล้ว

# %%
alldb_drop5 # ดูตาราง alldb.csv หลังจัดการข้อมูลแล้ว
# Out:
#         user                                RowKey        date  \
# 185    85879                        shmpdrmtgc.png  2022-03-24
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 190     6223                        kfpwuaqldj.png  2022-03-23
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30
# ...      ...                                   ...         ...
# 39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  2022-03-11
# 39813  99999                        lnlohgqckf.png  2022-03-10
# 39814  99999                        vkdocpmjiv.png  2022-03-10
# 39815  99999                        vrvyfnvayq.png  2022-03-10
# 39816  99999                        zuhbtvyrce.png  2022-03-10
#
#                    phone   site      time                 urine  ov  \
# 185         OPPO CPH2293   5194  13-08-39               มีตะกอน   0
# 188           iPhone13,1   4999  14-22-22       ปกติ (เหลืองใส)   0
# 190    Xiaomi 21081111RG  13777  16-31-45       ปกติ (เหลืองใส)   0
# 191           iPhone12,3   6307  14-46-08       ปกติ (เหลืองใส)   4
# 192           iPhone14,3   5328  15-27-45       ปกติ (เหลืองใส)   4
# ...                  ...    ...       ...                   ...  ..
# 39812         iPhone14,2  99999  11-36-34                  ขุ่น   1
# 39813   Samsung SM-G998B  99999  18-10-29               มีตะกอน   0
# 39814   Samsung SM-G998B  99999  12-14-41  ขุ่น, มีเม็ดเลือดแดง   1
# 39815   Samsung SM-G998B  99999  13-58-01       ปกติ (เหลืองใส)   1
# 39816   Samsung SM-G998B  99999  13-57-58       ปกติ (เหลืองใส)   1
#
#        PartitionKey
# 185               0
# 188               0
# 190               0
# 191               1
# 192               1
# ...             ...
# 39812         99999
# 39813         99999
# 39814         99999
# 39815         99999
# 39816         99999
#
# [37966 rows x 9 columns]

# %% [markdown]
# ## จัดการข้อมูลหลัก ตาราง hospital_list.xlsx

# %%
hospital_list # แสดงข้อมูลตาราง hospital_list.xlsx
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5  code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อท           ATG
# ...                         ...    ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
#
# [17103 rows x 16 columns]

# %% [markdown]
# ### ตรวจสอบค่า Missing

# %%
hospital_list.isnull().any() 
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# hcode            False
# name              True
# zone_code        False
# zone_name         True
# provincecode      True
# province         False
# amphurcode        True
# amphur            True
# tamboncode        True
# tambon            True
# code4             True
# name5             True
# code9             True
# name10            True
# short_thai        True
# short_english     True
# dtype: bool

# %% [markdown]
# ### ใช้ .dropna ซึ่งจะใช้ตัดแถวข้อมูลที่มีค่า missing

# %%
h_drop = hospital_list.dropna() #ใช้ dropna เพื่อต้องการลบข้อมูลทั้งแถวออกเมื่อมีคอลัมน์ใดคอลัมน์หนึ่งเป็น NaN
h_drop
# Out:
#        hcode                                               name  zone_code  \
# 931    00933              โรงพยาบาลส่งเสริมสุขภาพตำบลสำโรงเหนือ          6
# 932    00934                โรงพยาบาลส่งเสริมสุขภาพตำบลบางเมือง          6
# 933    00935  โรงพยาบาลส่งเสริมสุขภาพตำบลเฉลิมพระเกียรติ บ้า...          6
# 934    00936               โรงพยาบาลส่งเสริมสุขภาพตำบลบางปูใหม่          6
# 935    00937                  โรงพยาบาลส่งเสริมสุขภาพตำบลแพรกษา          6
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 931          สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 932          สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 933          สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 934          สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 935          สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode      tambon  code4  \
# 931    เมืองสมุทรปราการ         2.0  สำโรงเหนือ   18.0
# 932    เมืองสมุทรปราการ         3.0    บางเมือง   18.0
# 933    เมืองสมุทรปราการ         3.0    บางเมือง   18.0
# 934    เมืองสมุทรปราการ         8.0   บางปูใหม่   18.0
# 935    เมืองสมุทรปราการ        10.0      แพรกษา   18.0
# ...                 ...         ...         ...    ...
# 17098    เมืองอุตรดิตถ์         1.0      ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0     กุยบุรี    8.0
# 17100           วัดเพลง         3.0     วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0      โพนข่า    8.0
# 17102             บางแพ         2.0     วังเย็น    8.0
#
#                              name5  code9     name10 short_thai short_english
# 931    โรงพยาบาลส่งเสริมสุขภาพตำบล   10.0  1 ปฐมภูมิ         สป           SPK
# 932    โรงพยาบาลส่งเสริมสุขภาพตำบล   10.0  1 ปฐมภูมิ         สป           SPK
# 933    โรงพยาบาลส่งเสริมสุขภาพตำบล   10.0  1 ปฐมภูมิ         สป           SPK
# 934    โรงพยาบาลส่งเสริมสุขภาพตำบล   10.0  1 ปฐมภูมิ         สป           SPK
# 935    โรงพยาบาลส่งเสริมสุขภาพตำบล   10.0  1 ปฐมภูมิ         สป           SPK
# ...                            ...    ...        ...        ...           ...
# 17098     ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         อต           UTT
# 17099     ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ปข           PKN
# 17100     ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
# 17101     ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ศก           SSK
# 17102     ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
#
# [11798 rows x 16 columns]

# %%
h_drop.shape #ตรวจสอบขนาดของตารางใหม่
# Out:
# (11798, 16)

# %%
removes = hospital_list.shape[0] - h_drop.shape[0]
print(f'size before drop = {hospital_list.shape[0]}')
print(f'size after drop = {h_drop.shape[0]}')
print(f'% from drop = {(removes/hospital_list.shape[0])*100}')
 # จากการคำนวณพบว่ามีข้อมูลที่หายไปถึง 31% ดังนั้น จึงไม่สามารถใช้การ .dropna() ได ้
# Out:
# size before drop = 17103
# size after drop = 11798
# % from drop = 31.017950067239664

# %%
hospital_list[['name']] = hospital_list[['name']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
hospital_list[['zone_name']] = hospital_list[['zone_name']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
p = hospital_list[['provincecode']].mean() #กำหนดให้ provincecode เป็นค่าเฉลี่ยของ provincecode
hospital_list[['provincecode']] = hospital_list[['provincecode']].fillna(p) #แทนค่าเฉลี่ยลงในข้อมูลที่ว่าง หรือเป็นค่า missing

# %%
a = hospital_list[['amphurcode']].mean() #กำหนดให้ amphurcode เป็นค่าเฉลี่ยของ amphurcode
hospital_list[['amphurcode']] = hospital_list[['amphurcode']].fillna(a) #แทนค่าเฉลี่ยลงในข้อมูลที่ว่าง หรือเป็นค่า missing

# %%
hospital_list[['amphur']] = hospital_list[['amphur']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
t = hospital_list[['tamboncode']].mean() #กำหนดให้ tamboncode เป็นค่าเฉลี่ยของ tamboncode
hospital_list[['tamboncode']] = hospital_list[['tamboncode']].fillna(t) #แทนค่าเฉลี่ยลงในข้อมูลที่ว่าง หรือเป็นค่า missing

# %%
hospital_list[['tambon']] = hospital_list[['tambon']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
c = hospital_list[['code4']].mean() #กำหนดให้ code4 เป็นค่าเฉลี่ยของ code4
hospital_list[['code4']] = hospital_list[['code4']].fillna(c) #แทนค่าเฉลี่ยลงในข้อมูลที่ว่าง หรือเป็นค่า missing

# %%
hospital_list[['name5']] = hospital_list[['name5']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
c2 = hospital_list[['code9']].mean() #กำหนดให้ code9 เป็นค่าเฉลี่ยของ code9
hospital_list[['code9']] = hospital_list[['code9']].fillna(c2) #แทนค่าเฉลี่ยลงในข้อมูลที่ว่าง หรือเป็นค่า missing

# %%
hospital_list[['name10']] = hospital_list[['name10']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
hospital_list[['short_thai']] = hospital_list[['short_thai']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
hospital_list[['short_english']] = hospital_list[['short_english']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
hospital_list.isnull().any() 
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# hcode            False
# name             False
# zone_code        False
# zone_name        False
# provincecode     False
# province         False
# amphurcode       False
# amphur           False
# tamboncode       False
# tambon           False
# code4            False
# name5            False
# code9            False
# name10           False
# short_thai       False
# short_english    False
# dtype: bool

# %% [markdown]
# ### ทำการเปลี่ยน type ของข้อมูลให้เป็น type ที่ถูกต้อง

# %%
hospital_list.dtypes # เช็คว่าข้อมูลมี่ความตรงกับที่ต้องการหรือไม่ ## ต้องการให้ hcode เป็น int
# Out:
# hcode             object
# name              object
# zone_code          int64
# zone_name         object
# provincecode     float64
# province          object
# amphurcode       float64
# amphur            object
# tamboncode       float64
# tambon            object
# code4            float64
# name5             object
# code9            float64
# name10            object
# short_thai        object
# short_english     object
# dtype: object

# %%
set(hospital_list['hcode']) # เพื่อดูข้อมูลทั้งหมดใน column hcode
# Out:
# {'23732',
#  '01035',
#  '10734',
#  '24230',
#  '14994',
#  '05969',
#  '11261',
#  '07559',
#  '07184',
#  '08784',
#  '06508',
#  '19352',
#  '06982',
#  '14007',
#  '24102',
#  '07990',
#  '09453',
#  '04855',
#  '10735',
#  '08755',
#  '00520',
#  '24205',
#  '03323',
#  '05478',
#  '08949',
#  '24021',
#  '07390',
#  '25169',
#  '09060',
#  '07709',
#  '09729',
#  '00396',
#  '07078',
#  '01655',
#  '04933',
#  '01207',
#  '02375',
#  '08139',
#  '11531',
#  '08958',
#  '06056',
#  '07366',
#  '25589',
#  '05248',
#  '01859',
#  '03615',
#  '02272',
#  '05967',
#  '11996',
#  '14958',
#  '10234',
#  '08409',
#  '00423',
#  '10571',
#  '11523',
#  '16135',
#  '17911',
#  '00224',
#  '27347',
#  '11325',
#  '23983',
#  '09032',
#  '99774',
#  '11086',
#  '26246',
#  '01321',
#  '26284',
#  '10539',
#  '01481',
#  '04703',
#  '05559',
#  '27636',
#  '07770',
#  '08344',
#  '28669',
#  '05722',
#  '04191',
#  '25027',
#  '11631',
#  '06925',
#  '03907',
#  '01294',
#  '14261',
#  '26259',
#  '10223',
#  '25688',
#  '23686',
#  '08933',
#  '10356',
#  '06850',
#  '07294',
#  '25880',
#  '01378',
#  '25739',
#  '13685',
#  '04992',
#  '11155',
#  '02032',
#  '24281',
#  '00334',
#  '02547',
#  '27732',
#  '00407',
#  '08045',
#  '04118',
#  '03652',
#  '06203',
#  '01453',
#  '28175',
#  '28681',
#  '10796',
#  '25957',
#  '28410',
#  '10791',
#  '00554',
#  '04274',
#  '25868',
#  '28763',
#  '12254',
#  '06981',
#  ...}

# %% [markdown]
# เเก้ไขให้มีข้อมูลที่ถูกต้อง
#
# โดยกำหนดให้ข้อมูลที่ไม่ใช่เลข 5 หลัก เท่ากับ ข้อมูลว่าง

# %%
hospital_list['hcode'].replace({'2475x':None,'2560x':None},inplace=True)

# %%
hospital_list_drop = hospital_list.dropna() # ทำการ drop ค่าว่างออก 
hospital_list_drop # แสดงผลลัพธ์
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5     code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         อท           ATG
# ...                         ...       ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         รบ           RBR
#
# [17101 rows x 16 columns]

# %%
hospital_list_drop['hcode'] = hospital_list_drop['hcode'].astype(int) # เปลี่ยนข้อมูลจาก string เป็น int ในคอลัมน์ hcode
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## ตาราง hospital_list.xlsx หลังจัดการข้อมูลแล้ว

# %%
hospital_list_drop # ดูตาราง hospital_list.xlsx หลังจัดการข้อมูลแล้ว
# Out:
#        hcode                                               name  zone_code  \
# 0          1                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1          2                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2          3                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3          4            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4          5                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5     code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         อท           ATG
# ...                         ...       ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         รบ           RBR
#
# [17101 rows x 16 columns]

# %% [markdown]
# # รวมข้อมูลทั้งสองตารางเข้าด้วยกัน
#
# ไฟล์ alldb.csv และ hospital_list.xlsx สามารถถูกเชื่อมโยงกันโดย site ในไฟล์ alldb.csv คือ hcode ในไฟล์ hospital_list.xlsx

# %%
merged = alldb_drop5.merge(hospital_list_drop,how='left',left_on='site',right_on='hcode') 
merged
# Out:
#         user                                RowKey        date  \
# 0      85879                        shmpdrmtgc.png  2022-03-24
# 1      27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 2       6223                        kfpwuaqldj.png  2022-03-23
# 3      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30
# 4      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30
# ...      ...                                   ...         ...
# 37961  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  2022-03-11
# 37962  99999                        lnlohgqckf.png  2022-03-10
# 37963  99999                        vkdocpmjiv.png  2022-03-10
# 37964  99999                        vrvyfnvayq.png  2022-03-10
# 37965  99999                        zuhbtvyrce.png  2022-03-10
#
#                    phone   site      time                 urine  ov  \
# 0           OPPO CPH2293   5194  13-08-39               มีตะกอน   0
# 1             iPhone13,1   4999  14-22-22       ปกติ (เหลืองใส)   0
# 2      Xiaomi 21081111RG  13777  16-31-45       ปกติ (เหลืองใส)   0
# 3             iPhone12,3   6307  14-46-08       ปกติ (เหลืองใส)   4
# 4             iPhone14,3   5328  15-27-45       ปกติ (เหลืองใส)   4
# ...                  ...    ...       ...                   ...  ..
# 37961         iPhone14,2  99999  11-36-34                  ขุ่น   1
# 37962   Samsung SM-G998B  99999  18-10-29               มีตะกอน   0
# 37963   Samsung SM-G998B  99999  12-14-41  ขุ่น, มีเม็ดเลือดแดง   1
# 37964   Samsung SM-G998B  99999  13-58-01       ปกติ (เหลืองใส)   1
# 37965   Samsung SM-G998B  99999  13-57-58       ปกติ (เหลืองใส)   1
#
#        PartitionKey    hcode  ... amphurcode        amphur tamboncode  \
# 0                 0   5194.0  ...        9.0       หนองพอก        4.0
# 1                 0   4999.0  ...        6.0         บรบือ       19.0
# 2                 0  13777.0  ...        1.0  เมืองขอนแก่น        1.0
# 3                 1   6307.0  ...        7.0         พิชัย        2.0
# 4                 1   5328.0  ...       18.0       ฆ้องชัย        3.0
# ...             ...      ...  ...        ...           ...        ...
# 37961         99999      NaN  ...        NaN           NaN        NaN
# 37962         99999      NaN  ...        NaN           NaN        NaN
# 37963         99999      NaN  ...        NaN           NaN        NaN
# 37964         99999      NaN  ...        NaN           NaN        NaN
# 37965         99999      NaN  ...        NaN           NaN        NaN
#
#          tambon code4                        name5     code9     name10  \
# 0       กกโพธิ์  18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.00000  1 ปฐมภูมิ
# 1        หนองโก  18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.00000  1 ปฐมภูมิ
# 2       ในเมือง  12.0            โรงพยาบาล นอก สธ.  10.84859    ไม่ระบุ
# 3      บ้านดารา  18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.00000  1 ปฐมภูมิ
# 4      โคกสะอาด  18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.00000  1 ปฐมภูมิ
# ...         ...   ...                          ...       ...        ...
# 37961       NaN   NaN                          NaN       NaN        NaN
# 37962       NaN   NaN                          NaN       NaN        NaN
# 37963       NaN   NaN                          NaN       NaN        NaN
# 37964       NaN   NaN                          NaN       NaN        NaN
# 37965       NaN   NaN                          NaN       NaN        NaN
#
#       short_thai  short_english
# 0             รอ            RET
# 1             มค            MKM
# 2             ขก            KKN
# 3             อต            UTT
# 4             กส            KSN
# ...          ...            ...
# 37961        NaN            NaN
# 37962        NaN            NaN
# 37963        NaN            NaN
# 37964        NaN            NaN
# 37965        NaN            NaN
#
# [37966 rows x 25 columns]

# %% [markdown]
# ## ตรวจสอบค่า Missing

# %%
merged.isnull().any() 
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# user             False
# RowKey           False
# date             False
# phone            False
# site             False
# time             False
# urine            False
# ov               False
# PartitionKey     False
# hcode             True
# name              True
# zone_code         True
# zone_name         True
# provincecode      True
# province          True
# amphurcode        True
# amphur            True
# tamboncode        True
# tambon            True
# code4             True
# name5             True
# code9             True
# name10            True
# short_thai        True
# short_english     True
# dtype: bool

# %% [markdown]
# ## ใช้ .dropna ซึ่งจะใช้ตัดแถวข้อมูลที่มีค่า missing

# %%
merged_drop = merged.dropna() #ใช้ dropna เพื่อต้องการลบข้อมูลทั้งแถวออกเมื่อมีคอลัมน์ใดคอลัมน์หนึ่งเป็น NaN
merged_drop
# Out:
#         user                                RowKey        date  \
# 0      85879                        shmpdrmtgc.png  2022-03-24
# 1      27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 2       6223                        kfpwuaqldj.png  2022-03-23
# 3      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30
# 4      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30
# ...      ...                                   ...         ...
# 37949  76331                        pvpiawlexb.png  2022-02-23
# 37950  68317                        rtutxrlbam.png  2022-02-23
# 37951  68317                        dmuragqwza.png  2022-02-23
# 37952  68768  D8A3A9EA-929E-4CEB-BFDF-C9BE093EA663  2022-03-24
# 37953  99771  E04D3D60-B916-40A1-AE77-91CCD89DD084  2022-03-31
#
#                    phone   site      time            urine  ov  PartitionKey  \
# 0           OPPO CPH2293   5194  13-08-39          มีตะกอน   0             0
# 1             iPhone13,1   4999  14-22-22  ปกติ (เหลืองใส)   0             0
# 2      Xiaomi 21081111RG  13777  16-31-45  ปกติ (เหลืองใส)   0             0
# 3             iPhone12,3   6307  14-46-08  ปกติ (เหลืองใส)   4             1
# 4             iPhone14,3   5328  15-27-45  ปกติ (เหลืองใส)   4             1
# ...                  ...    ...       ...              ...  ..           ...
# 37949   Samsung SM-G965U   5258  15-32-53  ปกติ (เหลืองใส)   1            92
# 37950   Samsung SM-A115F  28017  14-31-01  ปกติ (เหลืองใส)   2           976
# 37951   Samsung SM-A115F  28017  14-30-21  ปกติ (เหลืองใส)   2           983
# 37952         iPhone11,8  11088  10-25-32  ปกติ (เหลืองใส)   1         99444
# 37953         iPhone10,5   5396  11-03-40  ปกติ (เหลืองใส)   0         99771
#
#          hcode  ... amphurcode        amphur tamboncode        tambon code4  \
# 0       5194.0  ...        9.0       หนองพอก        4.0       กกโพธิ์  18.0
# 1       4999.0  ...        6.0         บรบือ       19.0        หนองโก  18.0
# 2      13777.0  ...        1.0  เมืองขอนแก่น        1.0       ในเมือง  12.0
# 3       6307.0  ...        7.0         พิชัย        2.0      บ้านดารา  18.0
# 4       5328.0  ...       18.0       ฆ้องชัย        3.0      โคกสะอาด  18.0
# ...        ...  ...        ...           ...        ...           ...   ...
# 37949   5258.0  ...       14.0     อาจสามารถ        9.0      ขี้เหล็ก  18.0
# 37950  28017.0  ...       16.0          นาคู        1.0          นาคู   7.0
# 37951  28017.0  ...       16.0          นาคู        1.0          นาคู   7.0
# 37952  11088.0  ...       14.0      ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0
# 37953   5396.0  ...       10.0        คำม่วง        9.0       เนินยาง  18.0
#
#                              name5     code9                 name10  \
# 0      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.00000              1 ปฐมภูมิ
# 1      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.00000              1 ปฐมภูมิ
# 2                โรงพยาบาล นอก สธ.  10.84859                ไม่ระบุ
# 3      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.00000              1 ปฐมภูมิ
# 4      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.00000              1 ปฐมภูมิ
# ...                            ...       ...                    ...
# 37949  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.00000              1 ปฐมภูมิ
# 37950               โรงพยาบาลชุมชน  10.84859                ไม่ระบุ
# 37951               โรงพยาบาลชุมชน  10.84859                ไม่ระบุ
# 37952               โรงพยาบาลชุมชน  21.00000  2.1 ทุติยภูมิระดับต้น
# 37953  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.00000              1 ปฐมภูมิ
#
#       short_thai  short_english
# 0             รอ            RET
# 1             มค            MKM
# 2             ขก            KKN
# 3             อต            UTT
# 4             กส            KSN
# ...          ...            ...
# 37949         รอ            RET
# 37950         กส            KSN
# 37951         กส            KSN
# 37952         กส            KSN
# 37953         กส            KSN
#
# [37892 rows x 25 columns]

# %%
merged_drop.shape #ตรวจสอบขนาดของตารางใหม่
# Out:
# (37892, 25)

# %%
removes = merged.shape[0] - merged_drop.shape[0]
print(f'size before drop = {merged.shape[0]}')
print(f'size after drop = {merged_drop.shape[0]}')
print(f'% from drop = {(removes/merged.shape[0])*100}')
 # จากการคำนวณพบว่ามีข้อมูลที่หายไปเพียงแค่ 0.195% ดังนั้น จึงสามารถใช้การ .dropna() ได ้
# Out:
# size before drop = 37966
# size after drop = 37892
# % from drop = 0.19491123636938312

# %% [markdown]
# ## ตรวจสอบเอาแต่ 5 หลัก
#
# user & site & PartitionKey

# %%
TF=list()
for each_row in merged_drop.iterrows():
    if 9999< each_row[1]['site'] <100000:
        TF.append(True)
    else:
        TF.append(False)

merged_drop = merged_drop[TF]
merged_drop
# Out:
#         user                                RowKey        date  \
# 2       6223                        kfpwuaqldj.png  2022-03-23
# 15     18041  3FBB8FE8-F3EE-4307-8E01-406D7A1B2488  2022-03-28
# 20     27096  4D1F5F3E-E557-4F64-BEB7-D4FBCADFA43F  2022-03-30
# 22         1  540553CD-1EAB-4252-A64E-F96A8390CE10  2022-03-28
# 30      8370  6E4E96B0-5DE4-456F-8088-A1FEF6E3F468  2022-03-23
# ...      ...                                   ...         ...
# 37947  68768  899A7591-50C9-40BC-9746-A831A08DE980  2022-03-24
# 37948  68768  BF39F27C-1B43-4C97-A034-D7A579BED2B6  2022-03-24
# 37950  68317                        rtutxrlbam.png  2022-02-23
# 37951  68317                        dmuragqwza.png  2022-02-23
# 37952  68768  D8A3A9EA-929E-4CEB-BFDF-C9BE093EA663  2022-03-24
#
#                    phone   site      time            urine  ov  PartitionKey  \
# 2      Xiaomi 21081111RG  13777  16-31-45  ปกติ (เหลืองใส)   0             0
# 15            iPhone14,3  11158  10-12-10  ปกติ (เหลืองใส)   2             1
# 20            iPhone14,5  11160  14-56-46  ปกติ (เหลืองใส)   0             1
# 22              iPad13,6  10360  12-24-15  ปกติ (เหลืองใส)   2             1
# 30            iPhone10,5  13966  10-42-14  ปกติ (เหลืองใส)   1             1
# ...                  ...    ...       ...              ...  ..           ...
# 37947         iPhone11,8  11088  10-29-37  ปกติ (เหลืองใส)   0         90470
# 37948         iPhone11,8  11088  10-24-40  ปกติ (เหลืองใส)   1         91123
# 37950   Samsung SM-A115F  28017  14-31-01  ปกติ (เหลืองใส)   2           976
# 37951   Samsung SM-A115F  28017  14-30-21  ปกติ (เหลืองใส)   2           983
# 37952         iPhone11,8  11088  10-25-32  ปกติ (เหลืองใส)   1         99444
#
#          hcode  ... amphurcode        amphur tamboncode        tambon code4  \
# 2      13777.0  ...        1.0  เมืองขอนแก่น        1.0       ในเมือง  12.0
# 15     11158.0  ...        2.0          ตรอน        2.0      บ้านแก่ง   7.0
# 20     11160.0  ...        4.0        น้ำปาด        1.0         แสนตอ   7.0
# 22     10360.0  ...        4.0        น้ำปาด        5.0        น้ำไผ่  18.0
# 30     13966.0  ...       14.0      ห้วยผึ้ง        2.0       ไค้นุ่น  18.0
# ...        ...  ...        ...           ...        ...           ...   ...
# 37947  11088.0  ...       14.0      ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0
# 37948  11088.0  ...       14.0      ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0
# 37950  28017.0  ...       16.0          นาคู        1.0          นาคู   7.0
# 37951  28017.0  ...       16.0          นาคู        1.0          นาคู   7.0
# 37952  11088.0  ...       14.0      ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0
#
#                              name5     code9                  name10  \
# 2                โรงพยาบาล นอก สธ.  10.84859                 ไม่ระบุ
# 15                  โรงพยาบาลชุมชน  22.00000  2.2 ทุติยภูมิระดับกลาง
# 20                  โรงพยาบาลชุมชน  22.00000  2.2 ทุติยภูมิระดับกลาง
# 22     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.00000               1 ปฐมภูมิ
# 30     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.00000               1 ปฐมภูมิ
# ...                            ...       ...                     ...
# 37947               โรงพยาบาลชุมชน  21.00000   2.1 ทุติยภูมิระดับต้น
# 37948               โรงพยาบาลชุมชน  21.00000   2.1 ทุติยภูมิระดับต้น
# 37950               โรงพยาบาลชุมชน  10.84859                 ไม่ระบุ
# 37951               โรงพยาบาลชุมชน  10.84859                 ไม่ระบุ
# 37952               โรงพยาบาลชุมชน  21.00000   2.1 ทุติยภูมิระดับต้น
#
#       short_thai  short_english
# 2             ขก            KKN
# 15            อต            UTT
# 20            อต            UTT
# 22            อต            UTT
# 30            กส            KSN
# ...          ...            ...
# 37947         กส            KSN
# 37948         กส            KSN
# 37950         กส            KSN
# 37951         กส            KSN
# 37952         กส            KSN
#
# [4022 rows x 25 columns]

# %%
TF=list()
for each_row in merged_drop.iterrows():
    if 9999< each_row[1]['user'] <100000:
        TF.append(True)
    else:
        TF.append(False)

merged_drop = merged_drop[TF]
merged_drop
# Out:
#         user                                RowKey        date  \
# 15     18041  3FBB8FE8-F3EE-4307-8E01-406D7A1B2488  2022-03-28
# 20     27096  4D1F5F3E-E557-4F64-BEB7-D4FBCADFA43F  2022-03-30
# 33     76486  73F5F082-6877-4C1F-971D-0485621C1D94  2022-03-18
# 36     51235  76E4E69A-2C96-4B9D-BF7E-B97D64D3277D  2022-03-21
# 40     61813  7EED02D6-47C8-4AEE-9B88-5DFBD7836508  2022-03-03
# ...      ...                                   ...         ...
# 37947  68768  899A7591-50C9-40BC-9746-A831A08DE980  2022-03-24
# 37948  68768  BF39F27C-1B43-4C97-A034-D7A579BED2B6  2022-03-24
# 37950  68317                        rtutxrlbam.png  2022-02-23
# 37951  68317                        dmuragqwza.png  2022-02-23
# 37952  68768  D8A3A9EA-929E-4CEB-BFDF-C9BE093EA663  2022-03-24
#
#                   phone   site      time            urine  ov  PartitionKey  \
# 15           iPhone14,3  11158  10-12-10  ปกติ (เหลืองใส)   2             1
# 20           iPhone14,5  11160  14-56-46  ปกติ (เหลืองใส)   0             1
# 33           iPhone12,1  13949  15-09-50  ปกติ (เหลืองใส)   2             1
# 36           iPhone13,3  13987  11-21-56  ปกติ (เหลืองใส)   0             1
# 40           iPhone12,3  13777  15-59-20   มีเม็ดเลือดแดง   2             1
# ...                 ...    ...       ...              ...  ..           ...
# 37947        iPhone11,8  11088  10-29-37  ปกติ (เหลืองใส)   0         90470
# 37948        iPhone11,8  11088  10-24-40  ปกติ (เหลืองใส)   1         91123
# 37950  Samsung SM-A115F  28017  14-31-01  ปกติ (เหลืองใส)   2           976
# 37951  Samsung SM-A115F  28017  14-30-21  ปกติ (เหลืองใส)   2           983
# 37952        iPhone11,8  11088  10-25-32  ปกติ (เหลืองใส)   1         99444
#
#          hcode  ... amphurcode        amphur tamboncode        tambon code4  \
# 15     11158.0  ...        2.0          ตรอน        2.0      บ้านแก่ง   7.0
# 20     11160.0  ...        4.0        น้ำปาด        1.0         แสนตอ   7.0
# 33     13949.0  ...        6.0        พนมไพร        7.0      โคกสว่าง  18.0
# 36     13987.0  ...        3.0       แม่แจ่ม        8.0        กองแขก  18.0
# 40     13777.0  ...        1.0  เมืองขอนแก่น        1.0       ในเมือง  12.0
# ...        ...  ...        ...           ...        ...           ...   ...
# 37947  11088.0  ...       14.0      ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0
# 37948  11088.0  ...       14.0      ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0
# 37950  28017.0  ...       16.0          นาคู        1.0          นาคู   7.0
# 37951  28017.0  ...       16.0          นาคู        1.0          นาคู   7.0
# 37952  11088.0  ...       14.0      ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0
#
#                              name5     code9                  name10  \
# 15                  โรงพยาบาลชุมชน  22.00000  2.2 ทุติยภูมิระดับกลาง
# 20                  โรงพยาบาลชุมชน  22.00000  2.2 ทุติยภูมิระดับกลาง
# 33     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.00000               1 ปฐมภูมิ
# 36     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.00000               1 ปฐมภูมิ
# 40               โรงพยาบาล นอก สธ.  10.84859                 ไม่ระบุ
# ...                            ...       ...                     ...
# 37947               โรงพยาบาลชุมชน  21.00000   2.1 ทุติยภูมิระดับต้น
# 37948               โรงพยาบาลชุมชน  21.00000   2.1 ทุติยภูมิระดับต้น
# 37950               โรงพยาบาลชุมชน  10.84859                 ไม่ระบุ
# 37951               โรงพยาบาลชุมชน  10.84859                 ไม่ระบุ
# 37952               โรงพยาบาลชุมชน  21.00000   2.1 ทุติยภูมิระดับต้น
#
#       short_thai  short_english
# 15            อต            UTT
# 20            อต            UTT
# 33            รอ            RET
# 36            ชม            CMI
# 40            ขก            KKN
# ...          ...            ...
# 37947         กส            KSN
# 37948         กส            KSN
# 37950         กส            KSN
# 37951         กส            KSN
# 37952         กส            KSN
#
# [3625 rows x 25 columns]

# %%
TF=list()
for each_row in merged_drop.iterrows():
    if 9999< each_row[1]['PartitionKey'] <100000:
        TF.append(True)
    else:
        TF.append(False)

merged_drop = merged_drop[TF]
merged_drop
# Out:
#         user                                RowKey        date         phone  \
# 37792  26462  6C55B69E-8E4C-46B0-B0D7-4754A529EE3C  2022-03-21    iPhone13,4
# 37793  26462                        eehzjpxnjw.png  2022-03-22  OPPO CPH1819
# 37794  26462                        cjukggkdgy.png  2022-03-22  OPPO CPH1819
# 37795  26462                        wpnaiylzxi.png  2022-03-22    Vivo V2050
# 37796  26462                        pnqumypemv.png  2022-03-22    Vivo V2050
# ...      ...                                   ...         ...           ...
# 37945  68768  40A5A14E-33E1-4246-95A7-9757D184BC39  2022-03-24    iPhone11,8
# 37946  68768  B7F36631-D2C4-4EB5-852D-790BFAFDFD71  2022-03-24    iPhone11,8
# 37947  68768  899A7591-50C9-40BC-9746-A831A08DE980  2022-03-24    iPhone11,8
# 37948  68768  BF39F27C-1B43-4C97-A034-D7A579BED2B6  2022-03-24    iPhone11,8
# 37952  68768  D8A3A9EA-929E-4CEB-BFDF-C9BE093EA663  2022-03-24    iPhone11,8
#
#         site      time            urine  ov  PartitionKey    hcode  ...  \
# 37792  11069  10-08-34  ปกติ (เหลืองใส)   4         10961  11069.0  ...
# 37793  11069  10-06-17             ขุ่น   1         10962  11069.0  ...
# 37794  11069  09-33-02  ใส่เป็นน้ำเปล่า   0         10963  11069.0  ...
# 37795  11069  09-31-42  ปกติ (เหลืองใส)   0         10964  11069.0  ...
# 37796  11069  09-49-16  ปกติ (เหลืองใส)   3         10965  11069.0  ...
# ...      ...       ...              ...  ..           ...      ...  ...
# 37945  11088  10-31-17  ปกติ (เหลืองใส)   1         88432  11088.0  ...
# 37946  11088  10-30-22  ปกติ (เหลืองใส)   2         89170  11088.0  ...
# 37947  11088  10-29-37  ปกติ (เหลืองใส)   0         90470  11088.0  ...
# 37948  11088  10-24-40  ปกติ (เหลืองใส)   1         91123  11088.0  ...
# 37952  11088  10-25-32  ปกติ (เหลืองใส)   1         99444  11088.0  ...
#
#       amphurcode    amphur tamboncode        tambon code4           name5  \
# 37792       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0  โรงพยาบาลชุมชน
# 37793       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0  โรงพยาบาลชุมชน
# 37794       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0  โรงพยาบาลชุมชน
# 37795       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0  โรงพยาบาลชุมชน
# 37796       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0  โรงพยาบาลชุมชน
# ...          ...       ...        ...           ...   ...             ...
# 37945       14.0  ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0  โรงพยาบาลชุมชน
# 37946       14.0  ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0  โรงพยาบาลชุมชน
# 37947       14.0  ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0  โรงพยาบาลชุมชน
# 37948       14.0  ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0  โรงพยาบาลชุมชน
# 37952       14.0  ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0  โรงพยาบาลชุมชน
#
#       code9                  name10 short_thai  short_english
# 37792  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37793  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37794  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37795  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37796  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# ...     ...                     ...        ...            ...
# 37945  21.0   2.1 ทุติยภูมิระดับต้น         กส            KSN
# 37946  21.0   2.1 ทุติยภูมิระดับต้น         กส            KSN
# 37947  21.0   2.1 ทุติยภูมิระดับต้น         กส            KSN
# 37948  21.0   2.1 ทุติยภูมิระดับต้น         กส            KSN
# 37952  21.0   2.1 ทุติยภูมิระดับต้น         กส            KSN
#
# [72 rows x 25 columns]

# %% [markdown]
# # ตารางข้อมูลที่จะนำมาใช้

# %%
merged_drop # แสดงผลลัพธ์
# Out:
#         user                                RowKey        date         phone  \
# 37792  26462  6C55B69E-8E4C-46B0-B0D7-4754A529EE3C  2022-03-21    iPhone13,4
# 37793  26462                        eehzjpxnjw.png  2022-03-22  OPPO CPH1819
# 37794  26462                        cjukggkdgy.png  2022-03-22  OPPO CPH1819
# 37795  26462                        wpnaiylzxi.png  2022-03-22    Vivo V2050
# 37796  26462                        pnqumypemv.png  2022-03-22    Vivo V2050
# ...      ...                                   ...         ...           ...
# 37945  68768  40A5A14E-33E1-4246-95A7-9757D184BC39  2022-03-24    iPhone11,8
# 37946  68768  B7F36631-D2C4-4EB5-852D-790BFAFDFD71  2022-03-24    iPhone11,8
# 37947  68768  899A7591-50C9-40BC-9746-A831A08DE980  2022-03-24    iPhone11,8
# 37948  68768  BF39F27C-1B43-4C97-A034-D7A579BED2B6  2022-03-24    iPhone11,8
# 37952  68768  D8A3A9EA-929E-4CEB-BFDF-C9BE093EA663  2022-03-24    iPhone11,8
#
#         site      time            urine  ov  PartitionKey    hcode  ...  \
# 37792  11069  10-08-34  ปกติ (เหลืองใส)   4         10961  11069.0  ...
# 37793  11069  10-06-17             ขุ่น   1         10962  11069.0  ...
# 37794  11069  09-33-02  ใส่เป็นน้ำเปล่า   0         10963  11069.0  ...
# 37795  11069  09-31-42  ปกติ (เหลืองใส)   0         10964  11069.0  ...
# 37796  11069  09-49-16  ปกติ (เหลืองใส)   3         10965  11069.0  ...
# ...      ...       ...              ...  ..           ...      ...  ...
# 37945  11088  10-31-17  ปกติ (เหลืองใส)   1         88432  11088.0  ...
# 37946  11088  10-30-22  ปกติ (เหลืองใส)   2         89170  11088.0  ...
# 37947  11088  10-29-37  ปกติ (เหลืองใส)   0         90470  11088.0  ...
# 37948  11088  10-24-40  ปกติ (เหลืองใส)   1         91123  11088.0  ...
# 37952  11088  10-25-32  ปกติ (เหลืองใส)   1         99444  11088.0  ...
#
#       amphurcode    amphur tamboncode        tambon code4           name5  \
# 37792       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0  โรงพยาบาลชุมชน
# 37793       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0  โรงพยาบาลชุมชน
# 37794       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0  โรงพยาบาลชุมชน
# 37795       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0  โรงพยาบาลชุมชน
# 37796       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0  โรงพยาบาลชุมชน
# ...          ...       ...        ...           ...   ...             ...
# 37945       14.0  ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0  โรงพยาบาลชุมชน
# 37946       14.0  ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0  โรงพยาบาลชุมชน
# 37947       14.0  ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0  โรงพยาบาลชุมชน
# 37948       14.0  ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0  โรงพยาบาลชุมชน
# 37952       14.0  ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0  โรงพยาบาลชุมชน
#
#       code9                  name10 short_thai  short_english
# 37792  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37793  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37794  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37795  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37796  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# ...     ...                     ...        ...            ...
# 37945  21.0   2.1 ทุติยภูมิระดับต้น         กส            KSN
# 37946  21.0   2.1 ทุติยภูมิระดับต้น         กส            KSN
# 37947  21.0   2.1 ทุติยภูมิระดับต้น         กส            KSN
# 37948  21.0   2.1 ทุติยภูมิระดับต้น         กส            KSN
# 37952  21.0   2.1 ทุติยภูมิระดับต้น         กส            KSN
#
# [72 rows x 25 columns]

# %%
merged_drop.isnull().any()
# Out:
# user             False
# RowKey           False
# date             False
# phone            False
# site             False
# time             False
# urine            False
# ov               False
# PartitionKey     False
# hcode            False
# name             False
# zone_code        False
# zone_name        False
# provincecode     False
# province         False
# amphurcode       False
# amphur           False
# tamboncode       False
# tambon           False
# code4            False
# name5            False
# code9            False
# name10           False
# short_thai       False
# short_english    False
# dtype: bool

# %% [markdown]
# ## จำนวนการตรวจในแต่ละพื้นที่

# %%
Province = merged_drop.groupby('province').count()
Province
# Out:
#            user  RowKey  date  phone  site  time  urine  ov  PartitionKey  \
# province
# กาฬสินธุ์     8       8     8      8     8     8      8   8             8
# นครพนม       16      16    16     16    16    16     16  16            16
# ร้อยเอ็ด     47      47    47     47    47    47     47  47            47
# อุตรดิตถ์     1       1     1      1     1     1      1   1             1
#
#            hcode  ...  amphurcode  amphur  tamboncode  tambon  code4  name5  \
# province          ...
# กาฬสินธุ์      8  ...           8       8           8       8      8      8
# นครพนม        16  ...          16      16          16      16     16     16
# ร้อยเอ็ด      47  ...          47      47          47      47     47     47
# อุตรดิตถ์      1  ...           1       1           1       1      1      1
#
#            code9  name10  short_thai  short_english
# province
# กาฬสินธุ์      8       8           8              8
# นครพนม        16      16          16             16
# ร้อยเอ็ด      47      47          47             47
# อุตรดิตถ์      1       1           1              1
#
# [4 rows x 24 columns]

# %%
Province_new = Province.iloc[:,:1]
Province_new
# Out:
#            user
# province
# กาฬสินธุ์     8
# นครพนม       16
# ร้อยเอ็ด     47
# อุตรดิตถ์     1

# %%
P_noindex = Province_new.reset_index()
P_noindex
# Out:
#     province  user
# 0  กาฬสินธุ์     8
# 1     นครพนม    16
# 2   ร้อยเอ็ด    47
# 3  อุตรดิตถ์     1

# %%
pv = {'user':'จำนวนการตรวจในแต่ละพื้นที่'}
# call rename () method
P_noindex.rename(columns=pv,
          inplace=True)
P_noindex
# Out:
#     province  จำนวนการตรวจในแต่ละพื้นที่
# 0  กาฬสินธุ์                           8
# 1     นครพนม                          16
# 2   ร้อยเอ็ด                          47
# 3  อุตรดิตถ์                           1

# %% [markdown]
# ## จำนวนที่พบโรค

# %% [markdown]
# ### ระดับ 0

# %%
ov_0 = merged_drop[merged_drop['ov']== 0]
ov_0
# Out:
#         user                                RowKey        date  \
# 37794  26462                        cjukggkdgy.png  2022-03-22
# 37795  26462                        wpnaiylzxi.png  2022-03-22
# 37797  26462                        rkkutomafv.png  2022-03-22
# 37798  26462                        emcshsfjwi.png  2022-03-22
# 37802  26462                        lybdixwhaq.png  2022-03-22
# 37803  26462                        alevoqyzru.png  2022-03-22
# 37804  26462                        gukjamcmkc.png  2022-03-22
# 37805  26462                        vdnnojfhka.png  2022-03-22
# 37806  26462                        byyhydmqlz.png  2022-03-21
# 37809  26462                        vmenrqvavo.png  2022-03-21
# 37811  26462                        fezuexxmnv.png  2022-03-21
# 37813  26462  CF0A47B9-752D-4FC9-A96F-DDC08AAA2247  2022-03-21
# 37815  26462                        lyqpzibhsh.png  2022-03-21
# 37817  26462                        zjcmumrvpp.png  2022-03-22
# 37819  26462                        uvjpltipuw.png  2022-03-22
# 37820  26462                        jvbisyqqsu.png  2022-03-21
# 37821  26462                        vzenektyaa.png  2022-03-22
# 37822  26462                        edquaqyuia.png  2022-03-21
# 37823  26462  9B2969BF-F999-43AD-A082-AFFF7615AEC7  2022-03-21
# 37824  26462                        zkddsdiwzw.png  2022-03-21
# 37825  26462                        jajxlriszt.png  2022-03-22
# 37826  26462                        vqkgeemfhy.png  2022-03-22
# 37827  26462                        vcubzchjxv.png  2022-03-21
# 37829  26462  AD576EF3-4128-4DCD-93CB-63494C69F326  2022-03-22
# 37830  26462                        qukpkgoxfp.png  2022-03-21
# 37832  26462                        dghzdcrtay.png  2022-03-21
# 37837  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  2022-03-21
# 37854  80880  4648F57F-E9AD-468B-9E56-E2844626C772  2022-03-30
# 37881  11177                        frvgwohzcx.png  2022-02-27
# 37940  68768  5CF89F00-A898-4BB6-B42A-06CC7EBD3114  2022-03-24
# 37943  68768  C38927EF-F10C-4A5D-A7CA-E22DC7A70BAD  2022-03-24
# 37944  68768  7B050412-1100-4397-9688-175B92B851C9  2022-03-24
# 37947  68768  899A7591-50C9-40BC-9746-A831A08DE980  2022-03-24
#
#                   phone   site      time                             urine  \
# 37794      OPPO CPH1819  11069  09-33-02                   ใส่เป็นน้ำเปล่า
# 37795        Vivo V2050  11069  09-31-42                   ปกติ (เหลืองใส)
# 37797        Vivo V2050  11069  09-12-19                   ใส่เป็นน้ำเปล่า
# 37798        Vivo V2050  11069  09-32-32                              ขุ่น
# 37802        Vivo V2050  11069  11-40-37                   ปกติ (เหลืองใส)
# 37803      OPPO CPH1819  11069  10-59-51                   ปกติ (เหลืองใส)
# 37804      OPPO CPH1819  11069  10-57-27                   ปกติ (เหลืองใส)
# 37805        Vivo V2050  11069  10-56-14                   ปกติ (เหลืองใส)
# 37806         Vivo 1920  11069  13-57-55                   ปกติ (เหลืองใส)
# 37809         Vivo 1920  11069  10-27-48                   ใส่เป็นน้ำเปล่า
# 37811        Vivo V2050  11069  09-48-21                   ปกติ (เหลืองใส)
# 37813        iPhone13,4  11069  09-47-58                   ปกติ (เหลืองใส)
# 37815         Vivo 1920  11069  11-52-33                   ปกติ (เหลืองใส)
# 37817        Vivo V2050  11069  09-11-13  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า
# 37819         Vivo 1920  11069  13-42-14                   ปกติ (เหลืองใส)
# 37820        Vivo V2050  11069  10-53-58                   ปกติ (เหลืองใส)
# 37821         Vivo 1920  11069  13-41-49                   ปกติ (เหลืองใส)
# 37822         Vivo 1920  11069  10-55-13                   ปกติ (เหลืองใส)
# 37823        iPhone13,4  11069  10-56-13                   ปกติ (เหลืองใส)
# 37824         Vivo 1920  11069  14-17-08                   ปกติ (เหลืองใส)
# 37825         Vivo 1920  11069  14-01-37                   ปกติ (เหลืองใส)
# 37826         Vivo 1920  11069  14-02-37                           มีตะกอน
# 37827         Vivo 1920  11069  14-18-41                   ปกติ (เหลืองใส)
# 37829        iPhone13,4  11069  13-39-56                   ปกติ (เหลืองใส)
# 37830         Vivo 1920  11069  11-54-17                   ปกติ (เหลืองใส)
# 37832         Vivo 1920  11069  11-51-32                           มีตะกอน
# 37837        iPhone13,4  11069  14-17-46                   ปกติ (เหลืองใส)
# 37854        iPhone12,1  11163  09-17-58                   ปกติ (เหลืองใส)
# 37881  Samsung SM-G998B  11111  12-47-12                   ปกติ (เหลืองใส)
# 37940        iPhone11,8  11088  10-30-56                   ปกติ (เหลืองใส)
# 37943        iPhone11,8  11088  10-31-40                   ปกติ (เหลืองใส)
# 37944        iPhone11,8  11088  10-26-19                   ปกติ (เหลืองใส)
# 37947        iPhone11,8  11088  10-29-37                   ปกติ (เหลืองใส)
#
#        ov  PartitionKey    hcode  ... amphurcode    amphur tamboncode  \
# 37794   0         10963  11069.0  ...       10.0   เสลภูมิ       17.0
# 37795   0         10964  11069.0  ...       10.0   เสลภูมิ       17.0
# 37797   0         10966  11069.0  ...       10.0   เสลภูมิ       17.0
# 37798   0         10967  11069.0  ...       10.0   เสลภูมิ       17.0
# 37802   0         10971  11069.0  ...       10.0   เสลภูมิ       17.0
# 37803   0         10972  11069.0  ...       10.0   เสลภูมิ       17.0
# 37804   0         10972  11069.0  ...       10.0   เสลภูมิ       17.0
# 37805   0         10973  11069.0  ...       10.0   เสลภูมิ       17.0
# 37806   0         10974  11069.0  ...       10.0   เสลภูมิ       17.0
# 37809   0         10977  11069.0  ...       10.0   เสลภูมิ       17.0
# 37811   0         10979  11069.0  ...       10.0   เสลภูมิ       17.0
# 37813   0         10981  11069.0  ...       10.0   เสลภูมิ       17.0
# 37815   0         10983  11069.0  ...       10.0   เสลภูมิ       17.0
# 37817   0         10985  11069.0  ...       10.0   เสลภูมิ       17.0
# 37819   0         10987  11069.0  ...       10.0   เสลภูมิ       17.0
# 37820   0         10988  11069.0  ...       10.0   เสลภูมิ       17.0
# 37821   0         10989  11069.0  ...       10.0   เสลภูมิ       17.0
# 37822   0         10990  11069.0  ...       10.0   เสลภูมิ       17.0
# 37823   0         10991  11069.0  ...       10.0   เสลภูมิ       17.0
# 37824   0         10992  11069.0  ...       10.0   เสลภูมิ       17.0
# 37825   0         10993  11069.0  ...       10.0   เสลภูมิ       17.0
# 37826   0         10993  11069.0  ...       10.0   เสลภูมิ       17.0
# 37827   0         10995  11069.0  ...       10.0   เสลภูมิ       17.0
# 37829   0         10997  11069.0  ...       10.0   เสลภูมิ       17.0
# 37830   0         10998  11069.0  ...       10.0   เสลภูมิ       17.0
# 37832   0         11000  11069.0  ...       10.0   เสลภูมิ       17.0
# 37837   0         11007  11069.0  ...       10.0   เสลภูมิ       17.0
# 37854   0         11163  11163.0  ...        7.0     พิชัย        1.0
# 37881   0         44147  11111.0  ...        9.0    นาหว้า        1.0
# 37940   0         72093  11088.0  ...       14.0  ห้วยผึ้ง        3.0
# 37943   0         87606  11088.0  ...       14.0  ห้วยผึ้ง        3.0
# 37944   0         87720  11088.0  ...       14.0  ห้วยผึ้ง        3.0
# 37947   0         90470  11088.0  ...       14.0  ห้วยผึ้ง        3.0
#
#              tambon code4           name5 code9                  name10  \
# 37794     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37795     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37797     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37798     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37802     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37803     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37804     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37805     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37806     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37809     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37811     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37813     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37815     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37817     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37819     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37820     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37821     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37822     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37823     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37824     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37825     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37826     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37827     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37829     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37830     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37832     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37837     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37854       ในเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37881        นาหว้า   7.0  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น
# 37940  นิคมห้วยผึ้ง   7.0  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น
# 37943  นิคมห้วยผึ้ง   7.0  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น
# 37944  นิคมห้วยผึ้ง   7.0  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น
# 37947  นิคมห้วยผึ้ง   7.0  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น
#
#       short_thai  short_english
# 37794         รอ            RET
# 37795         รอ            RET
# 37797         รอ            RET
# 37798         รอ            RET
# 37802         รอ            RET
# 37803         รอ            RET
# 37804         รอ            RET
# 37805         รอ            RET
# 37806         รอ            RET
# 37809         รอ            RET
# 37811         รอ            RET
# 37813         รอ            RET
# 37815         รอ            RET
# 37817         รอ            RET
# 37819         รอ            RET
# 37820         รอ            RET
# 37821         รอ            RET
# 37822         รอ            RET
# 37823         รอ            RET
# 37824         รอ            RET
# 37825         รอ            RET
# 37826         รอ            RET
# 37827         รอ            RET
# 37829         รอ            RET
# 37830         รอ            RET
# 37832         รอ            RET
# 37837         รอ            RET
# 37854         อต            UTT
# 37881         นพ            NPM
# 37940         กส            KSN
# 37943         กส            KSN
# 37944         กส            KSN
# 37947         กส            KSN
#
# [33 rows x 25 columns]

# %%
ov_0 = ov_0.groupby('province').count()
ov_0
# Out:
#            user  RowKey  date  phone  site  time  urine  ov  PartitionKey  \
# province
# กาฬสินธุ์     4       4     4      4     4     4      4   4             4
# นครพนม        1       1     1      1     1     1      1   1             1
# ร้อยเอ็ด     27      27    27     27    27    27     27  27            27
# อุตรดิตถ์     1       1     1      1     1     1      1   1             1
#
#            hcode  ...  amphurcode  amphur  tamboncode  tambon  code4  name5  \
# province          ...
# กาฬสินธุ์      4  ...           4       4           4       4      4      4
# นครพนม         1  ...           1       1           1       1      1      1
# ร้อยเอ็ด      27  ...          27      27          27      27     27     27
# อุตรดิตถ์      1  ...           1       1           1       1      1      1
#
#            code9  name10  short_thai  short_english
# province
# กาฬสินธุ์      4       4           4              4
# นครพนม         1       1           1              1
# ร้อยเอ็ด      27      27          27             27
# อุตรดิตถ์      1       1           1              1
#
# [4 rows x 24 columns]

# %%
ov_0_new = ov_0.iloc[:,:1]
ov_0_new
# Out:
#            user
# province
# กาฬสินธุ์     4
# นครพนม        1
# ร้อยเอ็ด     27
# อุตรดิตถ์     1

# %%
ov_0_noindex = ov_0_new.reset_index()
ov_0_noindex
# Out:
#     province  user
# 0  กาฬสินธุ์     4
# 1     นครพนม     1
# 2   ร้อยเอ็ด    27
# 3  อุตรดิตถ์     1

# %%
o0 = {'user':'จำนวนที่พบโรค ระดับ 0'}
# call rename () method
ov_0_noindex.rename(columns=o0,
          inplace=True)
ov_0_noindex
# Out:
#     province  จำนวนที่พบโรค ระดับ 0
# 0  กาฬสินธุ์                      4
# 1     นครพนม                      1
# 2   ร้อยเอ็ด                     27
# 3  อุตรดิตถ์                      1

# %% [markdown]
# ### ระดับ 1

# %%
ov_1 = merged_drop[merged_drop['ov']== 1]
ov_1
# Out:
#         user                                RowKey        date         phone  \
# 37793  26462                        eehzjpxnjw.png  2022-03-22  OPPO CPH1819
# 37801  26462                        bfceftfurl.png  2022-03-22  OPPO CPH1819
# 37808  26462                        sxzmzrsmyf.png  2022-03-21     Vivo 1920
# 37810  26462  9438FD60-2EED-4FC1-BDE0-3AE05A3317BF  2022-03-21    iPhone13,4
# 37812  26462                        fvygcngevl.png  2022-03-21     Vivo 1920
# 37816  26462                        jdmhexxudc.png  2022-03-21     Vivo 1920
# 37831  26462  10CBBBC5-3BAC-4927-93B1-24918834B166  2022-03-22    iPhone13,4
# 37834  26462                        ieotqfnqcq.png  2022-03-22     Vivo 1920
# 37838  26462                        vdxxgljykj.png  2022-03-21    Vivo V2050
# 37840  11111  2B2C2FAA-3007-46DF-950D-443F3AEB1C98  2022-02-27    iPhone13,4
# 37847  11111  C4DAA911-AC32-413D-99DC-880D598208B4  2022-03-07    iPhone13,4
# 37850  11111  EF66DB5E-518F-43A4-A071-4548470CDC2C  2022-03-10    iPhone13,4
# 37945  68768  40A5A14E-33E1-4246-95A7-9757D184BC39  2022-03-24    iPhone11,8
# 37948  68768  BF39F27C-1B43-4C97-A034-D7A579BED2B6  2022-03-24    iPhone11,8
# 37952  68768  D8A3A9EA-929E-4CEB-BFDF-C9BE093EA663  2022-03-24    iPhone11,8
#
#         site      time                             urine  ov  PartitionKey  \
# 37793  11069  10-06-17                              ขุ่น   1         10962
# 37801  11069  10-08-24                   ปกติ (เหลืองใส)   1         10970
# 37808  11069  10-08-48                   ปกติ (เหลืองใส)   1         10976
# 37810  11069  09-49-51                   ปกติ (เหลืองใส)   1         10978
# 37812  11069  10-29-01                   ปกติ (เหลืองใส)   1         10980
# 37816  11069  10-54-05  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1         10984
# 37831  11069  14-01-18                   ปกติ (เหลืองใส)   1         10999
# 37834  11069  14-03-12                   ปกติ (เหลืองใส)   1         11003
# 37838  11069  10-54-49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1         11008
# 37840  11111  19-04-40             สีเหลืองส้ม (ผิดปกติ)   1         11111
# 37847  11111  11-45-19                           มีตะกอน   1         11111
# 37850  11111  19-22-23                           มีตะกอน   1         11111
# 37945  11088  10-31-17                   ปกติ (เหลืองใส)   1         88432
# 37948  11088  10-24-40                   ปกติ (เหลืองใส)   1         91123
# 37952  11088  10-25-32                   ปกติ (เหลืองใส)   1         99444
#
#          hcode  ... amphurcode    amphur tamboncode        tambon code4  \
# 37793  11069.0  ...       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0
# 37801  11069.0  ...       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0
# 37808  11069.0  ...       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0
# 37810  11069.0  ...       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0
# 37812  11069.0  ...       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0
# 37816  11069.0  ...       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0
# 37831  11069.0  ...       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0
# 37834  11069.0  ...       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0
# 37838  11069.0  ...       10.0   เสลภูมิ       17.0     ขวัญเมือง   7.0
# 37840  11111.0  ...        9.0    นาหว้า        1.0        นาหว้า   7.0
# 37847  11111.0  ...        9.0    นาหว้า        1.0        นาหว้า   7.0
# 37850  11111.0  ...        9.0    นาหว้า        1.0        นาหว้า   7.0
# 37945  11088.0  ...       14.0  ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0
# 37948  11088.0  ...       14.0  ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0
# 37952  11088.0  ...       14.0  ห้วยผึ้ง        3.0  นิคมห้วยผึ้ง   7.0
#
#                 name5 code9                  name10 short_thai  short_english
# 37793  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37801  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37808  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37810  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37812  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37816  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37831  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37834  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37838  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37840  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น         นพ            NPM
# 37847  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น         นพ            NPM
# 37850  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น         นพ            NPM
# 37945  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น         กส            KSN
# 37948  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น         กส            KSN
# 37952  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น         กส            KSN
#
# [15 rows x 25 columns]

# %%
ov_1 = ov_1.groupby('province').count()
ov_1
# Out:
#            user  RowKey  date  phone  site  time  urine  ov  PartitionKey  \
# province
# กาฬสินธุ์     3       3     3      3     3     3      3   3             3
# นครพนม        3       3     3      3     3     3      3   3             3
# ร้อยเอ็ด      9       9     9      9     9     9      9   9             9
#
#            hcode  ...  amphurcode  amphur  tamboncode  tambon  code4  name5  \
# province          ...
# กาฬสินธุ์      3  ...           3       3           3       3      3      3
# นครพนม         3  ...           3       3           3       3      3      3
# ร้อยเอ็ด       9  ...           9       9           9       9      9      9
#
#            code9  name10  short_thai  short_english
# province
# กาฬสินธุ์      3       3           3              3
# นครพนม         3       3           3              3
# ร้อยเอ็ด       9       9           9              9
#
# [3 rows x 24 columns]

# %%
ov_1_new = ov_1.iloc[:,:1]
ov_1_new
# Out:
#            user
# province
# กาฬสินธุ์     3
# นครพนม        3
# ร้อยเอ็ด      9

# %%
ov_1_noindex = ov_1_new.reset_index()
ov_1_noindex
# Out:
#     province  user
# 0  กาฬสินธุ์     3
# 1     นครพนม     3
# 2   ร้อยเอ็ด     9

# %%
o1 = {'user':'จำนวนที่พบโรค ระดับ 1'}
# call rename () method
ov_1_noindex.rename(columns=o1,
          inplace=True)
ov_1_noindex
# Out:
#     province  จำนวนที่พบโรค ระดับ 1
# 0  กาฬสินธุ์                      3
# 1     นครพนม                      3
# 2   ร้อยเอ็ด                      9

# %% [markdown]
# ### ระดับ 2

# %%
ov_2 = merged_drop[merged_drop['ov']== 2]
ov_2
# Out:
#         user                                RowKey        date  \
# 37799  26462                        wgxurysjec.png  2022-03-22
# 37800  26462                        vanquopswi.png  2022-03-22
# 37828  26462  3340619E-D3F4-4090-B3D0-B6CDF1D9F370  2022-03-21
# 37835  26462                        cywpeqziic.png  2022-03-21
# 37836  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  2022-03-22
# 37852  11111  FF5EA455-7093-4F87-B00C-CD84B563F7DE  2022-02-27
# 37872  11111                        willjicqkd.png  2022-03-07
# 37946  68768  B7F36631-D2C4-4EB5-852D-790BFAFDFD71  2022-03-24
#
#                   phone   site      time                  urine  ov  \
# 37799      OPPO CPH1819  11069  09-13-07                   ขุ่น   2
# 37800        Vivo V2050  11069  09-48-29        ปกติ (เหลืองใส)   2
# 37828        iPhone13,4  11069  13-58-41                มีตะกอน   2
# 37835         Vivo 1920  11069  13-59-04        ปกติ (เหลืองใส)   2
# 37836        iPhone13,4  11069  13-41-47        ปกติ (เหลืองใส)   2
# 37852        iPhone13,4  11111  19-23-25  สีเหลืองส้ม (ผิดปกติ)   2
# 37872  Samsung SM-G998B  11111  11-58-03      สีฟ้า หรือน้ำเงิน   2
# 37946        iPhone11,8  11088  10-30-22        ปกติ (เหลืองใส)   2
#
#        PartitionKey    hcode  ... amphurcode    amphur tamboncode  \
# 37799         10968  11069.0  ...       10.0   เสลภูมิ       17.0
# 37800         10969  11069.0  ...       10.0   เสลภูมิ       17.0
# 37828         10996  11069.0  ...       10.0   เสลภูมิ       17.0
# 37835         11005  11069.0  ...       10.0   เสลภูมิ       17.0
# 37836         11006  11069.0  ...       10.0   เสลภูมิ       17.0
# 37852         11111  11111.0  ...        9.0    นาหว้า        1.0
# 37872         22222  11111.0  ...        9.0    นาหว้า        1.0
# 37946         89170  11088.0  ...       14.0  ห้วยผึ้ง        3.0
#
#              tambon code4           name5 code9                  name10  \
# 37799     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37800     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37828     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37835     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37836     ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37852        นาหว้า   7.0  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น
# 37872        นาหว้า   7.0  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น
# 37946  นิคมห้วยผึ้ง   7.0  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น
#
#       short_thai  short_english
# 37799         รอ            RET
# 37800         รอ            RET
# 37828         รอ            RET
# 37835         รอ            RET
# 37836         รอ            RET
# 37852         นพ            NPM
# 37872         นพ            NPM
# 37946         กส            KSN
#
# [8 rows x 25 columns]

# %%
ov_2 = ov_2.groupby('province').count()
ov_2
# Out:
#            user  RowKey  date  phone  site  time  urine  ov  PartitionKey  \
# province
# กาฬสินธุ์     1       1     1      1     1     1      1   1             1
# นครพนม        2       2     2      2     2     2      2   2             2
# ร้อยเอ็ด      5       5     5      5     5     5      5   5             5
#
#            hcode  ...  amphurcode  amphur  tamboncode  tambon  code4  name5  \
# province          ...
# กาฬสินธุ์      1  ...           1       1           1       1      1      1
# นครพนม         2  ...           2       2           2       2      2      2
# ร้อยเอ็ด       5  ...           5       5           5       5      5      5
#
#            code9  name10  short_thai  short_english
# province
# กาฬสินธุ์      1       1           1              1
# นครพนม         2       2           2              2
# ร้อยเอ็ด       5       5           5              5
#
# [3 rows x 24 columns]

# %%
ov_2_new = ov_2.iloc[:,:1]
ov_2_new
# Out:
#            user
# province
# กาฬสินธุ์     1
# นครพนม        2
# ร้อยเอ็ด      5

# %%
ov_2_noindex = ov_2_new.reset_index()
ov_2_noindex
# Out:
#     province  user
# 0  กาฬสินธุ์     1
# 1     นครพนม     2
# 2   ร้อยเอ็ด     5

# %%
o2 = {'user':'จำนวนที่พบโรค ระดับ 2'}
# call rename () method
ov_2_noindex.rename(columns=o2,
          inplace=True)
ov_2_noindex
# Out:
#     province  จำนวนที่พบโรค ระดับ 2
# 0  กาฬสินธุ์                      1
# 1     นครพนม                      2
# 2   ร้อยเอ็ด                      5

# %% [markdown]
# ### ระดับ 3

# %%
ov_3 = merged_drop[merged_drop['ov']== 3]
ov_3
# Out:
#         user                                RowKey        date  \
# 37796  26462                        pnqumypemv.png  2022-03-22
# 37814  10982  D713CB5A-AE59-4FA7-9387-39C0B766120A  2022-03-21
# 37839  11111  1CE25D88-8ED6-46C8-8EBD-DE2D5F89EB7F  2022-02-27
# 37844  11111  97F01805-4C0F-4478-9D0F-FF6A5A0B45B5  2022-02-27
# 37845  11111  A6D69321-ED1F-457D-B615-6F4C1F600C01  2022-02-27
# 37848  11111  D8D8751F-7259-429A-98AE-431346C74317  2022-02-27
# 37849  11111  E2371023-E100-4255-BB0A-9314D26674FC  2022-02-27
# 37851  11111  FA4AB630-0269-4445-8439-D22139951BC1  2022-03-07
# 37853  11111                        mnoycjbkar.png  2022-03-07
#
#                   phone   site      time            urine  ov  PartitionKey  \
# 37796        Vivo V2050  11069  09-49-16  ปกติ (เหลืองใส)   3         10965
# 37814        iPhone13,4  11069  10-30-00  ปกติ (เหลืองใส)   3         10982
# 37839        iPhone13,4  11111  19-21-47   มีเม็ดเลือดแดง   3         11111
# 37844        iPhone13,4  11111  19-22-48          มีตะกอน   3         11111
# 37845        iPhone13,4  11111  18-50-25   มีเม็ดเลือดแดง   3         11111
# 37848        iPhone13,4  11111  19-14-58   มีเม็ดเลือดแดง   3         11111
# 37849        iPhone13,4  11111  19-19-43   มีเม็ดเลือดแดง   3         11111
# 37851        iPhone13,4  11111  11-49-54   มีเม็ดเลือดแดง   3         11111
# 37853  Samsung SM-G998B  11111  11-57-35  ปกติ (เหลืองใส)   3         11111
#
#          hcode  ... amphurcode   amphur tamboncode     tambon code4  \
# 37796  11069.0  ...       10.0  เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37814  11069.0  ...       10.0  เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37839  11111.0  ...        9.0   นาหว้า        1.0     นาหว้า   7.0
# 37844  11111.0  ...        9.0   นาหว้า        1.0     นาหว้า   7.0
# 37845  11111.0  ...        9.0   นาหว้า        1.0     นาหว้า   7.0
# 37848  11111.0  ...        9.0   นาหว้า        1.0     นาหว้า   7.0
# 37849  11111.0  ...        9.0   นาหว้า        1.0     นาหว้า   7.0
# 37851  11111.0  ...        9.0   นาหว้า        1.0     นาหว้า   7.0
# 37853  11111.0  ...        9.0   นาหว้า        1.0     นาหว้า   7.0
#
#                 name5 code9                  name10 short_thai  short_english
# 37796  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37814  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37839  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น         นพ            NPM
# 37844  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น         นพ            NPM
# 37845  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น         นพ            NPM
# 37848  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น         นพ            NPM
# 37849  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น         นพ            NPM
# 37851  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น         นพ            NPM
# 37853  โรงพยาบาลชุมชน  21.0   2.1 ทุติยภูมิระดับต้น         นพ            NPM
#
# [9 rows x 25 columns]

# %%
ov_3 = ov_3.groupby('province').count()
ov_3
# Out:
#           user  RowKey  date  phone  site  time  urine  ov  PartitionKey  \
# province
# นครพนม       7       7     7      7     7     7      7   7             7
# ร้อยเอ็ด     2       2     2      2     2     2      2   2             2
#
#           hcode  ...  amphurcode  amphur  tamboncode  tambon  code4  name5  \
# province         ...
# นครพนม        7  ...           7       7           7       7      7      7
# ร้อยเอ็ด      2  ...           2       2           2       2      2      2
#
#           code9  name10  short_thai  short_english
# province
# นครพนม        7       7           7              7
# ร้อยเอ็ด      2       2           2              2
#
# [2 rows x 24 columns]

# %%
ov_3_new = ov_3.iloc[:,:1]
ov_3_new
# Out:
#           user
# province
# นครพนม       7
# ร้อยเอ็ด     2

# %%
ov_3_noindex = ov_3_new.reset_index()
ov_3_noindex
# Out:
#    province  user
# 0    นครพนม     7
# 1  ร้อยเอ็ด     2

# %%
o3 = {'user':'จำนวนที่พบโรค ระดับ 3'}
# call rename () method
ov_3_noindex.rename(columns=o3,
          inplace=True)
ov_3_noindex
# Out:
#    province  จำนวนที่พบโรค ระดับ 3
# 0    นครพนม                      7
# 1  ร้อยเอ็ด                      2

# %% [markdown]
# ### ระดับ 4

# %%
ov_4 = merged_drop[merged_drop['ov']== 4]
ov_4
# Out:
#         user                                RowKey        date         phone  \
# 37792  26462  6C55B69E-8E4C-46B0-B0D7-4754A529EE3C  2022-03-21    iPhone13,4
# 37807  26462  5CB6F5EB-324D-448C-84AD-C9D48B23684E  2022-03-22    iPhone13,4
# 37818  26462                        iwwwnyrmtz.png  2022-03-22  OPPO CPH1819
# 37833  26462                        rryhjijyje.png  2022-03-21    Vivo V2050
# 37842  11111  6F95D193-3E3D-452D-99BD-705D0271030F  2022-02-27    iPhone13,4
# 37843  11111  7BB0E403-CEC8-4860-A4B9-C9487B18CDC5  2022-02-27    iPhone13,4
# 37846  11111  AD73A95C-3C91-42DA-85AC-00AE0524FAEE  2022-02-27    iPhone13,4
#
#         site      time            urine  ov  PartitionKey    hcode  ...  \
# 37792  11069  10-08-34  ปกติ (เหลืองใส)   4         10961  11069.0  ...
# 37807  11069  14-04-13  ปกติ (เหลืองใส)   4         10975  11069.0  ...
# 37818  11069  09-32-10  ปกติ (เหลืองใส)   4         10986  11069.0  ...
# 37833  11069  11-52-34   มีเม็ดเลือดแดง   4         11002  11069.0  ...
# 37842  11111  18-53-44   มีเม็ดเลือดแดง   4         11111  11111.0  ...
# 37843  11111  19-23-10   ใสเป็นน้ำเปล่า   4         11111  11111.0  ...
# 37846  11111  19-01-11   มีเม็ดเลือดแดง   4         11111  11111.0  ...
#
#       amphurcode   amphur tamboncode     tambon code4           name5 code9  \
# 37792       10.0  เสลภูมิ       17.0  ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0
# 37807       10.0  เสลภูมิ       17.0  ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0
# 37818       10.0  เสลภูมิ       17.0  ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0
# 37833       10.0  เสลภูมิ       17.0  ขวัญเมือง   7.0  โรงพยาบาลชุมชน  22.0
# 37842        9.0   นาหว้า        1.0     นาหว้า   7.0  โรงพยาบาลชุมชน  21.0
# 37843        9.0   นาหว้า        1.0     นาหว้า   7.0  โรงพยาบาลชุมชน  21.0
# 37846        9.0   นาหว้า        1.0     นาหว้า   7.0  โรงพยาบาลชุมชน  21.0
#
#                        name10 short_thai  short_english
# 37792  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37807  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37818  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37833  2.2 ทุติยภูมิระดับกลาง         รอ            RET
# 37842   2.1 ทุติยภูมิระดับต้น         นพ            NPM
# 37843   2.1 ทุติยภูมิระดับต้น         นพ            NPM
# 37846   2.1 ทุติยภูมิระดับต้น         นพ            NPM
#
# [7 rows x 25 columns]

# %%
ov_4 = ov_4.groupby('province').count()
ov_4_new = ov_4.iloc[:,:1]
ov_4_noindex = ov_4_new.reset_index()
ov_4_noindex
# Out:
#    province  user
# 0    นครพนม     3
# 1  ร้อยเอ็ด     4

# %%
o4 = {'user':'จำนวนที่พบโรค ระดับ 4'}
# call rename () method
ov_4_noindex.rename(columns=o4,
          inplace=True)
ov_4_noindex
# Out:
#    province  จำนวนที่พบโรค ระดับ 4
# 0    นครพนม                      3
# 1  ร้อยเอ็ด                      4

# %% [markdown]
# ### รวมตาราง 4 ตารางเข้าด้วยกัน

# %%
ov_merge = ov_0_noindex.merge(ov_1_noindex,how='left',left_on='province',right_on='province') 
ov_merge = ov_merge.merge(ov_2_noindex,how='left',left_on='province',right_on='province') 
ov_merge = ov_merge.merge(ov_3_noindex,how='left',left_on='province',right_on='province') 
ov_merge = ov_merge.merge(ov_4_noindex,how='left',left_on='province',right_on='province') 
ov_merge
# Out:
#     province  จำนวนที่พบโรค ระดับ 0  จำนวนที่พบโรค ระดับ 1  \
# 0  กาฬสินธุ์                      4                    3.0
# 1     นครพนม                      1                    3.0
# 2   ร้อยเอ็ด                     27                    9.0
# 3  อุตรดิตถ์                      1                    NaN
#
#    จำนวนที่พบโรค ระดับ 2  จำนวนที่พบโรค ระดับ 3  จำนวนที่พบโรค ระดับ 4
# 0                    1.0                    NaN                    NaN
# 1                    2.0                    7.0                    3.0
# 2                    5.0                    2.0                    4.0
# 3                    NaN                    NaN                    NaN

# %%
# เเทนค่า NaN ด้วย 0
ov_merge['จำนวนที่พบโรค ระดับ 1'] = ov_merge['จำนวนที่พบโรค ระดับ 1'].fillna(0) 
ov_merge['จำนวนที่พบโรค ระดับ 2'] = ov_merge['จำนวนที่พบโรค ระดับ 2'].fillna(0) 
ov_merge['จำนวนที่พบโรค ระดับ 3'] = ov_merge['จำนวนที่พบโรค ระดับ 3'].fillna(0) 
ov_merge['จำนวนที่พบโรค ระดับ 4'] = ov_merge['จำนวนที่พบโรค ระดับ 4'].fillna(0)

# %%
ov_merge.isnull().any()
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# province                 False
# จำนวนที่พบโรค ระดับ 0    False
# จำนวนที่พบโรค ระดับ 1    False
# จำนวนที่พบโรค ระดับ 2    False
# จำนวนที่พบโรค ระดับ 3    False
# จำนวนที่พบโรค ระดับ 4    False
# dtype: bool

# %% [markdown]
# # Dashboard 1
#
# รวมตารางระหว่างจำนวนการตรวจในแต่ละพื้นที่ กับ จำนวนที่พบโรค

# %%
data1 = P_noindex.merge(ov_merge,how='left',left_on='province',right_on='province') 
data1
# Out:
#     province  จำนวนการตรวจในแต่ละพื้นที่  จำนวนที่พบโรค ระดับ 0  \
# 0  กาฬสินธุ์                           8                      4
# 1     นครพนม                          16                      1
# 2   ร้อยเอ็ด                          47                     27
# 3  อุตรดิตถ์                           1                      1
#
#    จำนวนที่พบโรค ระดับ 1  จำนวนที่พบโรค ระดับ 2  จำนวนที่พบโรค ระดับ 3  \
# 0                    3.0                    1.0                    0.0
# 1                    3.0                    2.0                    7.0
# 2                    9.0                    5.0                    2.0
# 3                    0.0                    0.0                    0.0
#
#    จำนวนที่พบโรค ระดับ 4
# 0                    0.0
# 1                    3.0
# 2                    4.0
# 3                    0.0

# %%
# เเทนค่า NaN ด้วย 0
data1['จำนวนที่พบโรค ระดับ 0'] = data1['จำนวนที่พบโรค ระดับ 0'].fillna(0) 
data1['จำนวนที่พบโรค ระดับ 1'] = data1['จำนวนที่พบโรค ระดับ 1'].fillna(0) 
data1['จำนวนที่พบโรค ระดับ 2'] = data1['จำนวนที่พบโรค ระดับ 2'].fillna(0) 
data1['จำนวนที่พบโรค ระดับ 3'] = data1['จำนวนที่พบโรค ระดับ 3'].fillna(0) 
data1['จำนวนที่พบโรค ระดับ 4'] = data1['จำนวนที่พบโรค ระดับ 4'].fillna(0)

# %%
data1.isnull().any()
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# province                      False
# จำนวนการตรวจในแต่ละพื้นที่    False
# จำนวนที่พบโรค ระดับ 0         False
# จำนวนที่พบโรค ระดับ 1         False
# จำนวนที่พบโรค ระดับ 2         False
# จำนวนที่พบโรค ระดับ 3         False
# จำนวนที่พบโรค ระดับ 4         False
# dtype: bool

# %%
data1 # แสดงข้อมูลหลังเเทน NaN ด้วย 0
# Out:
#     province  จำนวนการตรวจในแต่ละพื้นที่  จำนวนที่พบโรค ระดับ 0  \
# 0  กาฬสินธุ์                           8                      4
# 1     นครพนม                          16                      1
# 2   ร้อยเอ็ด                          47                     27
# 3  อุตรดิตถ์                           1                      1
#
#    จำนวนที่พบโรค ระดับ 1  จำนวนที่พบโรค ระดับ 2  จำนวนที่พบโรค ระดับ 3  \
# 0                    3.0                    1.0                    0.0
# 1                    3.0                    2.0                    7.0
# 2                    9.0                    5.0                    2.0
# 3                    0.0                    0.0                    0.0
#
#    จำนวนที่พบโรค ระดับ 4
# 0                    0.0
# 1                    3.0
# 2                    4.0
# 3                    0.0

# %%
data1.to_csv(os.path.join(path,'data1.csv')) # save เข้า drive เพื่อนำไปทำ dashboard

# %% [markdown]
# # Dashboard 2
#
# ข้อมูลที่เหลือ
#
# * ช่วงเวลาที่ตรวจ (date ในไฟล์ alldb.csv)
# * อื่นๆที่นักศึกษาเห็นว่าเป็นประโยชน์ (phone (ชนิดโทรศัพท์ที่ใช้บันทึก), title (คำนำหน้าชื่อ), age (อายุ))

# %%
merged_use = merged_drop[['user','date','phone','site','time','urine','ov','PartitionKey','hcode','name','province']] 
merged_use
# Out:
#         user        date         phone   site      time            urine  ov  \
# 37792  26462  2022-03-21    iPhone13,4  11069  10-08-34  ปกติ (เหลืองใส)   4
# 37793  26462  2022-03-22  OPPO CPH1819  11069  10-06-17             ขุ่น   1
# 37794  26462  2022-03-22  OPPO CPH1819  11069  09-33-02  ใส่เป็นน้ำเปล่า   0
# 37795  26462  2022-03-22    Vivo V2050  11069  09-31-42  ปกติ (เหลืองใส)   0
# 37796  26462  2022-03-22    Vivo V2050  11069  09-49-16  ปกติ (เหลืองใส)   3
# ...      ...         ...           ...    ...       ...              ...  ..
# 37945  68768  2022-03-24    iPhone11,8  11088  10-31-17  ปกติ (เหลืองใส)   1
# 37946  68768  2022-03-24    iPhone11,8  11088  10-30-22  ปกติ (เหลืองใส)   2
# 37947  68768  2022-03-24    iPhone11,8  11088  10-29-37  ปกติ (เหลืองใส)   0
# 37948  68768  2022-03-24    iPhone11,8  11088  10-24-40  ปกติ (เหลืองใส)   1
# 37952  68768  2022-03-24    iPhone11,8  11088  10-25-32  ปกติ (เหลืองใส)   1
#
#        PartitionKey    hcode               name   province
# 37792         10961  11069.0   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด
# 37793         10962  11069.0   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด
# 37794         10963  11069.0   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด
# 37795         10964  11069.0   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด
# 37796         10965  11069.0   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด
# ...             ...      ...                ...        ...
# 37945         88432  11088.0  โรงพยาบาลห้วยผึ้ง  กาฬสินธุ์
# 37946         89170  11088.0  โรงพยาบาลห้วยผึ้ง  กาฬสินธุ์
# 37947         90470  11088.0  โรงพยาบาลห้วยผึ้ง  กาฬสินธุ์
# 37948         91123  11088.0  โรงพยาบาลห้วยผึ้ง  กาฬสินธุ์
# 37952         99444  11088.0  โรงพยาบาลห้วยผึ้ง  กาฬสินธุ์
#
# [72 rows x 11 columns]

# %%
merged_use.to_csv(os.path.join(path,'merged_use.csv')) # save เข้า drive เพื่อนำไปทำ dashboard

# %% [markdown]
# ลิงค์ Dashboard
#
# Link: https://datastudio.google.com/reporting/a76882b0-d2de-409a-a7b9-b9d4b4a6061a
