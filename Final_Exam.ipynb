# %% [markdown]
# <a href="https://colab.research.google.com/github/Thitichaya2000/data_viz_2022/blob/main/Final_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # โจทย์

# %% [markdown]
# Final Exam: งานกลุ่ม Final ที่อาจารย์สุ่มให้
#
#
# ให้นักศึกษาสร้าง Dashboard แสดงรายงานเกี่ยวกับข้อมูลการตรวจโรค(ov) จาก ไฟล์ alldb.csv และ hospital_list.xlsx
#
#
# ( ดาวน์โหลดจาก https://drive.google.com/drive/folders/1D_Z0fjTki6U6ECbgh2V3wBOSdOXS81YT?fbclid=IwAR3KK7jaRTK1DI3hfBq--qsME4ScgtNdrEbo2yvE2rn08tOTfmXED5kAEB8)
#
#
# โดยข้อมูลหลักจะอยู่ใน ตาราง alldb.csv (ข้อมูลที่สมบูรณ์ที่สามารถนำมาใช้งานได้ต้องมีค่าใน column ต่อไปนี้ดังนี้
#
#
# * user เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)
# * RowKey เป็น String
# * date เป็น YYYY-MM-DD
# * phone เป็น String
# * site เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)
# * time เป็น hh-mm-ss
# * urine มีค่า String
# * ov เป็นตัวเลข มีค่าตั้งแต่ 0-4 (0 คือไม่พบโรค 1-4 คือพบโรคที่ระดับความรุนแรงต่างๆ)
# * PartitionKey เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น))
#
#
# ไฟล์ alldb.csv และ hospital_list.xlsx สามารถถูกเชื่อมโยงกันโดย site ในไฟล์ alldb.csv คือ hcode ในไฟล์ hospital_list.xlsx
#
#
# โดยข้อมูลสำคัญที่ต้องแสดงคือ
#
#
# * จำนวนการตรวจในแต่ละพื้นที่ (จังหวัด-อำเภอ ในไฟล์ hospital_list.xlsx) เทียบกับ จำนวนที่พบโรค (column ov ในไฟล์ alldb.csv)
# * ช่วงเวลาที่ตรวจ (date ในไฟล์ alldb.csv)
# * อื่นๆที่นักศึกษาเห็นว่าเป็นประโยชน์ (phone (ชนิดโทรศัพท์ที่ใช้บันทึก), title (คำนำหน้าชื่อ), age (อายุ))
#
#
# (คิดคะแนนตามกลุ่ม final โดยไฟล์ที่ทุกคนในกลุ่มต้องมีคือไฟล์ data pre-processing และ link ไปที่ Dashboard ที่สร้่างโดยเปิดให้สามารถเข้าไปดูและใช้งานได้)
#
#
# ส่งไม่เกิน 23.59 วันจันทร์ที่ 11 เมษายน 2565

# %% [markdown]
# # รายชื่อสมาชิกภายในกลุ่ม triturate

# %% [markdown]
# 1. นางสาววัชราภรณ์ บุญจวง 613020615-8
#
# 2. นางสาวฐิติชญา ไกรวงค์ 623020520-0
#
# 3. นางสาวสุพิชญา ตั้งกิจวานิชย์ 623020542-0
#
# 4. นายดิษพงษ์ นาทองห่อ 623020999-5

# %% [markdown]
# # การเชื่อมไดร์ฟเพื่อดึงข้อมูลจากไดรฟ์

# %%
import pandas as pd #เพื่อใช้ทำงานกับข้อมูลที่เป็นรูปแบบตาราง
import os           #เพื่อจัดการกับไฟล์ และ ตัว path ที่เราจะนำเข้า

# %%
from google.colab import drive#เชื่อมข้อมูล เพราะเราจะทำการนำเข้าข้อมูล โดยให้ดึงมาจาก google drive ของเรา
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/ovrdt_data'
#โดยเราจะทำการระบุให้ชี้ไปที่ โฟลเดอร์ที่เราเซฟไฟล์ไว้ หรือก็คือ โฟลเดอร์ Project

# %%
# เชื่อม library
from datetime import datetime as dt # ใช้สำหรับเกี่ยวกับวัน
from datetime import time # ใช้สำหรับเกี่ยวกับวัน
import matplotlib.pyplot as plt # ใช้สำหรับเกี่ยวกับการวาดกราฟ
import numpy as np # ใช้สำหรับเกี่ยวกับตัวเลข
import datetime as dt # ใช้สำหรับเกี่ยวกับวัน

# %% [markdown]
# ## ข้อมูลหลัก ตาราง alldb

# %%
alldb = os.path.join(path,'alldb.xlsx')
alldb = pd.read_excel(alldb)
alldb
# Out:
#        Column1           user                                    RowKey care  \
# 0            0           test                                       NaN  NaN
# 1            1          04857      136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 2            2            NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png  NaN
# 3            3  3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE  NaN
# 4            4  3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21  NaN
# ...        ...            ...                                       ...  ...
# 40030    40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C  NaN
# 40031    40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1  NaN
# 40032    40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9  NaN
# 40033    40033            NaN                            bbuogxulur.png  NaN
# 40034    40034            NaN                            zttpqogiso.png  NaN
#
#             date   ov             phone   site      time            urine  \
# 0            NaT  NaN               NaN    NaN       NaN              NaN
# 1     2022-02-24  NaN        iPhone10,4  05310  10:50:32              NaN
# 2            NaT  NaN               NaN    NaN       NaN              NaN
# 3     2022-02-23  0.0        iPhone13,4  05087  09:59:47  ปกติ (เหลืองใส)
# 4     2022-02-23  NaN        iPhone13,4  05087  09:44:06  ปกติ (เหลืองใส)
# ...          ...  ...               ...    ...       ...              ...
# 40030        NaT  NaN        iPhone13,4  01234       NaN              NaN
# 40031        NaT  2.0        iPhone10,5  01234       NaN  ปกติ (เหลืองใส)
# 40032        NaT  1.0        iPhone13,4  01234       NaN  ปกติ (เหลืองใส)
# 40033        NaT  NaN  Samsung SM-A115F  01234       NaN              NaN
# 40034        NaT  1.0  Samsung SM-A115F  01234       NaN  ปกติ (เหลืองใส)
#
#        pid            PartitionKey                  title  \
# 0      NaN                     NaN  data is not completed
# 1      NaN                     NaN  data is not completed
# 2      NaN                     NaN  data is not completed
# 3      NaN                     NaN  data is not completed
# 4      NaN                     NaN  data is not completed
# ...    ...                     ...                    ...
# 40030  5.0     เกษศิรินทร์  ไชยลาภ  data is not completed
# 40031  5.0  เถลิงเกียรติ เสริฐเลิศ  data is not completed
# 40032  1.0                    เสรี  data is not completed
# 40033  1.0                    เสรี  data is not completed
# 40034  1.0                    เสรี  data is not completed
#
#                          age
# 0      data is not completed
# 1      data is not completed
# 2      data is not completed
# 3      data is not completed
# 4      data is not completed
# ...                      ...
# 40030  data is not completed
# 40031  data is not completed
# 40032  data is not completed
# 40033  data is not completed
# 40034  data is not completed
#
# [40035 rows x 14 columns]

# %% [markdown]
# ## ข้อมูลรอง ตาราง hospital_list

# %%
hospital_list = os.path.join(path,'hospital_list.xlsx')
hospital_list = pd.read_excel(hospital_list)
hospital_list
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5  code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อท           ATG
# ...                         ...    ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
#
# [17103 rows x 16 columns]

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# ## จัดการข้อมูลหลัก ตาราง alldb

# %% [markdown]
# ### เลือกข้อมูลจากตารางหลัก แค่คอลัมน์ที่ต้องการใช้งาน

# %%
alldb_new = alldb[['user','RowKey','date','phone','site','time','urine','ov','PartitionKey','title','age']] 
alldb_new
# Out:
#                 user                                    RowKey       date  \
# 0               test                                       NaN        NaT
# 1              04857      136FD222-FD9F-4E54-AE1F-7282A276B085 2022-02-24
# 2                NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png        NaT
# 3      3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE 2022-02-23
# 4      3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21 2022-02-23
# ...              ...                                       ...        ...
# 40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C        NaT
# 40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1        NaT
# 40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9        NaT
# 40033            NaN                            bbuogxulur.png        NaT
# 40034            NaN                            zttpqogiso.png        NaT
#
#                   phone   site      time            urine   ov  \
# 0                   NaN    NaN       NaN              NaN  NaN
# 1            iPhone10,4  05310  10:50:32              NaN  NaN
# 2                   NaN    NaN       NaN              NaN  NaN
# 3            iPhone13,4  05087  09:59:47  ปกติ (เหลืองใส)  0.0
# 4            iPhone13,4  05087  09:44:06  ปกติ (เหลืองใส)  NaN
# ...                 ...    ...       ...              ...  ...
# 40030        iPhone13,4  01234       NaN              NaN  NaN
# 40031        iPhone10,5  01234       NaN  ปกติ (เหลืองใส)  2.0
# 40032        iPhone13,4  01234       NaN  ปกติ (เหลืองใส)  1.0
# 40033  Samsung SM-A115F  01234       NaN              NaN  NaN
# 40034  Samsung SM-A115F  01234       NaN  ปกติ (เหลืองใส)  1.0
#
#                  PartitionKey                  title                    age
# 0                         NaN  data is not completed  data is not completed
# 1                         NaN  data is not completed  data is not completed
# 2                         NaN  data is not completed  data is not completed
# 3                         NaN  data is not completed  data is not completed
# 4                         NaN  data is not completed  data is not completed
# ...                       ...                    ...                    ...
# 40030     เกษศิรินทร์  ไชยลาภ  data is not completed  data is not completed
# 40031  เถลิงเกียรติ เสริฐเลิศ  data is not completed  data is not completed
# 40032                    เสรี  data is not completed  data is not completed
# 40033                    เสรี  data is not completed  data is not completed
# 40034                    เสรี  data is not completed  data is not completed
#
# [40035 rows x 11 columns]

# %% [markdown]
# ### ตรวจสอบค่า Missing

# %%
alldb_new.isnull().any() 
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# user            True
# RowKey          True
# date            True
# phone           True
# site            True
# time            True
# urine           True
# ov              True
# PartitionKey    True
# title           True
# age             True
# dtype: bool

# %% [markdown]
# ### ใช้ .dropna ซึ่งจะใช้ตัดแถวข้อมูลที่มีค่า missing

# %%
alldb_drop = alldb_new.dropna() #ใช้ dropna เพื่อต้องการลบข้อมูลทั้งแถวออกเมื่อมีคอลัมน์ใดคอลัมน์หนึ่งเป็น NaN
alldb_drop
# Out:
#          user                                RowKey       date  \
# 186    45-161  D2CABB8C-533B-450A-AFA6-B693749CC1C6 2022-02-23
# 187    45-161  57A5F06C-C840-49EA-9514-A30D3C897CC8 2022-02-23
# 188     27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1 2022-02-25
# 191     12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192     91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# ...       ...                                   ...        ...
# 40013   ttest                        crqcufokmn.png 2022-02-21
# 40014   ttest                        gzxgflnowr.png 2022-02-21
# 40016     xxx                        jytlopevha.png 2022-02-17
# 40022     yyy                        ivccsksowb.png 2022-02-17
# 40023     zzz                        psudrnccsh.png 2022-02-17
#
#                   phone   site      time            urine   ov PartitionKey  \
# 186          iPhone11,8  04312  09:45:28  ปกติ (เหลืองใส)  0.0       0-1528
# 187          iPhone11,8  04312  10:06:45  ปกติ (เหลืองใส)  0.0       0-1544
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0.0         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)  4.0        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)  4.0        00001
# ...                 ...    ...       ...              ...  ...          ...
# 40013  Samsung SM-G998B   test  14:23:45             ขุ่น  2.0         x001
# 40014  Samsung SM-G998B   test  14:23:43             ขุ่น  2.0         x001
# 40016  Samsung SM-N950F    xxx  00:01:06  ปกติ (เหลืองใส)  3.0          xxx
# 40022  Samsung SM-N950F    yyy  08:41:05   มีเม็ดเลือดแดง  2.0          yyy
# 40023  Samsung SM-N950F    zzz  08:41:04          มีตะกอน  2.0          zzz
#
#                        title                    age
# 186    data is not completed  data is not completed
# 187    data is not completed  data is not completed
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# ...                      ...                    ...
# 40013  data is not completed  data is not completed
# 40014  data is not completed  data is not completed
# 40016  data is not completed  data is not completed
# 40022  data is not completed  data is not completed
# 40023  data is not completed  data is not completed
#
# [38134 rows x 11 columns]

# %%
alldb_drop.shape #ตรวจสอบขนาดของตารางใหม่
# Out:
# (38134, 11)

# %%
removes = alldb_new.shape[0] - alldb_drop.shape[0]
print(f'size before drop = {alldb_new.shape[0]}')
print(f'size after drop = {alldb_drop.shape[0]}')
print(f'% from drop = {(removes/alldb_new.shape[0])*100}')
 # จากการคำนวณพบว่ามีข้อมูลที่หายไปเพียงแค่ 3% ดังนั้น จึงสามารถใช้การ .dropna() ได ้
# Out:
# size before drop = 40035
# size after drop = 38134
# % from drop = 4.748345197951792

# %%
alldb_drop.isnull().any() 
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# user            False
# RowKey          False
# date            False
# phone           False
# site            False
# time            False
# urine           False
# ov              False
# PartitionKey    False
# title           False
# age             False
# dtype: bool

# %% [markdown]
# ### ทำการเปลี่ยน type ของข้อมูลให้เป็น type ที่ถูกต้อง

# %%
alldb_drop.dtypes # เช็คว่าข้อมูลมี่ความตรงกับที่ต้องการหรือไม่
# Out:
# user                    object
# RowKey                  object
# date            datetime64[ns]
# phone                   object
# site                    object
# time                    object
# urine                   object
# ov                     float64
# PartitionKey            object
# title                   object
# age                     object
# dtype: object

# %% [markdown]
# พบว่ามีข้อมูลที่ไม่ตรงกับสิ่งที่ต้องการ
#
#  * user ปัจจุบันยังเป็นข้อมูล type string ควรเปลี่ยนเป็น int
#  * site ปัจจุบันยังเป็นข้อมูล type string ควรเปลี่ยนเป็น int
#  * ov ปัจจุบันยังเป็นข้อมูล type string ควรเปลี่ยนเป็น int
#  * PartitionKey ปัจจุบันยังเป็นข้อมูล type string ควรเปลี่ยนเป็น int

# %% [markdown]
# #### คอลัมน์ user

# %%
set(alldb_drop['user']) # เพื่อดูข้อมูลทั้งหมดใน column user
# Out:
# {'18865',
#  '83303',
#  '84459',
#  '00201',
#  '76088',
#  '67093',
#  '15980',
#  '70490',
#  '83725',
#  '98080',
#  '19920',
#  '3450100805222',
#  '61591',
#  '745-61',
#  '11215',
#  '01762',
#  '40551',
#  '34501009308',
#  '09315',
#  '19852',
#  '26859',
#  '63951',
#  '28593',
#  '37231',
#  '23630',
#  '70370',
#  '00235',
#  '85444',
#  '3451100141252',
#  '85989',
#  '74378',
#  '00029',
#  '16321',
#  '38778',
#  '37645',
#  '00130',
#  '82954',
#  '63485',
#  '33869',
#  '30041',
#  '79817',
#  '45485',
#  '49322',
#  '67778',
#  '03953',
#  '18253',
#  '28010',
#  '31577',
#  '80979',
#  '58668',
#  '00135',
#  '00123',
#  '83733',
#  '3450101325593',
#  '97505',
#  '27732',
#  '69428',
#  '63091',
#  '23554',
#  '28330',
#  '05151',
#  '00941',
#  '80175',
#  '74964',
#  '00009',
#  '06385',
#  '42682',
#  '13070',
#  '23010',
#  '00755',
#  '62261',
#  '12041',
#  '00026',
#  '26477',
#  '36358',
#  '31619',
#  '19322',
#  '30311',
#  '12605',
#  '23231',
#  '26531',
#  '81197',
#  '80317',
#  '39638',
#  '22680',
#  '31762',
#  '02075',
#  '22099',
#  '31582',
#  '08021',
#  '00624',
#  '81065',
#  '3450101229373',
#  '83449',
#  '44805',
#  '61320',
#  '60581',
#  '61419',
#  '75911',
#  '18025',
#  '00140',
#  '16022',
#  '25781',
#  '88337',
#  '96699',
#  '93020',
#  'vvv',
#  '00297',
#  '77688',
#  'sss',
#  '19211',
#  '47933',
#  '68162',
#  '14387',
#  '10534',
#  '33791',
#  '53980',
#  '88315',
#  '61486',
#  '  67241\n',
#  '12015',
#  '25219',
#  '25683',
#  '74523',
#  '67400',
#  '33237',
#  '47146',
#  '03617',
#  '45729',
#  '00151',
#  '24563',
#  '55911',
#  '54599',
#  '98908',
#  '44845',
#  '85504',
#  '07556',
#  '25331',
#  '26989',
#  '53188',
#  '15731',
#  '00313',
#  '16725',
#  '36001',
#  '09269',
#  '00046',
#  '94538',
#  '3451100150251',
#  '05135',
#  '25923',
#  '47135',
#  '54932',
#  '84005',
#  '63748',
#  '78673',
#  '54781',
#  '00073',
#  '63312',
#  '63471',
#  '97290',
#  '86271',
#  '77706',
#  '00342',
#  '03949',
#  '30283',
#  '70196',
#  '48493',
#  '62334',
#  '26082',
#  '49387',
#  '40881',
#  '48908',
#  '89381',
#  '27046',
#  '03080',
#  '79066',
#  '45701',
#  '54100',
#  '12576',
#  '51795',
#  '98474',
#  '22421',
#  '22824',
#  '89609',
#  '97860',
#  '84493',
#  '00126',
#  '00301',
#  '75835',
#  '16214',
#  '08971',
#  '11282',
#  '29441',
#  '84409',
#  '00284',
#  '76096',
#  '19632',
#  '77862',
#  '34169',
#  '20452',
#  '26459',
#  '53089',
#  '63018',
#  '99376',
#  '93671',
#  '61806',
#  '65675',
#  '60847',
#  '17966',
#  '00282',
#  '3451400598487',
#  '00319',
#  '97016',
#  '50624',
#  '02639',
#  '09617',
#  '00290',
#  '00176',
#  '29051',
#  '61552',
#  '00113',
#  '66191',
#  '58870',
#  '00296',
#  '92241',
#  '85934',
#  '93726',
#  '45924',
#  '70810',
#  '94558',
#  '27902',
#  '81724',
#  '76819',
#  '89056',
#  '28627',
#  '04402',
#  '12561',
#  '96786',
#  '06681',
#  '06855',
#  '52210',
#  't006',
#  '71378\n71378',
#  '17536',
#  '15588',
#  '52350',
#  '75579',
#  '71998',
#  '90888',
#  '05590',
#  '47938',
#  '96771',
#  '71805',
#  'xxx',
#  '01312',
#  '00328',
#  '21860',
#  '15971',
#  '71872',
#  '36481',
#  '67450',
#  '68805',
#  '05272',
#  '12413',
#  '47858',
#  '3450100543961',
#  '49741',
#  '01942',
#  '00014',
#  '00023',
#  '87797',
#  '28961',
#  '79322',
#  '83662',
#  '27529',
#  '90770',
#  '08777',
#  '75910',
#  '30024',
#  '34331',
#  '87218',
#  '00065',
#  '38463',
#  '19201',
#  '00305',
#  '00168',
#  '25221',
#  '51892',
#  '89290',
#  '04461',
#  '86588',
#  '80364',
#  '44364',
#  '00012',
#  '02647',
#  '00051',
#  '40865',
#  '00756',
#  '74493',
#  '05304',
#  '00582',
#  '3451100324713',
#  '00124',
#  '92120',
#  '87738',
#  '39103',
#  '32077',
#  '76386',
#  '79920',
#  '57398',
#  '10518',
#  '77670',
#  '83900',
#  '05069',
#  '13312',
#  '22455',
#  '18769',
#  '53151',
#  '22542',
#  '34711',
#  '54458',
#  '87771',
#  '00348',
#  '19875',
#  '84055',
#  '53330',
#  '59305',
#  '11727',
#  '04193',
#  '68317',
#  '32310',
#  '65664',
#  'aiov0001',
#  '06283',
#  '58845',
#  '46520',
#  '23811',
#  '53510',
#  '10375',
#  '57228',
#  '62440',
#  '50349',
#  '11611',
#  '01636',
#  '00017',
#  '60181',
#  '80481',
#  '00394',
#  '00133',
#  '19002',
#  '17564',
#  '98488',
#  '00013',
#  '15678',
#  '05091',
#  '26440',
#  '85702',
#  '87541',
#  '89394',
#  '70290',
#  '86474',
#  '3451100241281',
#  '41026',
#  '89251',
#  '36692',
#  '65388',
#  '35942',
#  '01467',
#  '78251',
#  '00021',
#  '26957',
#  '00205',
#  '24501',
#  '95668',
#  '39079',
#  '88377',
#  '05358',
#  '96670',
#  '52013',
#  '70281',
#  '81621',
#  '33121',
#  '00079',
#  '17769',
#  '71791',
#  '00170',
#  '37140',
#  '09006',
#  '89913',
#  '00138',
#  '23958',
#  '65678',
#  '06924',
#  '18318',
#  '00050',
#  '80289',
#  '46902',
#  '25478',
#  '46783',
#  '72225',
#  '63306',
#  '24179',
#  '00299',
#  '01883',
#  'aiov0002',
#  '31401',
#  '72186',
#  '36593',
#  '25466',
#  '00071',
#  '27143',
#  '00302',
#  '05291',
#  '48710',
#  '3450100940367',
#  '28062',
#  '01861',
#  '10348',
#  '49215',
#  '00025',
#  '90343',
#  '52912',
#  '00132',
#  '54281',
#  '10653',
#  '89576',
#  '82894',
#  '06436',
#  '79493',
#  '63880',
#  '05974',
#  '10691',
#  '36390',
#  '48440',
#  '23416',
#  '08602',
#  '41182',
#  '17277',
#  '74951',
#  '95821',
#  '94988',
#  '00212',
#  '50004',
#  'uuu',
#  '30121',
#  '80336',
#  'tttt',
#  '02579',
#  '00143',
#  '45914',
#  '00141',
#  '07427',
#  '00139',
#  '00287',
#  '48393',
#  '24559',
#  '63323',
#  '04405',
#  '95161',
#  '47623',
#  '77811',
#  '16820',
#  '00167',
#  '96081',
#  '61044',
#  '02878',
#  '62059',
#  '18524',
#  '26462',
#  '91125',
#  '00035',
#  '19575',
#  '16193',
#  '7140',
#  '63381',
#  '62616',
#  '68856',
#  '43143',
#  '00158',
#  '99288',
#  '71417',
#  '64081',
#  '29907',
#  '03381',
#  '60688',
#  '47810',
#  '73375',
#  '26811',
#  '45531',
#  '40035',
#  '14491',
#  '00286',
#  '00312',
#  '32831',
#  '14988',
#  '05849',
#  '87067',
#  '50144',
#  '53920',
#  '88708',
#  '38614',
#  '00209',
#  '25837',
#  '00237',
#  '76246',
#  '06271',
#  '00292',
#  '31811',
#  '22244',
#  '01850',
#  '48255',
#  '56051',
#  '94087',
#  '29159',
#  '49103',
#  '51039',
#  '00018',
#  '92893',
#  '17777',
#  '49791',
#  '58500',
#  '3451100324624',
#  '70187',
#  '69037',
#  '90257',
#  '62105',
#  '52922',
#  '62459',
#  '67352',
#  '61182',
#  '09902',
#  '39342',
#  '50466',
#  '95609',
#  '39593',
#  '97770',
#  '06268',
#  '11522',
#  '95978',
#  '19578',
#  '10673',
#  '38381',
#  '16529',
#  '65390',
#  '92648',
#  '25943',
#  '49424',
#  '71503',
#  '96730',
#  '57066',
#  '99992',
#  '65301',
#  '31196',
#  '84479',
#  '53011',
#  '00280',
#  '50284',
#  '33643',
#  '08741',
#  '63429',
#  '67094',
#  '33664',
#  '86547',
#  '23885',
#  '02263',
#  '28241',
#  '26647',
#  '99835',
#  '54538',
#  '00291',
#  '14037',
#  '93189',
#  '20061',
#  '09072',
#  '59181',
#  'bbb',
#  '63799',
#  '31792',
#  '00006',
#  '00303',
#  '00052',
#  '65321',
#  '00217',
#  '28186',
#  '52180',
#  '10993',
#  '99734',
#  '3450100810285',
#  '75061',
#  '70455',
#  '02853',
#  '01183',
#  '80511',
#  '39448',
#  '50276',
#  '95810',
#  '16144',
#  '49268',
#  '98171',
#  '73445',
#  '00253',
#  '01008',
#  '50471',
#  '26442',
#  '26916',
#  '5799',
#  '10695',
#  '85493',
#  '5450500072920',
#  '88942',
#  '03663',
#  '07166',
#  '91209',
#  '61121',
#  '70409',
#  '3450101325097',
#  '45-161',
#  '19855',
#  '02990',
#  '00164',
#  '11864',
#  '26604',
#  '00019',
#  '00315',
#  '01088',
#  '28348',
#  '97013',
#  '96630',
#  '30511',
#  '76486',
#  '11165',
#  '95104',
#  '27096',
#  '72483',
#  '46970',
#  '08436',
#  '27589',
#  '19756',
#  '49413',
#  '55547',
#  '49634',
#  '69681',
#  '05082',
#  '52520',
#  '15102',
#  '81570',
#  '00318',
#  '08072',
#  '83771',
#  '33316',
#  '00283',
#  '92431',
#  '05232',
#  '31086',
#  '18873',
#  '68829',
#  '32200',
#  '3450101325119',
#  '63039',
#  '38547',
#  '73000',
#  '44018',
#  '00114',
#  '00409',
#  '00210',
#  '62768',
#  '00276',
#  '32591',
#  '30660',
#  '04857',
#  '71327',
#  '65733',
#  '00136',
#  '49782',
#  '99245',
#  '37914',
#  '97281',
#  '54679',
#  '00118',
#  '03338',
#  '63865',
#  '39959',
#  '44199',
#  '65075',
#  '01651',
#  '45680',
#  '00160',
#  '88023',
#  '71228',
#  '62687',
#  '34322',
#  '00088',
#  '00134',
#  '82777',
#  '24491',
#  'ggg',
#  '89801',
#  '64520',
#  '17974',
#  '18181',
#  '45641',
#  '19237',
#  'ttt',
#  '00112',
#  '00166',
#  '85737',
#  '07203',
#  '12003',
#  '52481',
#  '80880',
#  '36362',
#  '77384',
#  'ttohn',
#  '66708',
#  '19180',
#  '63098',
#  '24612',
#  '35178',
#  '10724',
#  '00142',
#  '92220',
#  '78231',
#  '12723',
#  '26540',
#  '43257',
#  '00183',
#  '95935',
#  '39764',
#  '3451100146637',
#  'hu',
#  '00148',
#  '31283',
#  '30059',
#  '00309',
#  '87536',
#  '40591\n40591\n',
#  '71970',
#  '34585',
#  '01403',
#  '53356',
#  '85753',
#  '59128',
#  '00322',
#  '20380',
#  '62061',
#  '00281',
#  '53333',
#  '06964',
#  '37228',
#  '22119',
#  '10194',
#  '59721',
#  '3450101536268',
#  '77994',
#  '00149',
#  '06790',
#  '47950',
#  '70948',
#  '73251',
#  '22545',
#  '26773',
#  '07573',
#  '63200',
#  '00011',
#  '01730',
#  '00152',
#  '45881',
#  '02217',
#  '64503',
#  '77254',
#  '74414',
#  '02693',
#  '75921',
#  '00039',
#  '77509',
#  '63852',
#  '69576',
#  '83257',
#  '27802',
#  '52724',
#  '42468',
#  '74747',
#  '00122',
#  '79001',
#  '55659',
#  '31534',
#  '50911',
#  '56326',
#  '04347',
#  '11891',
#  '57099',
#  '37408',
#  '00341',
#  '41340',
#  '81529',
#  '67379',
#  '55075',
#  '05242',
#  '12786',
#  '27604',
#  '08818',
#  '00324',
#  '02087',
#  '02604',
#  '83937',
#  '11887',
#  '46775',
#  '49901',
#  '52678',
#  '90609',
#  '35605',
#  '00146',
#  '22692',
#  '59423',
#  '79834',
#  '46897',
#  '93527',
#  '87315',
#  '48274',
#  '00048',
#  '29760',
#  '86981',
#  '11387',
#  '29796',
#  '61587',
#  '66062',
#  'lll',
#  '24258',
#  '41951',
#  '14088',
#  '06260',
#  '07331',
#  '60953',
#  '88973',
#  '98519',
#  '29000',
#  '00083',
#  '10487',
#  '80374',
#  '88459',
#  '73636',
#  '23675',
#  '05019',
#  '29309',
#  '35888',
#  '75771',
#  '63767',
#  '74335',
#  '61605',
#  '91167',
#  '55299',
#  '10992',
#  '79590',
#  '91947',
#  '54192',
#  '43868',
#  '51060',
#  '06655',
#  '02547',
#  '29118',
#  '26776',
#  '23186',
#  '02091',
#  '89681',
#  '22354',
#  '45047',
#  '  noknoi2601@gmail.com\n',
#  '32796',
#  '56821',
#  '92415',
#  '71112',
#  '50837',
#  '04281',
#  '51973',
#  '04854',
#  '43834',
#  '30767',
#  '17916',
#  '44502',
#  '14455',
#  '90604',
#  '16372',
#  '42465',
#  '00271',
#  '95127',
#  '14667',
#  '59051',
#  '74840',
#  '32581',
#  '08773',
#  '00137',
#  '66381',
#  '38500',
#  '23596',
#  '00002',
#  '03087',
#  '12022',
#  '14255',
#  '73225',
#  '18737',
#  '39537',
#  '00278',
#  '34988',
#  '34343',
#  '84935',
#  '18849',
#  '97057',
#  '13361',
#  '37259',
#  '00045',
#  '00269',
#  '99011',
#  '67615',
#  '84196',
#  '5450100026807',
#  '14380',
#  '00213',
#  '93991',
#  '26469',
#  '95927',
#  '81293',
#  '19364',
#  '89475',
#  '15963',
#  '69091',
#  '69431',
#  '19559',
#  '63274',
#  '73336',
#  '29476',
#  '72330',
#  '45787',
#  '74289',
#  '10264',
#  '93028',
#  '68081',
#  '00162',
#  '03500',
#  '00031',
#  '58196',
#  '22478',
#  '77645',
#  '88351',
#  '00197',
#  '51241',
#  '41301',
#  '58718',
#  '12378',
#  '00214',
#  '00204',
#  '00266',
#  '99475',
#  '46732',
#  '47605',
#  '14189',
#  '61325',
#  '49659',
#  '86113',
#  '98156',
#  '84063',
#  '15737',
#  '66155',
#  '78960',
#  '36994',
#  '00565',
#  '74345',
#  '00059',
#  '51568',
#  '45593',
#  '46285',
#  '49178',
#  '97308',
#  '94406',
#  '00274',
#  '01068',
#  '67972',
#  '58271',
#  '90154',
#  '80463',
#  '06223',
#  '65995',
#  '51689',
#  '92948',
#  '00147',
#  '94414',
#  '86721',
#  '00293',
#  '47656',
#  '44201',
#  '67961',
#  '00203',
#  '00165',
#  '66771',
#  '00121',
#  '50951',
#  '53579',
#  '43228',
#  '05047',
#  '03308',
#  '15734',
#  ...}

# %% [markdown]
# เเก้ไขให้มีข้อมูลที่ถูกต้อง
#
# โดยกำหนดให้ข้อมูลที่ไม่ใช่เลข 5 หลัก เท่ากับ ข้อมูลว่าง

# %%
alldb_drop['user'].replace({'3450101325119':None,
'34501009308':None,
'71378\n71378':'71378',
'yyy':None,
'7197':None,
'rrr':None,
'745-61':'74561',
'uuu':None,
'3450100810285':None,
'jjj':None,
'11111111':None,
'3450100805222':None,
'zzz':None,
'3450101556129':None,
'3450101325593':None,
'4':None,
'6724100235':None,
'17536\n\n17536':'17536',
'3450101229373':None,
'Testtohn':None,
'  noknoi2601@gmail.com\n':None,
'3451100324624':None,
'40591\n40591\n':'40591',
'6724-':None,
'test':None,
'3450101536268':None,
'3450100543961':None,
'ppp':None,
'xxx':None,
'3451100451758':None,
'hhh':None,
'ttohn':None,
'fff':None,
'ggg':None,
'ccc':None,
'5600190011969':None,
'testtohn':None,
'3451400598487':None,
'3':None,
'3400900747146':None,
'5450100026807':None,
'iii':None,
'5799':None,
'aaa':None,
'3451100141252':None,
't006':None,
'5450500072920':None,
'bbb':None,
'hu':None,
'3450101323370':None,
'ttest':None,
'test1':None,
'tttt':None,
'eee':None,
'qqq':None,
'ttt':None,
'45-161':None,
'sss':None,
'tt':None,
'u789':None,
'3451100241281':None,
'3451100324713':None,
'3450101514299':None,
'3451100451251':None,
'1450700099250':None,
'3450100836420':None,
'3450500541443':None,
'www':None,
'5451100055352':None,
'3451100146637':None,
'3450100940367':None,
'mmm':None,
'3460500500020':None,
'vvv':None,
'lll':None,
'3450101325097':None,
'aiov0001':None,
'kkk':None,
'mks':None,
'aiov0002':None,
'3459900286317':None,
'3451100150251':None,
'3450101576642':None,
'  67241\n':'67241'
},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
set(alldb_drop['user']) # เพื่อดูข้อมูลทั้งหมดใน column user
# Out:
# {'18865',
#  '83303',
#  '84459',
#  '00201',
#  '76088',
#  '67093',
#  '15980',
#  '70490',
#  '83725',
#  '98080',
#  '19920',
#  '61591',
#  '11215',
#  '01762',
#  '40551',
#  '09315',
#  '19852',
#  '26859',
#  '63951',
#  '28593',
#  '37231',
#  '23630',
#  '70370',
#  '00235',
#  '85444',
#  '85989',
#  '74378',
#  '00029',
#  '16321',
#  '38778',
#  '37645',
#  '00130',
#  '82954',
#  '63485',
#  '33869',
#  '30041',
#  '79817',
#  '45485',
#  '49322',
#  '67778',
#  '03953',
#  '18253',
#  '28010',
#  '31577',
#  '80979',
#  '58668',
#  '00135',
#  '00123',
#  '83733',
#  '97505',
#  '27732',
#  '69428',
#  '63091',
#  '23554',
#  '28330',
#  '05151',
#  '00941',
#  '80175',
#  '74964',
#  '00009',
#  '06385',
#  '42682',
#  '13070',
#  '23010',
#  '00755',
#  '62261',
#  '12041',
#  '00026',
#  '26477',
#  '36358',
#  '31619',
#  '19322',
#  '30311',
#  '12605',
#  '23231',
#  '26531',
#  '81197',
#  '80317',
#  '39638',
#  '22680',
#  '31762',
#  '02075',
#  '22099',
#  '31582',
#  '08021',
#  '00624',
#  '81065',
#  '44805',
#  '83449',
#  '61320',
#  '60581',
#  '61419',
#  '75911',
#  '18025',
#  '00140',
#  '16022',
#  '25781',
#  '88337',
#  '96699',
#  '93020',
#  '00297',
#  '77688',
#  '19211',
#  '47933',
#  '68162',
#  '14387',
#  '10534',
#  '33791',
#  '53980',
#  '88315',
#  '61486',
#  '12015',
#  '25219',
#  '25683',
#  '74523',
#  '67400',
#  '33237',
#  '47146',
#  '03617',
#  '45729',
#  '00151',
#  '24563',
#  '55911',
#  '54599',
#  '98908',
#  '44845',
#  '85504',
#  '07556',
#  '25331',
#  '26989',
#  '53188',
#  '15731',
#  '00313',
#  '16725',
#  '36001',
#  '09269',
#  '00046',
#  '94538',
#  '05135',
#  '25923',
#  '47135',
#  '54932',
#  '84005',
#  '63748',
#  '78673',
#  '54781',
#  '00073',
#  '63312',
#  '63471',
#  '97290',
#  '86271',
#  '77706',
#  '00342',
#  '03949',
#  '30283',
#  '70196',
#  '48493',
#  '62334',
#  '26082',
#  '49387',
#  '40881',
#  '48908',
#  '89381',
#  '27046',
#  '03080',
#  '79066',
#  '45701',
#  '54100',
#  '12576',
#  '51795',
#  '98474',
#  '22421',
#  '22824',
#  '89609',
#  '97860',
#  '84493',
#  '00126',
#  '00301',
#  '75835',
#  '16214',
#  '08971',
#  '11282',
#  '29441',
#  '84409',
#  '00284',
#  '76096',
#  '19632',
#  '77862',
#  '34169',
#  '20452',
#  '26459',
#  '53089',
#  '63018',
#  '99376',
#  '93671',
#  '61806',
#  '65675',
#  '60847',
#  '17966',
#  '00282',
#  '00319',
#  '97016',
#  '50624',
#  '02639',
#  '09617',
#  '00290',
#  '00176',
#  '29051',
#  '61552',
#  '00113',
#  '66191',
#  '58870',
#  '00296',
#  '92241',
#  '85934',
#  '93726',
#  '45924',
#  '70810',
#  '94558',
#  '27902',
#  '81724',
#  '76819',
#  '89056',
#  '28627',
#  '04402',
#  '12561',
#  '96786',
#  '06681',
#  '06855',
#  '52210',
#  '17536',
#  '15588',
#  '52350',
#  '75579',
#  '71998',
#  '90888',
#  '05590',
#  '47938',
#  '96771',
#  '71805',
#  '01312',
#  '00328',
#  '21860',
#  '15971',
#  '71872',
#  '36481',
#  '67450',
#  '68805',
#  '05272',
#  '12413',
#  '47858',
#  '49741',
#  '01942',
#  '00014',
#  '00023',
#  '87797',
#  '28961',
#  '79322',
#  '83662',
#  '27529',
#  '90770',
#  '08777',
#  '75910',
#  '30024',
#  '34331',
#  '87218',
#  '00065',
#  '38463',
#  '19201',
#  '00305',
#  '00168',
#  '25221',
#  '51892',
#  '89290',
#  '04461',
#  '86588',
#  '80364',
#  '44364',
#  '00012',
#  '02647',
#  '00051',
#  '40865',
#  '00756',
#  '74493',
#  '05304',
#  '00582',
#  '00124',
#  '92120',
#  '87738',
#  '39103',
#  '32077',
#  '76386',
#  '79920',
#  '57398',
#  '10518',
#  '77670',
#  '83900',
#  '05069',
#  '13312',
#  '22455',
#  '18769',
#  '53151',
#  '22542',
#  '34711',
#  '54458',
#  '87771',
#  '00348',
#  '19875',
#  '84055',
#  '53330',
#  '59305',
#  '11727',
#  '04193',
#  '68317',
#  '32310',
#  '65664',
#  '06283',
#  '58845',
#  '46520',
#  '23811',
#  '53510',
#  '10375',
#  '57228',
#  '62440',
#  '50349',
#  '11611',
#  '01636',
#  '00017',
#  '60181',
#  '80481',
#  '00394',
#  '00133',
#  '19002',
#  '17564',
#  '98488',
#  '00013',
#  '15678',
#  '05091',
#  '26440',
#  '85702',
#  '87541',
#  '89394',
#  '70290',
#  '86474',
#  '41026',
#  '89251',
#  '36692',
#  '65388',
#  '35942',
#  '01467',
#  '78251',
#  '00021',
#  '26957',
#  '00205',
#  '24501',
#  '95668',
#  '39079',
#  '88377',
#  '05358',
#  '96670',
#  '52013',
#  '70281',
#  '81621',
#  '33121',
#  '00079',
#  '17769',
#  '71791',
#  '00170',
#  '37140',
#  '09006',
#  '89913',
#  '00138',
#  '23958',
#  '65678',
#  '06924',
#  '18318',
#  '00050',
#  '80289',
#  '46902',
#  '25478',
#  '46783',
#  '72225',
#  '63306',
#  '24179',
#  '00299',
#  '01883',
#  '31401',
#  '72186',
#  '36593',
#  '25466',
#  '00071',
#  '27143',
#  '00302',
#  '05291',
#  '48710',
#  '28062',
#  '01861',
#  '10348',
#  '49215',
#  '00025',
#  '90343',
#  '52912',
#  '00132',
#  '54281',
#  '10653',
#  '89576',
#  '82894',
#  '06436',
#  '79493',
#  '63880',
#  '05974',
#  '10691',
#  '36390',
#  '48440',
#  '23416',
#  '08602',
#  '41182',
#  '17277',
#  '74951',
#  '95821',
#  '94988',
#  '00212',
#  '50004',
#  '30121',
#  '80336',
#  '02579',
#  '00143',
#  '45914',
#  '00141',
#  '07427',
#  '00139',
#  '00287',
#  '48393',
#  '24559',
#  '63323',
#  '04405',
#  '95161',
#  '47623',
#  '77811',
#  '16820',
#  '00167',
#  '96081',
#  '61044',
#  '02878',
#  '62059',
#  '18524',
#  '26462',
#  '91125',
#  '00035',
#  '19575',
#  '16193',
#  '7140',
#  '63381',
#  '62616',
#  '68856',
#  '43143',
#  '00158',
#  '99288',
#  '71417',
#  '64081',
#  '29907',
#  '03381',
#  '60688',
#  '47810',
#  '73375',
#  '26811',
#  '45531',
#  '40035',
#  '14491',
#  '00286',
#  '00312',
#  '32831',
#  '14988',
#  '05849',
#  '87067',
#  '50144',
#  '53920',
#  '88708',
#  '38614',
#  '00209',
#  '25837',
#  '00237',
#  '76246',
#  '06271',
#  '00292',
#  '31811',
#  '22244',
#  '01850',
#  '48255',
#  '56051',
#  '94087',
#  '29159',
#  '49103',
#  '51039',
#  '00018',
#  '92893',
#  '17777',
#  '49791',
#  '58500',
#  '70187',
#  '69037',
#  '90257',
#  '62105',
#  '52922',
#  '62459',
#  '67352',
#  '61182',
#  '09902',
#  '39342',
#  '50466',
#  '95609',
#  '39593',
#  '97770',
#  '06268',
#  '11522',
#  '95978',
#  '19578',
#  '10673',
#  '38381',
#  '16529',
#  '65390',
#  '92648',
#  '25943',
#  '49424',
#  '71503',
#  '96730',
#  '57066',
#  '99992',
#  '65301',
#  '31196',
#  '84479',
#  '53011',
#  '00280',
#  '50284',
#  '33643',
#  '08741',
#  '63429',
#  '67094',
#  '33664',
#  '86547',
#  '23885',
#  '02263',
#  '28241',
#  '26647',
#  '99835',
#  '54538',
#  '00291',
#  '14037',
#  '93189',
#  '20061',
#  '09072',
#  '59181',
#  '63799',
#  '31792',
#  '00006',
#  '00303',
#  '00052',
#  '65321',
#  '00217',
#  '28186',
#  '52180',
#  '10993',
#  '99734',
#  '75061',
#  '70455',
#  '02853',
#  '01183',
#  '80511',
#  '39448',
#  '50276',
#  '95810',
#  '16144',
#  '49268',
#  '98171',
#  '73445',
#  '00253',
#  '01008',
#  '50471',
#  '26442',
#  '26916',
#  '10695',
#  '85493',
#  '88942',
#  '03663',
#  '07166',
#  '91209',
#  '61121',
#  '70409',
#  '19855',
#  '02990',
#  '00164',
#  '11864',
#  '26604',
#  '00019',
#  '00315',
#  '01088',
#  '28348',
#  '97013',
#  '96630',
#  '30511',
#  '76486',
#  '11165',
#  '95104',
#  '27096',
#  '72483',
#  '46970',
#  '08436',
#  '27589',
#  '19756',
#  '49413',
#  '55547',
#  '49634',
#  '69681',
#  '05082',
#  '52520',
#  '15102',
#  '81570',
#  '00318',
#  '08072',
#  '83771',
#  '33316',
#  '00283',
#  '92431',
#  '05232',
#  '31086',
#  '18873',
#  '68829',
#  '32200',
#  '63039',
#  '73000',
#  '38547',
#  '44018',
#  '00114',
#  '00409',
#  '00210',
#  '62768',
#  '00276',
#  '32591',
#  '30660',
#  '04857',
#  '71327',
#  '65733',
#  '00136',
#  '49782',
#  '99245',
#  '37914',
#  '97281',
#  '54679',
#  '00118',
#  '03338',
#  '63865',
#  '39959',
#  '44199',
#  '65075',
#  '01651',
#  '45680',
#  '00160',
#  '88023',
#  '71228',
#  '62687',
#  '34322',
#  '00088',
#  '00134',
#  '82777',
#  '24491',
#  '89801',
#  '64520',
#  '17974',
#  '18181',
#  '45641',
#  '19237',
#  '00112',
#  '00166',
#  '85737',
#  '07203',
#  '12003',
#  '52481',
#  '80880',
#  '36362',
#  '77384',
#  '66708',
#  '19180',
#  '63098',
#  '24612',
#  '35178',
#  '10724',
#  '00142',
#  '92220',
#  '78231',
#  '12723',
#  '26540',
#  '43257',
#  '00183',
#  '95935',
#  '39764',
#  '00148',
#  '31283',
#  '30059',
#  '00309',
#  '87536',
#  '71970',
#  '34585',
#  '01403',
#  '53356',
#  '85753',
#  '59128',
#  '00322',
#  '20380',
#  '62061',
#  '00281',
#  '53333',
#  '06964',
#  '37228',
#  '22119',
#  '10194',
#  '59721',
#  '77994',
#  '00149',
#  '06790',
#  '47950',
#  '70948',
#  '73251',
#  '22545',
#  '26773',
#  '07573',
#  '63200',
#  '00011',
#  '01730',
#  '00152',
#  '45881',
#  '02217',
#  '64503',
#  '77254',
#  '74414',
#  '02693',
#  '75921',
#  '00039',
#  '77509',
#  '63852',
#  '69576',
#  '83257',
#  '27802',
#  '52724',
#  '42468',
#  '74747',
#  '00122',
#  '79001',
#  '55659',
#  '31534',
#  '50911',
#  '56326',
#  '04347',
#  '11891',
#  '57099',
#  '37408',
#  '00341',
#  '41340',
#  '81529',
#  '67379',
#  '55075',
#  '05242',
#  '12786',
#  '27604',
#  '08818',
#  '00324',
#  '02087',
#  '02604',
#  '83937',
#  '11887',
#  '46775',
#  '49901',
#  '52678',
#  '90609',
#  '35605',
#  '00146',
#  '22692',
#  '59423',
#  '79834',
#  '46897',
#  '93527',
#  '87315',
#  '48274',
#  '00048',
#  '29760',
#  '86981',
#  '11387',
#  '29796',
#  '61587',
#  '66062',
#  '24258',
#  '41951',
#  '14088',
#  '06260',
#  '07331',
#  '60953',
#  '88973',
#  '98519',
#  '29000',
#  '00083',
#  '10487',
#  '80374',
#  '88459',
#  '73636',
#  '23675',
#  '05019',
#  '29309',
#  '35888',
#  '75771',
#  '63767',
#  '74335',
#  '61605',
#  '91167',
#  '55299',
#  '10992',
#  '79590',
#  '91947',
#  '54192',
#  '43868',
#  '51060',
#  '06655',
#  '02547',
#  '29118',
#  '26776',
#  '23186',
#  '02091',
#  '89681',
#  '22354',
#  '45047',
#  '32796',
#  '56821',
#  '92415',
#  '71112',
#  '50837',
#  '04281',
#  '51973',
#  '04854',
#  '43834',
#  '30767',
#  '17916',
#  '44502',
#  '14455',
#  '90604',
#  '16372',
#  '42465',
#  '00271',
#  '95127',
#  '14667',
#  '59051',
#  '74840',
#  '32581',
#  '08773',
#  '00137',
#  '66381',
#  '38500',
#  '23596',
#  '00002',
#  '03087',
#  '12022',
#  '14255',
#  '73225',
#  '18737',
#  '39537',
#  '00278',
#  '34988',
#  '34343',
#  '84935',
#  '18849',
#  '97057',
#  '13361',
#  '37259',
#  '00045',
#  '00269',
#  '99011',
#  '67615',
#  '84196',
#  '14380',
#  '00213',
#  '93991',
#  '26469',
#  '95927',
#  '81293',
#  '19364',
#  '89475',
#  '15963',
#  '69091',
#  '69431',
#  '19559',
#  '63274',
#  '73336',
#  '29476',
#  '72330',
#  '45787',
#  '74289',
#  '10264',
#  '93028',
#  '68081',
#  '00162',
#  '03500',
#  '00031',
#  '58196',
#  '22478',
#  '77645',
#  '88351',
#  '00197',
#  '51241',
#  '41301',
#  '58718',
#  '12378',
#  '00214',
#  '00204',
#  '00266',
#  '99475',
#  '46732',
#  '47605',
#  '14189',
#  '61325',
#  '49659',
#  '86113',
#  '98156',
#  '84063',
#  '15737',
#  '66155',
#  '78960',
#  '36994',
#  '00565',
#  '74345',
#  '00059',
#  '51568',
#  None,
#  '46285',
#  '45593',
#  '49178',
#  '97308',
#  '94406',
#  '00274',
#  '01068',
#  '67972',
#  '58271',
#  '90154',
#  '80463',
#  '06223',
#  '65995',
#  '51689',
#  '92948',
#  '00147',
#  '94414',
#  '86721',
#  '00293',
#  '47656',
#  '44201',
#  '67961',
#  '00203',
#  '00165',
#  '66771',
#  '00121',
#  '50951',
#  '53579',
#  '43228',
#  '05047',
#  '03308',
#  '15734',
#  '00285',
#  '48016',
#  '77743',
#  '37216',
#  '26511',
#  '37186',
#  '28890',
#  '53751',
#  '90872',
#  '49367',
#  '16904',
#  '05368',
#  '01461',
#  '86050',
#  '24404',
#  '55236',
#  '18954',
#  '82685',
#  '32171',
#  '37551',
#  '00273',
#  '95301',
#  '50900',
#  '86299',
#  '67850',
#  '11027',
#  '31428',
#  '53481',
#  '00208',
#  '02663',
#  '59144',
#  '00352',
#  '38822',
#  '39440',
#  '35139',
#  '31062',
#  '23214',
#  '87802',
#  '79028',
#  ...}

# %%
alldb_drop2 = alldb_drop.dropna() # ทำการ drop ค่าว่างออก 
alldb_drop2 # แสดงผลลัพธ์
# Out:
#         user                                RowKey       date  \
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1 2022-02-25
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 39722  76331                        bbrbiwclgv.png 2022-02-23
# 39782  76331                        lzzsckyyqs.png 2022-02-23
# 39791  76331                        pvpiawlexb.png 2022-02-23
# 39794  68317                        rtutxrlbam.png 2022-02-23
# 39795  68317                        dmuragqwza.png 2022-02-23
#
#                   phone   site      time            urine   ov PartitionKey  \
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0.0         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)  4.0        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)  4.0        00001
# 193          iPhone13,4  06302  10:16:46  ปกติ (เหลืองใส)  3.0        00001
# 194           iPhone9,4  05059  12:26:38  ปกติ (เหลืองใส)  3.0        00001
# ...                 ...    ...       ...              ...  ...          ...
# 39722  Samsung SM-G965U  05258  14:05:25  ปกติ (เหลืองใส)  0.0           61
# 39782  Samsung SM-G965U  05258  14:42:45  ปกติ (เหลืองใส)  0.0           89
# 39791  Samsung SM-G965U  05258  15:32:53  ปกติ (เหลืองใส)  1.0           92
# 39794  Samsung SM-A115F  28017  14:31:01  ปกติ (เหลืองใส)  2.0          976
# 39795  Samsung SM-A115F  28017  14:30:21  ปกติ (เหลืองใส)  2.0          983
#
#                        title                    age
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# 193                      นาง                     55
# 194                      นาย                     66
# ...                      ...                    ...
# 39722  data is not completed  data is not completed
# 39782  data is not completed  data is not completed
# 39791  data is not completed  data is not completed
# 39794  data is not completed  data is not completed
# 39795  data is not completed  data is not completed
#
# [37481 rows x 11 columns]

# %%
alldb_drop2 = alldb_drop2[(alldb_drop2['user'].astype(str).str.isdigit()) & (alldb_drop2['user'].str.len() == 5 )] # เลือกข้อมูลที่เป็น 5 หลัก

# %%
alldb_drop2
# Out:
#         user                                RowKey       date  \
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1 2022-02-25
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 39722  76331                        bbrbiwclgv.png 2022-02-23
# 39782  76331                        lzzsckyyqs.png 2022-02-23
# 39791  76331                        pvpiawlexb.png 2022-02-23
# 39794  68317                        rtutxrlbam.png 2022-02-23
# 39795  68317                        dmuragqwza.png 2022-02-23
#
#                   phone   site      time            urine   ov PartitionKey  \
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0.0         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)  4.0        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)  4.0        00001
# 193          iPhone13,4  06302  10:16:46  ปกติ (เหลืองใส)  3.0        00001
# 194           iPhone9,4  05059  12:26:38  ปกติ (เหลืองใส)  3.0        00001
# ...                 ...    ...       ...              ...  ...          ...
# 39722  Samsung SM-G965U  05258  14:05:25  ปกติ (เหลืองใส)  0.0           61
# 39782  Samsung SM-G965U  05258  14:42:45  ปกติ (เหลืองใส)  0.0           89
# 39791  Samsung SM-G965U  05258  15:32:53  ปกติ (เหลืองใส)  1.0           92
# 39794  Samsung SM-A115F  28017  14:31:01  ปกติ (เหลืองใส)  2.0          976
# 39795  Samsung SM-A115F  28017  14:30:21  ปกติ (เหลืองใส)  2.0          983
#
#                        title                    age
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# 193                      นาง                     55
# 194                      นาย                     66
# ...                      ...                    ...
# 39722  data is not completed  data is not completed
# 39782  data is not completed  data is not completed
# 39791  data is not completed  data is not completed
# 39794  data is not completed  data is not completed
# 39795  data is not completed  data is not completed
#
# [37473 rows x 11 columns]

# %% [markdown]
# #### คอลัมน์ site

# %%
set(alldb_drop2['site']) # เพื่อดูข้อมูลทั้งหมดใน column site
# Out:
# {'00027',
#  '00040',
#  '00513',
#  '00579',
#  '00580',
#  '01151',
#  '02759',
#  '03432',
#  '03626',
#  '04275',
#  '04279',
#  '04280',
#  '04281',
#  '04302',
#  '04312',
#  '04313',
#  '04321',
#  '04322',
#  '04326',
#  '04337',
#  '04347',
#  '04349',
#  '04351',
#  '04352',
#  '04355',
#  '04374',
#  '04376',
#  '04380',
#  '04384',
#  '04387',
#  '04388',
#  '04390',
#  '04391',
#  '04396',
#  '04399',
#  '04401',
#  '04402',
#  '04403',
#  '04404',
#  '04405',
#  '04406',
#  '04407',
#  '04408',
#  '04433',
#  '04434',
#  '04435',
#  '04436',
#  '04437',
#  '04438',
#  '04441',
#  '04443',
#  '04455',
#  '04456',
#  '04457',
#  '04458',
#  '04475',
#  '04478',
#  '04558',
#  '04936',
#  '04968',
#  '04970',
#  '04971',
#  '04973',
#  '04974',
#  '04977',
#  '04980',
#  '04981',
#  '04982',
#  '04983',
#  '04984',
#  '04985',
#  '04986',
#  '04989',
#  '04990',
#  '04992',
#  '04993',
#  '04994',
#  '04995',
#  '04996',
#  '04997',
#  '04999',
#  '05000',
#  '05001',
#  '05002',
#  '05003',
#  '05004',
#  '05005',
#  '05006',
#  '05007',
#  '05008',
#  '05009',
#  '05010',
#  '05011',
#  '05012',
#  '05013',
#  '05015',
#  '05016',
#  '05019',
#  '05021',
#  '05022',
#  '05023',
#  '05024',
#  '05025',
#  '05026',
#  '05027',
#  '05028',
#  '05029',
#  '05032',
#  '05033',
#  '05034',
#  '05035',
#  '05038',
#  '05040',
#  '05042',
#  '05044',
#  '05045',
#  '05047',
#  '05048',
#  '05049',
#  '05052',
#  '05054',
#  '05055',
#  '05058',
#  '05059',
#  '05060',
#  '05061',
#  '05062',
#  '05063',
#  '05064',
#  '05065',
#  '05066',
#  '05067',
#  '05068',
#  '05069',
#  '05072',
#  '05074',
#  '05075',
#  '05077',
#  '05080',
#  '05081',
#  '05082',
#  '05083',
#  '05084',
#  '05086',
#  '05087',
#  '05088',
#  '05090',
#  '05091',
#  '05094',
#  '05097',
#  '05098',
#  '05100',
#  '05101',
#  '05102',
#  '05103',
#  '05107',
#  '05111',
#  '05112',
#  '05113',
#  '05115',
#  '05116',
#  '05117',
#  '05119',
#  '05120',
#  '05123',
#  '05125',
#  '05126',
#  '05128',
#  '05129',
#  '05131',
#  '05132',
#  '05133',
#  '05135',
#  '05136',
#  '05141',
#  '05143',
#  '05144',
#  '05146',
#  '05147',
#  '05152',
#  '05154',
#  '05157',
#  '05158',
#  '05162',
#  '05166',
#  '05172',
#  '05173',
#  '05175',
#  '05177',
#  '05178',
#  '05180',
#  '05181',
#  '05182',
#  '05185',
#  '05187',
#  '05188',
#  '05192',
#  '05193',
#  '05194',
#  '05195',
#  '05196',
#  '05198',
#  '05200',
#  '05203',
#  '05205',
#  '05207',
#  '05210',
#  '05211',
#  '05213',
#  '05214',
#  '05215',
#  '05219',
#  '05220',
#  '05222',
#  '05223',
#  '05224',
#  '05225',
#  '05226',
#  '05228',
#  '05229',
#  '05233',
#  '05236',
#  '05237',
#  '05238',
#  '05240',
#  '05242',
#  '05244',
#  '05245',
#  '05246',
#  '05247',
#  '05248',
#  '05249',
#  '05250',
#  '05250\n',
#  '05251',
#  '05252',
#  '05253',
#  '05254',
#  '05256',
#  '05257',
#  '05258',
#  '05259',
#  '05260',
#  '05261',
#  '05264',
#  '05265',
#  '05291',
#  '05298',
#  '05300',
#  '05304',
#  '05310',
#  '05311',
#  '05312',
#  '05313',
#  '05314',
#  '05315',
#  '05316',
#  '05322',
#  '05323',
#  '05324',
#  '05325',
#  '05327',
#  '05328',
#  '05332',
#  '05335',
#  '05337',
#  '05338',
#  '05339',
#  '05340',
#  '05343',
#  '05344',
#  '05345',
#  '05346',
#  '05349',
#  '05350',
#  '05350ยอ',
#  '05351',
#  '05352',
#  '05354',
#  '05355',
#  '05356',
#  '05357',
#  '05358',
#  '05359',
#  '05360',
#  '05361',
#  '05363',
#  '05365',
#  '05366',
#  '05367',
#  '05368',
#  '05370',
#  '05371',
#  '05373',
#  '05378',
#  '05386',
#  '05391',
#  '05392',
#  '05393',
#  '05394',
#  '05395',
#  '05396',
#  '05413',
#  '05414',
#  '05415',
#  '05416',
#  '05418',
#  '05419',
#  '05422',
#  '05423',
#  '05424',
#  '05425',
#  '05428',
#  '05431',
#  '05432',
#  '05433',
#  '05434',
#  '05435',
#  '05436',
#  '05437',
#  '05439',
#  '05440',
#  '05441',
#  '05442',
#  '05541',
#  '06238',
#  '06251',
#  '06253',
#  '06254',
#  '06255',
#  '06256',
#  '06257',
#  '06259',
#  '06260',
#  '06261',
#  '06263',
#  '06265',
#  '06267',
#  '06268',
#  '06270',
#  '06271',
#  '06272',
#  '06273',
#  '06274',
#  '06275',
#  '06276',
#  '06277',
#  '06278',
#  '06279',
#  '06280',
#  '06281',
#  '06282',
#  '06283',
#  '06285',
#  '06286',
#  '06287',
#  '06288',
#  '06289',
#  '06290',
#  '06291',
#  '06292',
#  '06293',
#  '06294',
#  '06295',
#  '06296',
#  '06297',
#  '06298',
#  '06299',
#  '06300',
#  '06301',
#  '06302',
#  '06307',
#  '06308',
#  '06309',
#  '06310',
#  '06311',
#  '06312',
#  '06314',
#  '06315',
#  '06316',
#  '06318',
#  '06319',
#  '06320',
#  '06321',
#  '06322',
#  '06323',
#  '06324',
#  '06325',
#  '06326',
#  '06327',
#  '06328',
#  '06329',
#  '06330',
#  '06331',
#  '06332',
#  '06333',
#  '06334',
#  '10360',
#  '10673',
#  '11010',
#  '11055',
#  '11056',
#  '11057',
#  '11059',
#  '11060',
#  '11066',
#  '11069',
#  '11070',
#  '11072',
#  '11073',
#  '11084',
#  '11088',
#  '11158',
#  '11159',
#  '11160',
#  '11161',
#  '11163',
#  '11164',
#  '11165',
#  '11748',
#  '11749',
#  '13777',
#  '13937',
#  '13941',
#  '13943',
#  '13943\n\n',
#  '13944',
#  '13946',
#  '13947',
#  '13948',
#  '13949',
#  '13952',
#  '13953',
#  '13954',
#  '13955',
#  '13962',
#  '13963',
#  '13966',
#  '13984',
#  '14005',
#  '14007',
#  '14280',
#  '14284',
#  '14843',
#  '24650',
#  '27988',
#  '27990',
#  '28017',
#  '99795'}

# %% [markdown]
# เเก้ไขให้มีข้อมูลที่ถูกต้อง
#
# โดยกำหนดให้ข้อมูลที่ไม่ใช่เลข 5 หลัก เท่ากับ ข้อมูลว่าง

# %%
alldb_drop2['site'].replace({' 0502':None,
'05250\n':'05250',
'05350ยอ':'05350',
'13943\n\n':'13943',
'043.1':None
},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
alldb_drop3 = alldb_drop2.dropna() # ทำการ drop ค่าว่างออก 
alldb_drop3 # แสดงผลลัพธ์
# Out:
#         user                                RowKey       date  \
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1 2022-02-25
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 39722  76331                        bbrbiwclgv.png 2022-02-23
# 39782  76331                        lzzsckyyqs.png 2022-02-23
# 39791  76331                        pvpiawlexb.png 2022-02-23
# 39794  68317                        rtutxrlbam.png 2022-02-23
# 39795  68317                        dmuragqwza.png 2022-02-23
#
#                   phone   site      time            urine   ov PartitionKey  \
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0.0         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)  4.0        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)  4.0        00001
# 193          iPhone13,4  06302  10:16:46  ปกติ (เหลืองใส)  3.0        00001
# 194           iPhone9,4  05059  12:26:38  ปกติ (เหลืองใส)  3.0        00001
# ...                 ...    ...       ...              ...  ...          ...
# 39722  Samsung SM-G965U  05258  14:05:25  ปกติ (เหลืองใส)  0.0           61
# 39782  Samsung SM-G965U  05258  14:42:45  ปกติ (เหลืองใส)  0.0           89
# 39791  Samsung SM-G965U  05258  15:32:53  ปกติ (เหลืองใส)  1.0           92
# 39794  Samsung SM-A115F  28017  14:31:01  ปกติ (เหลืองใส)  2.0          976
# 39795  Samsung SM-A115F  28017  14:30:21  ปกติ (เหลืองใส)  2.0          983
#
#                        title                    age
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# 193                      นาง                     55
# 194                      นาย                     66
# ...                      ...                    ...
# 39722  data is not completed  data is not completed
# 39782  data is not completed  data is not completed
# 39791  data is not completed  data is not completed
# 39794  data is not completed  data is not completed
# 39795  data is not completed  data is not completed
#
# [37473 rows x 11 columns]

# %%
set(alldb_drop3['site']) # เพื่อดูข้อมูลทั้งหมดใน column site
# Out:
# {'00027',
#  '00040',
#  '00513',
#  '00579',
#  '00580',
#  '01151',
#  '02759',
#  '03432',
#  '03626',
#  '04275',
#  '04279',
#  '04280',
#  '04281',
#  '04302',
#  '04312',
#  '04313',
#  '04321',
#  '04322',
#  '04326',
#  '04337',
#  '04347',
#  '04349',
#  '04351',
#  '04352',
#  '04355',
#  '04374',
#  '04376',
#  '04380',
#  '04384',
#  '04387',
#  '04388',
#  '04390',
#  '04391',
#  '04396',
#  '04399',
#  '04401',
#  '04402',
#  '04403',
#  '04404',
#  '04405',
#  '04406',
#  '04407',
#  '04408',
#  '04433',
#  '04434',
#  '04435',
#  '04436',
#  '04437',
#  '04438',
#  '04441',
#  '04443',
#  '04455',
#  '04456',
#  '04457',
#  '04458',
#  '04475',
#  '04478',
#  '04558',
#  '04936',
#  '04968',
#  '04970',
#  '04971',
#  '04973',
#  '04974',
#  '04977',
#  '04980',
#  '04981',
#  '04982',
#  '04983',
#  '04984',
#  '04985',
#  '04986',
#  '04989',
#  '04990',
#  '04992',
#  '04993',
#  '04994',
#  '04995',
#  '04996',
#  '04997',
#  '04999',
#  '05000',
#  '05001',
#  '05002',
#  '05003',
#  '05004',
#  '05005',
#  '05006',
#  '05007',
#  '05008',
#  '05009',
#  '05010',
#  '05011',
#  '05012',
#  '05013',
#  '05015',
#  '05016',
#  '05019',
#  '05021',
#  '05022',
#  '05023',
#  '05024',
#  '05025',
#  '05026',
#  '05027',
#  '05028',
#  '05029',
#  '05032',
#  '05033',
#  '05034',
#  '05035',
#  '05038',
#  '05040',
#  '05042',
#  '05044',
#  '05045',
#  '05047',
#  '05048',
#  '05049',
#  '05052',
#  '05054',
#  '05055',
#  '05058',
#  '05059',
#  '05060',
#  '05061',
#  '05062',
#  '05063',
#  '05064',
#  '05065',
#  '05066',
#  '05067',
#  '05068',
#  '05069',
#  '05072',
#  '05074',
#  '05075',
#  '05077',
#  '05080',
#  '05081',
#  '05082',
#  '05083',
#  '05084',
#  '05086',
#  '05087',
#  '05088',
#  '05090',
#  '05091',
#  '05094',
#  '05097',
#  '05098',
#  '05100',
#  '05101',
#  '05102',
#  '05103',
#  '05107',
#  '05111',
#  '05112',
#  '05113',
#  '05115',
#  '05116',
#  '05117',
#  '05119',
#  '05120',
#  '05123',
#  '05125',
#  '05126',
#  '05128',
#  '05129',
#  '05131',
#  '05132',
#  '05133',
#  '05135',
#  '05136',
#  '05141',
#  '05143',
#  '05144',
#  '05146',
#  '05147',
#  '05152',
#  '05154',
#  '05157',
#  '05158',
#  '05162',
#  '05166',
#  '05172',
#  '05173',
#  '05175',
#  '05177',
#  '05178',
#  '05180',
#  '05181',
#  '05182',
#  '05185',
#  '05187',
#  '05188',
#  '05192',
#  '05193',
#  '05194',
#  '05195',
#  '05196',
#  '05198',
#  '05200',
#  '05203',
#  '05205',
#  '05207',
#  '05210',
#  '05211',
#  '05213',
#  '05214',
#  '05215',
#  '05219',
#  '05220',
#  '05222',
#  '05223',
#  '05224',
#  '05225',
#  '05226',
#  '05228',
#  '05229',
#  '05233',
#  '05236',
#  '05237',
#  '05238',
#  '05240',
#  '05242',
#  '05244',
#  '05245',
#  '05246',
#  '05247',
#  '05248',
#  '05249',
#  '05250',
#  '05251',
#  '05252',
#  '05253',
#  '05254',
#  '05256',
#  '05257',
#  '05258',
#  '05259',
#  '05260',
#  '05261',
#  '05264',
#  '05265',
#  '05291',
#  '05298',
#  '05300',
#  '05304',
#  '05310',
#  '05311',
#  '05312',
#  '05313',
#  '05314',
#  '05315',
#  '05316',
#  '05322',
#  '05323',
#  '05324',
#  '05325',
#  '05327',
#  '05328',
#  '05332',
#  '05335',
#  '05337',
#  '05338',
#  '05339',
#  '05340',
#  '05343',
#  '05344',
#  '05345',
#  '05346',
#  '05349',
#  '05350',
#  '05351',
#  '05352',
#  '05354',
#  '05355',
#  '05356',
#  '05357',
#  '05358',
#  '05359',
#  '05360',
#  '05361',
#  '05363',
#  '05365',
#  '05366',
#  '05367',
#  '05368',
#  '05370',
#  '05371',
#  '05373',
#  '05378',
#  '05386',
#  '05391',
#  '05392',
#  '05393',
#  '05394',
#  '05395',
#  '05396',
#  '05413',
#  '05414',
#  '05415',
#  '05416',
#  '05418',
#  '05419',
#  '05422',
#  '05423',
#  '05424',
#  '05425',
#  '05428',
#  '05431',
#  '05432',
#  '05433',
#  '05434',
#  '05435',
#  '05436',
#  '05437',
#  '05439',
#  '05440',
#  '05441',
#  '05442',
#  '05541',
#  '06238',
#  '06251',
#  '06253',
#  '06254',
#  '06255',
#  '06256',
#  '06257',
#  '06259',
#  '06260',
#  '06261',
#  '06263',
#  '06265',
#  '06267',
#  '06268',
#  '06270',
#  '06271',
#  '06272',
#  '06273',
#  '06274',
#  '06275',
#  '06276',
#  '06277',
#  '06278',
#  '06279',
#  '06280',
#  '06281',
#  '06282',
#  '06283',
#  '06285',
#  '06286',
#  '06287',
#  '06288',
#  '06289',
#  '06290',
#  '06291',
#  '06292',
#  '06293',
#  '06294',
#  '06295',
#  '06296',
#  '06297',
#  '06298',
#  '06299',
#  '06300',
#  '06301',
#  '06302',
#  '06307',
#  '06308',
#  '06309',
#  '06310',
#  '06311',
#  '06312',
#  '06314',
#  '06315',
#  '06316',
#  '06318',
#  '06319',
#  '06320',
#  '06321',
#  '06322',
#  '06323',
#  '06324',
#  '06325',
#  '06326',
#  '06327',
#  '06328',
#  '06329',
#  '06330',
#  '06331',
#  '06332',
#  '06333',
#  '06334',
#  '10360',
#  '10673',
#  '11010',
#  '11055',
#  '11056',
#  '11057',
#  '11059',
#  '11060',
#  '11066',
#  '11069',
#  '11070',
#  '11072',
#  '11073',
#  '11084',
#  '11088',
#  '11158',
#  '11159',
#  '11160',
#  '11161',
#  '11163',
#  '11164',
#  '11165',
#  '11748',
#  '11749',
#  '13777',
#  '13937',
#  '13941',
#  '13943',
#  '13944',
#  '13946',
#  '13947',
#  '13948',
#  '13949',
#  '13952',
#  '13953',
#  '13954',
#  '13955',
#  '13962',
#  '13963',
#  '13966',
#  '13984',
#  '14005',
#  '14007',
#  '14280',
#  '14284',
#  '14843',
#  '24650',
#  '27988',
#  '27990',
#  '28017',
#  '99795'}

# %%
alldb_drop3 = alldb_drop3[(alldb_drop3['site'].astype(str).str.isdigit()) & (alldb_drop3['site'].str.len() == 5 )] # เลือกข้อมูลที่เป็น 5 หลัก

# %%
alldb_drop3
# Out:
#         user                                RowKey       date  \
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1 2022-02-25
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 39722  76331                        bbrbiwclgv.png 2022-02-23
# 39782  76331                        lzzsckyyqs.png 2022-02-23
# 39791  76331                        pvpiawlexb.png 2022-02-23
# 39794  68317                        rtutxrlbam.png 2022-02-23
# 39795  68317                        dmuragqwza.png 2022-02-23
#
#                   phone   site      time            urine   ov PartitionKey  \
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0.0         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)  4.0        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)  4.0        00001
# 193          iPhone13,4  06302  10:16:46  ปกติ (เหลืองใส)  3.0        00001
# 194           iPhone9,4  05059  12:26:38  ปกติ (เหลืองใส)  3.0        00001
# ...                 ...    ...       ...              ...  ...          ...
# 39722  Samsung SM-G965U  05258  14:05:25  ปกติ (เหลืองใส)  0.0           61
# 39782  Samsung SM-G965U  05258  14:42:45  ปกติ (เหลืองใส)  0.0           89
# 39791  Samsung SM-G965U  05258  15:32:53  ปกติ (เหลืองใส)  1.0           92
# 39794  Samsung SM-A115F  28017  14:31:01  ปกติ (เหลืองใส)  2.0          976
# 39795  Samsung SM-A115F  28017  14:30:21  ปกติ (เหลืองใส)  2.0          983
#
#                        title                    age
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# 193                      นาง                     55
# 194                      นาย                     66
# ...                      ...                    ...
# 39722  data is not completed  data is not completed
# 39782  data is not completed  data is not completed
# 39791  data is not completed  data is not completed
# 39794  data is not completed  data is not completed
# 39795  data is not completed  data is not completed
#
# [37473 rows x 11 columns]

# %% [markdown]
# #### คอลัมน์ ov

# %%
set(alldb_drop3['ov']) # เพื่อดูข้อมูลทั้งหมดใน column ov
# Out:
# {0.0, 1.0, 2.0, 3.0, 4.0}

# %% [markdown]
# เเก้ไขให้มีข้อมูลที่ถูกต้อง
#
# โดยกำหนดให้ข้อมูลที่ไม่ใช่เลข  เท่ากับ ข้อมูลว่าง

# %%
alldb_drop3['ov'].replace({'ติดเชื้อ +2 ':None},inplace=True)

# %%
alldb_drop4 = alldb_drop3.dropna() # ทำการ drop ค่าว่างออก 
alldb_drop4 # แสดงผลลัพธ์
# Out:
#         user                                RowKey       date  \
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1 2022-02-25
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 39722  76331                        bbrbiwclgv.png 2022-02-23
# 39782  76331                        lzzsckyyqs.png 2022-02-23
# 39791  76331                        pvpiawlexb.png 2022-02-23
# 39794  68317                        rtutxrlbam.png 2022-02-23
# 39795  68317                        dmuragqwza.png 2022-02-23
#
#                   phone   site      time            urine   ov PartitionKey  \
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0.0         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)  4.0        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)  4.0        00001
# 193          iPhone13,4  06302  10:16:46  ปกติ (เหลืองใส)  3.0        00001
# 194           iPhone9,4  05059  12:26:38  ปกติ (เหลืองใส)  3.0        00001
# ...                 ...    ...       ...              ...  ...          ...
# 39722  Samsung SM-G965U  05258  14:05:25  ปกติ (เหลืองใส)  0.0           61
# 39782  Samsung SM-G965U  05258  14:42:45  ปกติ (เหลืองใส)  0.0           89
# 39791  Samsung SM-G965U  05258  15:32:53  ปกติ (เหลืองใส)  1.0           92
# 39794  Samsung SM-A115F  28017  14:31:01  ปกติ (เหลืองใส)  2.0          976
# 39795  Samsung SM-A115F  28017  14:30:21  ปกติ (เหลืองใส)  2.0          983
#
#                        title                    age
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# 193                      นาง                     55
# 194                      นาย                     66
# ...                      ...                    ...
# 39722  data is not completed  data is not completed
# 39782  data is not completed  data is not completed
# 39791  data is not completed  data is not completed
# 39794  data is not completed  data is not completed
# 39795  data is not completed  data is not completed
#
# [37473 rows x 11 columns]

# %%
set(alldb_drop4['ov']) # เพื่อดูข้อมูลทั้งหมดใน column ov
# Out:
# {0.0, 1.0, 2.0, 3.0, 4.0}

# %%
alldb_drop4['ov'] = alldb_drop4['ov'].astype(int) # เปลี่ยนข้อมูลจาก string เป็น int ในคอลัมน์ ov

# %%
alldb_drop4.dtypes # เช็คว่า ov ทั้งหมดเป็น int หรือไม่
# Out:
# user                    object
# RowKey                  object
# date            datetime64[ns]
# phone                   object
# site                    object
# time                    object
# urine                   object
# ov                       int64
# PartitionKey            object
# title                   object
# age                     object
# dtype: object

# %% [markdown]
# #### คอลัมน์ PartitionKey

# %%
set(alldb_drop4['PartitionKey']) # เพื่อดูข้อมูลทั้งหมดใน column PartitionKey
# Out:
# {'08942',
#  '00449',
#  '00467',
#  '00201',
#  '01156',
#  '08917',
#  '00110',
#  '02051',
#  '04171',
#  '03379',
#  '02177',
#  '02237',
#  '02158',
#  '06007',
#  '01986',
#  '06038',
#  '01285',
#  '01682',
#  '02292',
#  '03541',
#  '04665',
#  '01762',
#  '01417',
#  '05316',
#  '00836',
#  '03361',
#  '02796',
#  '04813',
#  '00726',
#  '02304',
#  '02671',
#  '00635',
#  '01985',
#  '02037',
#  '00889',
#  '01099',
#  '10978',
#  '01317',
#  '00921',
#  '01333',
#  '03178',
#  '00387',
#  '02180',
#  '00703',
#  '03295',
#  '01493',
#  '00235',
#  '01443',
#  '01226',
#  '00908',
#  '01513',
#  '03110',
#  '01641',
#  '02446',
#  '00029',
#  '00437',
#  '02752',
#  '00334',
#  '00620',
#  '02481',
#  '01740',
#  '08963',
#  '00130',
#  '04022',
#  '01808',
#  '02622',
#  '02761',
#  '02673',
#  '01570',
#  '02122',
#  '02135',
#  '01549',
#  '01791',
#  '00422',
#  '00622',
#  '00653',
#  '00906',
#  '02620',
#  '02400',
#  '03245',
#  '01224',
#  '06036',
#  '02737',
#  '01420',
#  '00569',
#  '01227',
#  '00637',
#  '02598',
#  '00135',
#  '01634',
#  '00123',
#  '00373',
#  '04253',
#  '01699',
#  '02078',
#  '05147',
#  '00446',
#  '01657',
#  '01174',
#  '00649',
#  '00941',
#  '00247',
#  '00360',
#  '00009',
#  '03154',
#  '01724',
#  '02651',
#  '00989',
#  '01589',
#  '00689',
#  '00674',
#  '00755',
#  '03279',
#  '02821',
#  '02199',
#  '01123',
#  '00092',
#  '04182',
#  '08974',
#  '00026',
#  '05986',
#  '01065',
#  '02353',
#  '05354',
#  '06008',
#  '02341',
#  '06730',
#  '01560',
#  '00682',
#  '00370',
#  '02042',
#  '02142',
#  '00421',
#  '01962',
#  '00396',
#  '02564',
#  '05121',
#  '05266',
#  '03254',
#  '00513',
#  '08988',
#  '01899',
#  '02034',
#  '01912',
#  '00666',
#  '00638',
#  '02076',
#  '00779',
#  '02287',
#  '02794',
#  '04028',
#  '01678',
#  '04188',
#  '00863',
#  '02398',
#  '00847',
#  '05153',
#  '02770',
#  '01616',
#  '01297',
#  '1022',
#  '02075',
#  '02333',
#  '00381',
#  '01157',
#  '00344',
#  '05108',
#  '02351',
#  '01748',
#  '00468',
#  '00624',
#  '03227',
#  '02334',
#  '09007',
#  '01812',
#  '01707',
#  '05102',
#  '10970',
#  '01787',
#  '02559',
#  '00749',
#  '02847',
#  '01915',
#  '02928',
#  '00140',
#  '02181',
#  '01416',
#  '02279',
#  '03188',
#  '04649',
#  '06022',
#  '01525',
#  '04017',
#  '06722',
#  '00340',
#  '00297',
#  '01265',
#  '01281',
#  '02242',
#  '00594',
#  '01143',
#  '01494',
#  '03104',
#  '00465',
#  '00469',
#  '01976',
#  '02262',
#  '01268',
#  '001',
#  '05098',
#  '04052',
#  '01695',
#  '04001',
#  '00173',
#  '01853',
#  '03981',
#  '00771',
#  '02205',
#  '00459',
#  '01107',
#  '01703',
#  '05107',
#  '01298',
#  '03438',
#  '00474',
#  '02727',
#  '04622',
#  '00414',
#  '02813',
#  '08067',
#  '00988',
#  '04118',
#  '01898',
#  '05336',
#  '00151',
#  '02500',
#  '00875',
#  '00629',
#  '01069',
#  '00495',
#  '02485',
#  '02031',
#  '01995',
#  '00580',
#  '00750',
#  '00792',
#  '00720',
#  '01507',
#  '03106',
#  '01080',
#  '10981',
#  '01114',
#  '00313',
#  '01909',
#  '01647',
#  '00598',
#  '01666',
#  '09017',
#  '00712',
#  '01241',
#  '01350',
#  '04683',
#  '00927',
#  '00996',
#  '00082',
#  '01034',
#  '01140',
#  '01928',
#  '02201',
#  '01449',
#  '00046',
#  '01058',
#  '02275',
#  '01504',
#  '01385',
#  '01282',
#  '09016',
#  '00981',
#  '01684',
#  '00336',
#  '01176',
#  '02670',
#  '02524',
#  '00911',
#  '00521',
#  '03310',
#  '02905',
#  '01172',
#  '01829',
#  '01044',
#  '00073',
#  '03909',
#  '05960',
#  '01137',
#  '02030',
#  '00551',
#  '08961',
#  '00342',
#  '03949',
#  '00494',
#  '02864',
#  '02258',
#  '03552',
#  '00662',
#  '00737',
#  '01228',
#  '01564',
#  '02563',
#  '00700',
#  '00825',
#  '00473',
#  '01470',
#  '02184',
#  '04186',
#  '01780',
#  '00830',
#  '02107',
#  '02451',
#  '01386',
#  '00920',
#  '01512',
#  '00484',
#  '01046',
#  '01913',
#  '02592',
#  '06042',
#  '04643',
#  '01457',
#  '04781',
#  '00543',
#  '02422',
#  '01028',
#  '01279',
#  '01629',
#  '01287',
#  '01274',
#  '02981',
#  '01747',
#  '11006',
#  '04693',
#  '00619',
#  '08951',
#  '01078',
#  '00241',
#  '00126',
#  '00301',
#  '01515',
#  '08968',
#  '01394',
#  '08971',
#  '00840',
#  '01013',
#  '02488',
#  '00284',
#  '01049',
#  '02771',
#  '02523',
#  '00426',
#  '02224',
#  '01948',
#  '03333',
#  '01445',
#  '01769',
#  '01848',
#  '02991',
#  '03547',
#  '00191',
#  '01880',
#  '00627',
#  '00541',
#  '01441',
#  '02832',
#  '04098',
#  '01650',
#  '01999',
#  '02507',
#  '01688',
#  '00933',
#  '00282',
#  '02099',
#  '01693',
#  '00100',
#  '01495',
#  '03506',
#  '00319',
#  '00633',
#  '02490',
#  '08962',
#  '02248',
#  '02639',
#  '01023',
#  '01427',
#  '00290',
#  '01532',
#  '03230',
#  '05111',
#  '00176',
#  '01945',
#  '04054',
#  '00240',
#  '04660',
#  '01483',
#  '01463',
#  '00113',
#  '01207',
#  '00886',
#  '09020',
#  '09025',
#  '09033',
#  '01141',
#  '00728',
#  '01818',
#  '05327',
#  '01796',
#  '00296',
#  '01514',
#  '01164',
#  '02112',
#  '01235',
#  '01256',
#  '01632',
#  '02017',
#  '02632',
#  '02348',
#  '03055',
#  '00973',
#  '06059',
#  '01896',
#  '00472',
#  '02664',
#  '02987',
#  '08928',
#  '04174',
#  '05290',
#  '02402',
#  '02494',
#  '00962',
#  '00356',
#  '00936',
#  '01820',
#  '02644',
#  '01094',
#  '09037',
#  '02211',
#  '01110',
#  '02833',
#  '01424',
#  '00386',
#  '02845',
#  '00782',
#  '01128',
#  '00734',
#  '02080',
#  '01410',
#  '05097',
#  '01921',
#  '01833',
#  '01827',
#  '00328',
#  '01312',
#  '03072',
#  '01070',
#  '02395',
#  '03339',
#  '02776',
#  '03019',
#  '09039',
#  '08945',
#  '02067',
#  '00504',
#  '01474',
#  '01330',
#  '01311',
#  '03056',
#  '01019',
#  '01591',
#  '01802',
#  '00735',
#  '0000',
#  '00778',
#  '00763',
#  '01741',
#  '06061',
#  '01245',
#  '01163',
#  '08921',
#  '00508',
#  '00014',
#  '01942',
#  '00023',
#  '00817',
#  '01210',
#  '02765',
#  '00239',
#  '00672',
#  '03403',
#  '00525',
#  '02338',
#  '03563',
#  '03325',
#  '01003',
#  '01859',
#  '01015',
#  '00609',
#  '01907',
#  '00795',
#  '01821',
#  '01758',
#  '08949',
#  '09009',
#  '01608',
#  '00952',
#  '02746',
#  '00065',
#  '06145',
#  '01795',
#  '02482',
#  '00305',
#  '00168',
#  '02160',
#  '02937',
#  '05106',
#  '00012',
#  '00590',
#  '00667',
#  '02647',
#  '00051',
#  '02900',
#  '00756',
#  '02803',
#  '01668',
#  '00556',
#  '00583',
#  '01798',
#  '00582',
#  '01865',
#  '01335',
#  '02189',
#  '02389',
#  '00124',
#  '00636',
#  '01234',
#  '00369',
#  '01328',
#  '01858',
#  '03220',
#  '00105',
#  '01087',
#  '02909',
#  '01923',
#  '00934',
#  '01676',
#  '00093',
#  '03351',
#  '00179',
#  '00397',
#  '05313',
#  '00776',
#  '01557',
#  '02952',
#  '00460',
#  '05262',
#  '03417',
#  '03932',
#  '01681',
#  '02896',
#  '01949',
#  '02561',
#  '01537',
#  '02854',
#  '00645',
#  '02404',
#  '00868',
#  '08941',
#  '01177',
#  '01902',
#  '04180',
#  '00382',
#  '01050',
#  '00812',
#  '01547',
#  '01562',
#  '02886',
#  '06725',
#  '00824',
#  '01275',
#  '00348',
#  '02743',
#  '04043',
#  '05204',
#  '08922',
#  '01096',
#  '04193',
#  '04730',
#  '04620',
#  '01939',
#  '03331',
#  '02638',
#  '09008',
#  '000167',
#  '01073',
#  '00696',
#  '00017',
#  '00394',
#  '00630',
#  '00957',
#  '01636',
#  '02439',
#  '02442',
#  '112',
#  '05717',
#  '00133',
#  '08932',
#  '02756',
#  '00937',
#  '00429',
#  '00013',
#  '05091',
#  '00193',
#  '01437',
#  '05994',
#  '06729',
#  '02039',
#  '03215',
#  '01989',
#  '04073',
#  '00560',
#  '05831',
#  '01175',
#  '01103',
#  '06720',
#  '09022',
#  '00692',
#  '00584',
#  '06033',
#  '05119',
#  '01958',
#  '00999',
#  '02714',
#  '04168',
#  '02110',
#  '01188',
#  '03499',
#  '11008',
#  '01467',
#  '02008',
#  '03305',
#  '01432',
#  '05129',
#  '00021',
#  '01195',
#  '01968',
#  '10984',
#  '00205',
#  '02424',
#  '05989',
#  '00862',
#  '00612',
#  '02093',
#  '04640',
#  '01089',
#  '01508',
#  '02476',
#  '01055',
#  '00993',
#  '00255',
#  '01476',
#  '01329',
#  '00571',
#  '02843',
#  '00879',
#  '00557',
#  '00925',
#  '00644',
#  '01487',
#  '00079',
#  '01286',
#  '01587',
#  '03356',
#  '02367',
#  '04095',
#  '01179',
#  '03804',
#  '00060',
#  '02585',
#  '03979',
#  '00445',
#  '01869',
#  '02403',
#  '02220',
#  '02935',
#  '00453',
#  '02863',
#  '00976',
#  '01485',
#  '00605',
#  '02406',
#  '04511',
#  '02222',
#  '01710',
#  '06046',
#  '00534',
#  '00170',
#  '02012',
#  '04020',
#  '00971',
#  '01194',
#  '09006',
#  '02950',
#  '03035',
#  '08957',
#  '03222',
#  '11000',
#  '00138',
#  '00768',
#  '01492',
#  '32',
#  '01171',
#  '02859',
#  '01192',
#  '04629',
#  '00533',
#  '03399',
#  '03515',
#  '00050',
#  '00854',
#  '05292',
#  '00380',
#  '03315',
#  '01473',
#  '01644',
#  '00681',
#  '01523',
#  '00561',
#  '00299',
#  '01883',
#  '04189',
#  '09015',
#  '01954',
#  '01972',
#  '02040',
#  '00839',
#  '02046',
#  '06055',
#  '04072',
#  '00071',
#  '01092',
#  '01201',
#  '03002',
#  '02071',
#  '05101',
#  '02499',
#  '04694',
#  '08915',
#  '03034',
#  '00302',
#  '00258',
#  '01006',
#  '00915',
#  '05830',
#  '00628',
#  '02162',
#  '02818',
#  '00858',
#  '00616',
#  '02253',
#  '10972',
#  '00098',
#  '00602',
#  '01645',
#  '01578',
#  '02668',
#  '01861',
#  '08902',
#  '00613',
#  '01794',
#  '02779',
#  '52',
#  '01052',
#  '09018',
#  '240',
#  '04631',
#  '01854',
#  '01755',
#  '01300',
#  '00025',
#  '01964',
#  '00430',
#  '02872',
#  '00363',
#  '01130',
#  '00132',
#  '00365',
#  '01579',
#  '01102',
#  '00891',
#  '03970',
#  '00664',
#  '03233',
#  '01007',
#  '01917',
#  '02819',
#  '00359',
#  '0010',
#  '01429',
#  '01994',
#  '02690',
#  '08956',
#  '01953',
#  '01118',
#  '05974',
#  '01914',
#  '02299',
#  '01559',
#  '01486',
#  '00401',
#  '01978',
#  '00481',
#  '01158',
#  '01605',
#  '06003',
#  '01825',
#  '01521',
#  '03508',
#  '02666',
#  '02532',
#  '00425',
#  '05982',
#  '01491',
#  '01956',
#  '08933',
#  '01071',
#  '10964',
#  '00212',
#  '00576',
#  '01392',
#  '00743',
#  '02228',
#  '01646',
#  '01352',
#  '00379',
#  '00881',
#  '03094',
#  '03108',
#  '05963',
#  '03269',
#  '02929',
#  '03997',
#  '00390',
#  '01919',
#  '01793',
#  '02495',
#  '10975',
#  '03406',
#  '03052',
#  '02579',
#  '00143',
#  '01846',
#  '000102',
#  '00984',
#  '00141',
#  '01725',
#  '02858',
#  '01191',
#  '00139',
#  '01334',
#  '00287',
#  '123',
#  '01407',
#  '01544',
#  '03334',
#  '02548',
#  '01165',
#  '04033',
#  '06047',
#  '153',
#  '00167',
#  '00754',
#  '02977',
#  '04165',
#  '02878',
#  '01081',
#  '00816',
#  '04619',
#  '02202',
#  '05094',
#  '00568',
#  '05724',
#  '01109',
#  '01033',
#  '00243',
#  '00035',
#  '01552',
#  '00514',
#  '01136',
#  '01761',
#  '01086',
#  '00333',
#  '02251',
#  '00505',
#  '01760',
#  '01380',
#  '01884',
#  '00376',
#  '00158',
#  '03381',
#  '00471',
#  '04653',
#  '00977',
#  '00572',
#  '02435',
#  '04735',
#  '10989',
#  '04754',
#  '01090',
#  '05155',
#  '05999',
#  '01575',
#  '00286',
#  '02584',
#  '00312',
#  '00236',
#  '01935',
#  '03496',
#  '01890',
#  '06045',
#  '01732',
#  '01588',
#  '02514',
#  '01669',
#  '02438',
#  '00658',
#  '01743',
#  '03411',
#  '08964',
#  '00209',
#  '03511',
#  '04143',
#  '03098',
#  '00237',
#  '01697',
#  '02125',
#  '03425',
#  '01097',
#  '00292',
#  '01716',
#  '00608',
#  '04100',
#  '01037',
#  '01850',
#  '01261',
#  '05716',
#  '01654',
#  '03527',
#  '00757',
#  '01022',
#  '00987',
#  '00894',
#  '00085',
#  '00913',
#  '00018',
#  '00094',
#  '01091',
#  '01400',
#  '02541',
#  '02204',
#  '01202',
#  '03708',
#  '01360',
#  '01184',
#  '01059',
#  '03124',
#  '04059',
#  '01295',
#  '01324',
#  '08919',
#  '00807',
#  '00968',
#  '03363',
#  '02014',
#  '04650',
#  '01271',
#  '01534',
#  '02120',
#  '04684',
#  '00872',
#  '00462',
#  '0023',
#  '01120',
#  '01178',
#  '02936',
#  '00623',
#  '00464',
#  '02096',
#  '00942',
#  '05244',
#  '08967',
#  '00819',
#  '02119',
#  '00947',
#  ...}

# %% [markdown]
# เเก้ไขให้มีข้อมูลที่ถูกต้อง
#
# โดยกำหนดให้ข้อมูลที่ไม่ใช่เลข 5 หลัก เท่ากับ ข้อมูลว่าง

# %%
alldb_drop4['PartitionKey'].replace({
'61':None,
'29':None,
'52':None,
'0083':None,
'000152':None,
'0034':None,
'23':None,
'219':None,
'185':None,
'00\u200b175':None,
'89':None,
'150':None,
'196':None,
'193':None,
'125':None,
'1881':None,
'32':None,
'124':None,
'112':None,
'00083\u200b':None,
'002.5':None                         
},inplace=True)

# %%
alldb_drop5 = alldb_drop4.dropna() # ทำการ drop ค่าว่างออก 
alldb_drop5 # แสดงผลลัพธ์
# Out:
#         user                                RowKey       date  \
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1 2022-02-25
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 39699  76331                        lbqlcrqxli.png 2022-02-23
# 39710  76331                        qofmbraznv.png 2022-02-23
# 39791  76331                        pvpiawlexb.png 2022-02-23
# 39794  68317                        rtutxrlbam.png 2022-02-23
# 39795  68317                        dmuragqwza.png 2022-02-23
#
#                   phone   site      time            urine  ov PartitionKey  \
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)   0         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)   4        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)   4        00001
# 193          iPhone13,4  06302  10:16:46  ปกติ (เหลืองใส)   3        00001
# 194           iPhone9,4  05059  12:26:38  ปกติ (เหลืองใส)   3        00001
# ...                 ...    ...       ...              ...  ..          ...
# 39699  Samsung SM-G965U  05258  14:22:42  ปกติ (เหลืองใส)   0           48
# 39710  Samsung SM-G965U  05258  14:08:37  ปกติ (เหลืองใส)   0           56
# 39791  Samsung SM-G965U  05258  15:32:53  ปกติ (เหลืองใส)   1           92
# 39794  Samsung SM-A115F  28017  14:31:01  ปกติ (เหลืองใส)   2          976
# 39795  Samsung SM-A115F  28017  14:30:21  ปกติ (เหลืองใส)   2          983
#
#                        title                    age
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# 193                      นาง                     55
# 194                      นาย                     66
# ...                      ...                    ...
# 39699  data is not completed  data is not completed
# 39710  data is not completed  data is not completed
# 39791  data is not completed  data is not completed
# 39794  data is not completed  data is not completed
# 39795  data is not completed  data is not completed
#
# [37452 rows x 11 columns]

# %%
set(alldb_drop5['PartitionKey']) # เพื่อดูข้อมูลทั้งหมดใน column PartitionKey
# Out:
# {'08942',
#  '00449',
#  '00467',
#  '00201',
#  '01156',
#  '08917',
#  '00110',
#  '02051',
#  '04171',
#  '03379',
#  '02177',
#  '02237',
#  '02158',
#  '06007',
#  '01986',
#  '06038',
#  '01285',
#  '01682',
#  '02292',
#  '03541',
#  '04665',
#  '01762',
#  '01417',
#  '05316',
#  '00836',
#  '03361',
#  '02796',
#  '04813',
#  '00726',
#  '02304',
#  '02671',
#  '00635',
#  '01985',
#  '02037',
#  '00889',
#  '01099',
#  '10978',
#  '01317',
#  '00921',
#  '01333',
#  '03178',
#  '00387',
#  '02180',
#  '00703',
#  '03295',
#  '01493',
#  '00235',
#  '01443',
#  '01226',
#  '00908',
#  '01513',
#  '03110',
#  '01641',
#  '02446',
#  '00029',
#  '00437',
#  '02752',
#  '00334',
#  '00620',
#  '02481',
#  '01740',
#  '08963',
#  '00130',
#  '04022',
#  '01808',
#  '02622',
#  '02761',
#  '02673',
#  '01570',
#  '02122',
#  '02135',
#  '01549',
#  '01791',
#  '00422',
#  '00622',
#  '00653',
#  '00906',
#  '02620',
#  '02400',
#  '03245',
#  '01224',
#  '06036',
#  '02737',
#  '01420',
#  '00569',
#  '01227',
#  '00637',
#  '02598',
#  '00135',
#  '01634',
#  '00123',
#  '00373',
#  '04253',
#  '01699',
#  '02078',
#  '05147',
#  '00446',
#  '01657',
#  '01174',
#  '00649',
#  '00941',
#  '00247',
#  '00360',
#  '00009',
#  '03154',
#  '01724',
#  '02651',
#  '00989',
#  '01589',
#  '00689',
#  '00674',
#  '00755',
#  '03279',
#  '02821',
#  '02199',
#  '01123',
#  '00092',
#  '04182',
#  '08974',
#  '00026',
#  '05986',
#  '01065',
#  '02353',
#  '05354',
#  '06008',
#  '02341',
#  '06730',
#  '01560',
#  '00682',
#  '00370',
#  '02042',
#  '02142',
#  '00421',
#  '01962',
#  '00396',
#  '02564',
#  '05121',
#  '05266',
#  '03254',
#  '00513',
#  '08988',
#  '01899',
#  '02034',
#  '01912',
#  '00666',
#  '00638',
#  '02076',
#  '00779',
#  '02287',
#  '02794',
#  '04028',
#  '01678',
#  '04188',
#  '00863',
#  '02398',
#  '00847',
#  '05153',
#  '02770',
#  '01616',
#  '01297',
#  '1022',
#  '02075',
#  '02333',
#  '00381',
#  '01157',
#  '00344',
#  '05108',
#  '02351',
#  '01748',
#  '00468',
#  '00624',
#  '03227',
#  '02334',
#  '09007',
#  '01812',
#  '01707',
#  '05102',
#  '10970',
#  '01787',
#  '02559',
#  '00749',
#  '02847',
#  '01915',
#  '02928',
#  '00140',
#  '02181',
#  '01416',
#  '02279',
#  '03188',
#  '04649',
#  '06022',
#  '01525',
#  '04017',
#  '06722',
#  '00340',
#  '00297',
#  '01265',
#  '01281',
#  '02242',
#  '00594',
#  '01143',
#  '01494',
#  '03104',
#  '00465',
#  '00469',
#  '01976',
#  '02262',
#  '01268',
#  '001',
#  '05098',
#  '04052',
#  '01695',
#  '04001',
#  '00173',
#  '01853',
#  '03981',
#  '00771',
#  '02205',
#  '00459',
#  '01107',
#  '01703',
#  '05107',
#  '01298',
#  '03438',
#  '00474',
#  '02727',
#  '04622',
#  '00414',
#  '02813',
#  '08067',
#  '00988',
#  '04118',
#  '01898',
#  '05336',
#  '00151',
#  '02500',
#  '00875',
#  '00629',
#  '01069',
#  '00495',
#  '02485',
#  '02031',
#  '01995',
#  '00580',
#  '00750',
#  '00792',
#  '00720',
#  '01507',
#  '03106',
#  '01080',
#  '10981',
#  '01114',
#  '00313',
#  '01909',
#  '01647',
#  '00598',
#  '01666',
#  '09017',
#  '00712',
#  '01241',
#  '01350',
#  '04683',
#  '00927',
#  '00996',
#  '00082',
#  '01034',
#  '01140',
#  '01928',
#  '02201',
#  '01449',
#  '00046',
#  '01058',
#  '02275',
#  '01504',
#  '01385',
#  '01282',
#  '09016',
#  '00981',
#  '01684',
#  '00336',
#  '01176',
#  '02670',
#  '02524',
#  '00911',
#  '00521',
#  '03310',
#  '02905',
#  '01172',
#  '01829',
#  '01044',
#  '00073',
#  '03909',
#  '05960',
#  '01137',
#  '02030',
#  '00551',
#  '08961',
#  '00342',
#  '03949',
#  '00494',
#  '02864',
#  '02258',
#  '03552',
#  '00662',
#  '00737',
#  '01228',
#  '01564',
#  '02563',
#  '00700',
#  '00825',
#  '00473',
#  '01470',
#  '02184',
#  '04186',
#  '01780',
#  '00830',
#  '02107',
#  '02451',
#  '01386',
#  '00920',
#  '01512',
#  '00484',
#  '01046',
#  '01913',
#  '02592',
#  '06042',
#  '04643',
#  '01457',
#  '04781',
#  '00543',
#  '02422',
#  '01028',
#  '01279',
#  '01629',
#  '01287',
#  '01274',
#  '02981',
#  '01747',
#  '11006',
#  '04693',
#  '00619',
#  '08951',
#  '01078',
#  '00241',
#  '00126',
#  '00301',
#  '01515',
#  '08968',
#  '01394',
#  '08971',
#  '00840',
#  '01013',
#  '02488',
#  '00284',
#  '01049',
#  '02771',
#  '02523',
#  '00426',
#  '02224',
#  '01948',
#  '03333',
#  '01445',
#  '01769',
#  '01848',
#  '02991',
#  '03547',
#  '00191',
#  '01880',
#  '00627',
#  '00541',
#  '01441',
#  '02832',
#  '04098',
#  '01650',
#  '01999',
#  '02507',
#  '01688',
#  '00933',
#  '00282',
#  '02099',
#  '01693',
#  '00100',
#  '01495',
#  '03506',
#  '00319',
#  '00633',
#  '02490',
#  '08962',
#  '02248',
#  '02639',
#  '01023',
#  '01427',
#  '00290',
#  '01532',
#  '03230',
#  '05111',
#  '00176',
#  '01945',
#  '04054',
#  '00240',
#  '04660',
#  '01483',
#  '01463',
#  '00113',
#  '01207',
#  '00886',
#  '09020',
#  '09025',
#  '09033',
#  '01141',
#  '00728',
#  '01818',
#  '05327',
#  '01796',
#  '00296',
#  '01514',
#  '01164',
#  '02112',
#  '01235',
#  '01256',
#  '01632',
#  '02017',
#  '02632',
#  '02348',
#  '03055',
#  '00973',
#  '06059',
#  '01896',
#  '00472',
#  '02664',
#  '02987',
#  '08928',
#  '04174',
#  '05290',
#  '02402',
#  '02494',
#  '00962',
#  '00356',
#  '00936',
#  '01820',
#  '02644',
#  '01094',
#  '09037',
#  '02211',
#  '01110',
#  '02833',
#  '01424',
#  '00386',
#  '02845',
#  '00782',
#  '01128',
#  '00734',
#  '02080',
#  '01410',
#  '05097',
#  '01921',
#  '01833',
#  '01827',
#  '00328',
#  '01312',
#  '03072',
#  '01070',
#  '02395',
#  '03339',
#  '02776',
#  '03019',
#  '09039',
#  '08945',
#  '02067',
#  '00504',
#  '01474',
#  '01330',
#  '01311',
#  '03056',
#  '01019',
#  '01591',
#  '01802',
#  '00735',
#  '0000',
#  '00778',
#  '00763',
#  '01741',
#  '06061',
#  '01245',
#  '01163',
#  '08921',
#  '00508',
#  '00014',
#  '01942',
#  '00023',
#  '00817',
#  '01210',
#  '02765',
#  '00239',
#  '00672',
#  '03403',
#  '00525',
#  '02338',
#  '03563',
#  '03325',
#  '01003',
#  '01859',
#  '01015',
#  '00609',
#  '01907',
#  '00795',
#  '01821',
#  '01758',
#  '08949',
#  '09009',
#  '01608',
#  '00952',
#  '02746',
#  '00065',
#  '06145',
#  '01795',
#  '02482',
#  '00305',
#  '00168',
#  '02160',
#  '02937',
#  '05106',
#  '00012',
#  '00590',
#  '00667',
#  '02647',
#  '00051',
#  '02900',
#  '00756',
#  '02803',
#  '01668',
#  '00556',
#  '00583',
#  '01798',
#  '00582',
#  '01865',
#  '01335',
#  '02189',
#  '02389',
#  '00124',
#  '00636',
#  '01234',
#  '00369',
#  '01328',
#  '01858',
#  '03220',
#  '00105',
#  '01087',
#  '02909',
#  '01923',
#  '00934',
#  '01676',
#  '00093',
#  '03351',
#  '00179',
#  '00397',
#  '05313',
#  '00776',
#  '01557',
#  '02952',
#  '00460',
#  '05262',
#  '03417',
#  '03932',
#  '01681',
#  '02896',
#  '01949',
#  '02561',
#  '01537',
#  '02854',
#  '00645',
#  '02404',
#  '00868',
#  '08941',
#  '01177',
#  '01902',
#  '04180',
#  '00382',
#  '01050',
#  '00812',
#  '01547',
#  '01562',
#  '02886',
#  '06725',
#  '00824',
#  '01275',
#  '00348',
#  '02743',
#  '04043',
#  '05204',
#  '08922',
#  '01096',
#  '04193',
#  '04730',
#  '04620',
#  '01939',
#  '03331',
#  '02638',
#  '09008',
#  '000167',
#  '01073',
#  '00696',
#  '00017',
#  '00394',
#  '00630',
#  '00957',
#  '01636',
#  '02439',
#  '02442',
#  '05717',
#  '00133',
#  '08932',
#  '02756',
#  '00937',
#  '00429',
#  '00013',
#  '05091',
#  '00193',
#  '01437',
#  '05994',
#  '06729',
#  '02039',
#  '03215',
#  '01989',
#  '04073',
#  '00560',
#  '05831',
#  '01175',
#  '01103',
#  '06720',
#  '09022',
#  '00692',
#  '00584',
#  '06033',
#  '05119',
#  '01958',
#  '00999',
#  '02714',
#  '04168',
#  '02110',
#  '01188',
#  '03499',
#  '11008',
#  '01467',
#  '02008',
#  '03305',
#  '01432',
#  '05129',
#  '00021',
#  '01195',
#  '01968',
#  '10984',
#  '00205',
#  '02424',
#  '05989',
#  '00862',
#  '00612',
#  '02093',
#  '04640',
#  '01089',
#  '01508',
#  '02476',
#  '01055',
#  '00993',
#  '00255',
#  '01476',
#  '01329',
#  '00571',
#  '02843',
#  '00879',
#  '00557',
#  '00925',
#  '00644',
#  '01487',
#  '00079',
#  '01286',
#  '01587',
#  '03356',
#  '02367',
#  '04095',
#  '01179',
#  '03804',
#  '00060',
#  '02585',
#  '03979',
#  '00445',
#  '01869',
#  '02403',
#  '02220',
#  '02935',
#  '00453',
#  '02863',
#  '00976',
#  '01485',
#  '00605',
#  '02406',
#  '04511',
#  '02222',
#  '01710',
#  '06046',
#  '00534',
#  '00170',
#  '02012',
#  '04020',
#  '00971',
#  '01194',
#  '09006',
#  '02950',
#  '03035',
#  '08957',
#  '03222',
#  '11000',
#  '00138',
#  '00768',
#  '01492',
#  '01171',
#  '02859',
#  '01192',
#  '04629',
#  '00533',
#  '03399',
#  '03515',
#  '00050',
#  '00854',
#  '05292',
#  '00380',
#  '03315',
#  '01473',
#  '01644',
#  '00681',
#  '01523',
#  '00561',
#  '00299',
#  '01883',
#  '04189',
#  '09015',
#  '01954',
#  '01972',
#  '02040',
#  '00839',
#  '02046',
#  '06055',
#  '04072',
#  '00071',
#  '01092',
#  '01201',
#  '03002',
#  '02071',
#  '05101',
#  '02499',
#  '04694',
#  '08915',
#  '03034',
#  '00302',
#  '00258',
#  '01006',
#  '00915',
#  '05830',
#  '00628',
#  '02162',
#  '02818',
#  '00858',
#  '00616',
#  '02253',
#  '10972',
#  '00098',
#  '00602',
#  '01645',
#  '01578',
#  '02668',
#  '01861',
#  '08902',
#  '00613',
#  '01794',
#  '02779',
#  '01052',
#  '09018',
#  '240',
#  '04631',
#  '01854',
#  '01755',
#  '01300',
#  '00025',
#  '01964',
#  '00430',
#  '02872',
#  '00363',
#  '01130',
#  '00132',
#  '00365',
#  '01579',
#  '01102',
#  '00891',
#  '03970',
#  '00664',
#  '03233',
#  '01007',
#  '01917',
#  '02819',
#  '00359',
#  '0010',
#  '01429',
#  '01994',
#  '02690',
#  '08956',
#  '01953',
#  '01118',
#  '05974',
#  '01914',
#  '02299',
#  '01559',
#  '01486',
#  '00401',
#  '01978',
#  '00481',
#  '01158',
#  '01605',
#  '06003',
#  '01825',
#  '01521',
#  '03508',
#  '02666',
#  '02532',
#  '00425',
#  '05982',
#  '01491',
#  '01956',
#  '08933',
#  '01071',
#  '10964',
#  '00212',
#  '00576',
#  '01392',
#  '00743',
#  '02228',
#  '01646',
#  '01352',
#  '00379',
#  '00881',
#  '03094',
#  '03108',
#  '05963',
#  '03269',
#  '02929',
#  '03997',
#  '00390',
#  '01919',
#  '01793',
#  '02495',
#  '10975',
#  '03406',
#  '03052',
#  '02579',
#  '00143',
#  '01846',
#  '000102',
#  '00984',
#  '00141',
#  '01725',
#  '02858',
#  '01191',
#  '00139',
#  '01334',
#  '00287',
#  '123',
#  '01407',
#  '01544',
#  '03334',
#  '02548',
#  '01165',
#  '04033',
#  '06047',
#  '153',
#  '00167',
#  '00754',
#  '02977',
#  '04165',
#  '02878',
#  '01081',
#  '00816',
#  '04619',
#  '02202',
#  '05094',
#  '00568',
#  '05724',
#  '01109',
#  '01033',
#  '00243',
#  '00035',
#  '01552',
#  '00514',
#  '01136',
#  '01761',
#  '01086',
#  '00333',
#  '02251',
#  '00505',
#  '01760',
#  '01380',
#  '01884',
#  '00376',
#  '00158',
#  '03381',
#  '00471',
#  '04653',
#  '00977',
#  '00572',
#  '02435',
#  '04735',
#  '10989',
#  '04754',
#  '01090',
#  '05155',
#  '05999',
#  '01575',
#  '00286',
#  '02584',
#  '00312',
#  '00236',
#  '01935',
#  '03496',
#  '01890',
#  '06045',
#  '01732',
#  '01588',
#  '02514',
#  '01669',
#  '02438',
#  '00658',
#  '01743',
#  '03411',
#  '08964',
#  '00209',
#  '03511',
#  '04143',
#  '03098',
#  '00237',
#  '01697',
#  '02125',
#  '03425',
#  '01097',
#  '00292',
#  '01716',
#  '00608',
#  '04100',
#  '01037',
#  '01850',
#  '01261',
#  '05716',
#  '01654',
#  '03527',
#  '00757',
#  '01022',
#  '00987',
#  '00894',
#  '00085',
#  '00913',
#  '00018',
#  '00094',
#  '01091',
#  '01400',
#  '02541',
#  '02204',
#  '01202',
#  '03708',
#  '01360',
#  '01184',
#  '01059',
#  '03124',
#  '04059',
#  '01295',
#  '01324',
#  '08919',
#  '00807',
#  '00968',
#  '03363',
#  '02014',
#  '04650',
#  '01271',
#  '01534',
#  '02120',
#  '04684',
#  '00872',
#  '00462',
#  '0023',
#  '01120',
#  '01178',
#  '02936',
#  '00623',
#  '00464',
#  '02096',
#  '00942',
#  '05244',
#  '08967',
#  '00819',
#  '02119',
#  '00947',
#  '02491',
#  '08069',
#  '03304',
#  ...}

# %%
alldb_drop5 = alldb_drop5[(alldb_drop5['PartitionKey'].astype(str).str.isdigit()) & (alldb_drop5['PartitionKey'].str.len() == 5 )] # เลือกข้อมูลที่เป็น 5 หลัก

# %%
alldb_drop5
# Out:
#         user                                RowKey       date       phone  \
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30  iPhone12,3
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30  iPhone14,3
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30  iPhone13,4
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29   iPhone9,4
# 195    28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402 2022-03-31  iPhone13,3
# ...      ...                                   ...        ...         ...
# 39416  26462                        ieotqfnqcq.png 2022-03-22   Vivo 1920
# 39417  26462                        cywpeqziic.png 2022-03-21   Vivo 1920
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7 2022-03-22  iPhone13,4
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC 2022-03-21  iPhone13,4
# 39420  26462                        vdxxgljykj.png 2022-03-21  Vivo V2050
#
#         site      time                             urine  ov PartitionKey  \
# 191    06307  14:46:08                   ปกติ (เหลืองใส)   4        00001
# 192    05328  15:27:45                   ปกติ (เหลืองใส)   4        00001
# 193    06302  10:16:46                   ปกติ (เหลืองใส)   3        00001
# 194    05059  12:26:38                   ปกติ (เหลืองใส)   3        00001
# 195    06334  14:57:41                   ปกติ (เหลืองใส)   0        00001
# ...      ...       ...                               ...  ..          ...
# 39416  11069  14:03:12                   ปกติ (เหลืองใส)   1        11003
# 39417  11069  13:59:04                   ปกติ (เหลืองใส)   2        11005
# 39418  11069  13:41:47                   ปกติ (เหลืองใส)   2        11006
# 39419  11069  14:17:46                   ปกติ (เหลืองใส)   0        11007
# 39420  11069  10:54:49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1        11008
#
#         title age
# 191    นางสาว  47
# 192       นาง  41
# 193       นาง  55
# 194       นาย  66
# 195    นางสาว  50
# ...       ...  ..
# 39416  นางสาว  33
# 39417     นาย  28
# 39418     นาง  72
# 39419     นาง  48
# 39420     นาย  36
#
# [37406 rows x 11 columns]

# %% [markdown]
# ### ทำการเเก้ไขข้อมูลให้ถูกต้อง ในรูปแบบที่กำหนด

# %% [markdown]
# #### คอลัมน์ time

# %%
alldb_drop5['time'] = alldb_drop5['time'].replace(':','-', regex=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
from functools import partial
to_datetime_fmt = partial(pd.to_datetime, format='%H:%M:%S')
alldb_drop5['time'] = alldb_drop5['time'].apply(to_datetime_fmt)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
alldb_drop5.dtypes
# Out:
# user                    object
# RowKey                  object
# date            datetime64[ns]
# phone                   object
# site                    object
# time            datetime64[ns]
# urine                   object
# ov                       int64
# PartitionKey            object
# title                   object
# age                     object
# dtype: object

# %% [markdown]
# ## ตาราง alldb หลังจัดการข้อมูลแล้ว

# %%
alldb_drop5 # ดูตาราง alldb หลังจัดการข้อมูลแล้ว
# Out:
#         user                                RowKey       date       phone  \
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30  iPhone12,3
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30  iPhone14,3
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30  iPhone13,4
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29   iPhone9,4
# 195    28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402 2022-03-31  iPhone13,3
# ...      ...                                   ...        ...         ...
# 39416  26462                        ieotqfnqcq.png 2022-03-22   Vivo 1920
# 39417  26462                        cywpeqziic.png 2022-03-21   Vivo 1920
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7 2022-03-22  iPhone13,4
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC 2022-03-21  iPhone13,4
# 39420  26462                        vdxxgljykj.png 2022-03-21  Vivo V2050
#
#         site                time                             urine  ov  \
# 191    06307 1900-01-01 14:46:08                   ปกติ (เหลืองใส)   4
# 192    05328 1900-01-01 15:27:45                   ปกติ (เหลืองใส)   4
# 193    06302 1900-01-01 10:16:46                   ปกติ (เหลืองใส)   3
# 194    05059 1900-01-01 12:26:38                   ปกติ (เหลืองใส)   3
# 195    06334 1900-01-01 14:57:41                   ปกติ (เหลืองใส)   0
# ...      ...                 ...                               ...  ..
# 39416  11069 1900-01-01 14:03:12                   ปกติ (เหลืองใส)   1
# 39417  11069 1900-01-01 13:59:04                   ปกติ (เหลืองใส)   2
# 39418  11069 1900-01-01 13:41:47                   ปกติ (เหลืองใส)   2
# 39419  11069 1900-01-01 14:17:46                   ปกติ (เหลืองใส)   0
# 39420  11069 1900-01-01 10:54:49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1
#
#       PartitionKey   title age
# 191          00001  นางสาว  47
# 192          00001     นาง  41
# 193          00001     นาง  55
# 194          00001     นาย  66
# 195          00001  นางสาว  50
# ...            ...     ...  ..
# 39416        11003  นางสาว  33
# 39417        11005     นาย  28
# 39418        11006     นาง  72
# 39419        11007     นาง  48
# 39420        11008     นาย  36
#
# [37406 rows x 11 columns]

# %% [markdown]
# ## จัดการข้อมูลหลัก ตาราง hospital_list.xlsx

# %%
hospital_list # แสดงข้อมูลตาราง hospital_list.xlsx
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5  code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อท           ATG
# ...                         ...    ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
#
# [17103 rows x 16 columns]

# %% [markdown]
# ### ตรวจสอบค่า Missing

# %%
hospital_list.isnull().any() 
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# hcode            False
# name              True
# zone_code        False
# zone_name         True
# provincecode      True
# province         False
# amphurcode        True
# amphur            True
# tamboncode        True
# tambon            True
# code4             True
# name5             True
# code9             True
# name10            True
# short_thai        True
# short_english     True
# dtype: bool

# %% [markdown]
# ### ใช้ .dropna ซึ่งจะใช้ตัดแถวข้อมูลที่มีค่า missing

# %%
h_drop = hospital_list.dropna() #ใช้ dropna เพื่อต้องการลบข้อมูลทั้งแถวออกเมื่อมีคอลัมน์ใดคอลัมน์หนึ่งเป็น NaN
h_drop
# Out:
#        hcode                                               name  zone_code  \
# 931    00933              โรงพยาบาลส่งเสริมสุขภาพตำบลสำโรงเหนือ          6
# 932    00934                โรงพยาบาลส่งเสริมสุขภาพตำบลบางเมือง          6
# 933    00935  โรงพยาบาลส่งเสริมสุขภาพตำบลเฉลิมพระเกียรติ บ้า...          6
# 934    00936               โรงพยาบาลส่งเสริมสุขภาพตำบลบางปูใหม่          6
# 935    00937                  โรงพยาบาลส่งเสริมสุขภาพตำบลแพรกษา          6
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 931          สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 932          สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 933          สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 934          สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 935          สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode      tambon  code4  \
# 931    เมืองสมุทรปราการ         2.0  สำโรงเหนือ   18.0
# 932    เมืองสมุทรปราการ         3.0    บางเมือง   18.0
# 933    เมืองสมุทรปราการ         3.0    บางเมือง   18.0
# 934    เมืองสมุทรปราการ         8.0   บางปูใหม่   18.0
# 935    เมืองสมุทรปราการ        10.0      แพรกษา   18.0
# ...                 ...         ...         ...    ...
# 17098    เมืองอุตรดิตถ์         1.0      ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0     กุยบุรี    8.0
# 17100           วัดเพลง         3.0     วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0      โพนข่า    8.0
# 17102             บางแพ         2.0     วังเย็น    8.0
#
#                              name5  code9     name10 short_thai short_english
# 931    โรงพยาบาลส่งเสริมสุขภาพตำบล   10.0  1 ปฐมภูมิ         สป           SPK
# 932    โรงพยาบาลส่งเสริมสุขภาพตำบล   10.0  1 ปฐมภูมิ         สป           SPK
# 933    โรงพยาบาลส่งเสริมสุขภาพตำบล   10.0  1 ปฐมภูมิ         สป           SPK
# 934    โรงพยาบาลส่งเสริมสุขภาพตำบล   10.0  1 ปฐมภูมิ         สป           SPK
# 935    โรงพยาบาลส่งเสริมสุขภาพตำบล   10.0  1 ปฐมภูมิ         สป           SPK
# ...                            ...    ...        ...        ...           ...
# 17098     ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         อต           UTT
# 17099     ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ปข           PKN
# 17100     ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
# 17101     ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ศก           SSK
# 17102     ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
#
# [11798 rows x 16 columns]

# %%
h_drop.shape #ตรวจสอบขนาดของตารางใหม่
# Out:
# (11798, 16)

# %%
removes = hospital_list.shape[0] - h_drop.shape[0]
print(f'size before drop = {hospital_list.shape[0]}')
print(f'size after drop = {h_drop.shape[0]}')
print(f'% from drop = {(removes/hospital_list.shape[0])*100}')
 # จากการคำนวณพบว่ามีข้อมูลที่หายไปถึง 31% ดังนั้น จึงไม่สามารถใช้การ .dropna() ได ้
# Out:
# size before drop = 17103
# size after drop = 11798
# % from drop = 31.017950067239664

# %%
hospital_list[['name']] = hospital_list[['name']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
hospital_list[['zone_name']] = hospital_list[['zone_name']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
p = hospital_list[['provincecode']].mean() #กำหนดให้ provincecode เป็นค่าเฉลี่ยของ provincecode
hospital_list[['provincecode']] = hospital_list[['provincecode']].fillna(p) #แทนค่าเฉลี่ยลงในข้อมูลที่ว่าง หรือเป็นค่า missing

# %%
a = hospital_list[['amphurcode']].mean() #กำหนดให้ amphurcode เป็นค่าเฉลี่ยของ amphurcode
hospital_list[['amphurcode']] = hospital_list[['amphurcode']].fillna(a) #แทนค่าเฉลี่ยลงในข้อมูลที่ว่าง หรือเป็นค่า missing

# %%
hospital_list[['amphur']] = hospital_list[['amphur']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
t = hospital_list[['tamboncode']].mean() #กำหนดให้ tamboncode เป็นค่าเฉลี่ยของ tamboncode
hospital_list[['tamboncode']] = hospital_list[['tamboncode']].fillna(t) #แทนค่าเฉลี่ยลงในข้อมูลที่ว่าง หรือเป็นค่า missing

# %%
hospital_list[['tambon']] = hospital_list[['tambon']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
c = hospital_list[['code4']].mean() #กำหนดให้ code4 เป็นค่าเฉลี่ยของ code4
hospital_list[['code4']] = hospital_list[['code4']].fillna(c) #แทนค่าเฉลี่ยลงในข้อมูลที่ว่าง หรือเป็นค่า missing

# %%
hospital_list[['name5']] = hospital_list[['name5']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
c2 = hospital_list[['code9']].mean() #กำหนดให้ code9 เป็นค่าเฉลี่ยของ code9
hospital_list[['code9']] = hospital_list[['code9']].fillna(c2) #แทนค่าเฉลี่ยลงในข้อมูลที่ว่าง หรือเป็นค่า missing

# %%
hospital_list[['name10']] = hospital_list[['name10']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
hospital_list[['short_thai']] = hospital_list[['short_thai']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
hospital_list[['short_english']] = hospital_list[['short_english']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
hospital_list.isnull().any() 
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# hcode            False
# name             False
# zone_code        False
# zone_name        False
# provincecode     False
# province         False
# amphurcode       False
# amphur           False
# tamboncode       False
# tambon           False
# code4            False
# name5            False
# code9            False
# name10           False
# short_thai       False
# short_english    False
# dtype: bool

# %% [markdown]
# ### ทำการเปลี่ยน type ของข้อมูลให้เป็น type ที่ถูกต้อง

# %%
hospital_list.dtypes # เช็คว่าข้อมูลมี่ความตรงกับที่ต้องการหรือไม่ ## ต้องการให้ hcode เป็น int
# Out:
# hcode             object
# name              object
# zone_code          int64
# zone_name         object
# provincecode     float64
# province          object
# amphurcode       float64
# amphur            object
# tamboncode       float64
# tambon            object
# code4            float64
# name5             object
# code9            float64
# name10            object
# short_thai        object
# short_english     object
# dtype: object

# %%
set(hospital_list['hcode']) # เพื่อดูข้อมูลทั้งหมดใน column hcode
# Out:
# {'11644',
#  '05769',
#  '00467',
#  '05072',
#  '02283',
#  '03867',
#  '04171',
#  '04409',
#  '06110',
#  '08150',
#  '10937',
#  '11119',
#  '14421',
#  '06646',
#  '77695',
#  '10835',
#  '07740',
#  '01986',
#  '10829',
#  '19484',
#  '28772',
#  '04278',
#  '02729',
#  '06460',
#  '26357',
#  '22867',
#  '04665',
#  '04554',
#  '07583',
#  '11708',
#  '21665',
#  '06153',
#  '09663',
#  '14418',
#  '23964',
#  '24749',
#  '07866',
#  '08079',
#  '24011',
#  '07088',
#  '05316',
#  '08694',
#  '09315',
#  '03361',
#  '05879',
#  '14345',
#  '10159',
#  '08751',
#  '22970',
#  '00726',
#  '24086',
#  '06465',
#  '26029',
#  '10381',
#  '04156',
#  '07262',
#  '07482',
#  '08781',
#  '10165',
#  '24938',
#  '10978',
#  '11849',
#  '14108',
#  '24534',
#  '28593',
#  '05664',
#  '25619',
#  '07848',
#  '12243',
#  '08416',
#  '05601',
#  '10866',
#  '02180',
#  '14649',
#  '00703',
#  '10909',
#  '14245',
#  '16236',
#  '03911',
#  '01226',
#  '08886',
#  '24078',
#  '08531',
#  '24460',
#  '10899',
#  '01641',
#  '03745',
#  '08753',
#  '11402',
#  '25196',
#  '03166',
#  '26276',
#  '26326',
#  '00437',
#  '02752',
#  '14808',
#  '24573',
#  '28688',
#  '09585',
#  '26179',
#  '01740',
#  '04797',
#  '09424',
#  '25861',
#  '11371',
#  '04578',
#  '05370',
#  '09051',
#  '09893',
#  '04243',
#  '04627',
#  '10586',
#  '05134',
#  '23973',
#  '01570',
#  '02649',
#  '28166',
#  '02135',
#  '05389',
#  '11051',
#  '01791',
#  '00422',
#  '10498',
#  '08071',
#  '00622',
#  '05856',
#  '77768',
#  '27430',
#  '07598',
#  '13657',
#  '01224',
#  '14312',
#  '24471',
#  '10697',
#  '12195',
#  '24515',
#  '01420',
#  '24784',
#  '03449',
#  '24953',
#  '26971',
#  '06816',
#  '07577',
#  '25050',
#  '14147',
#  '26701',
#  '24379',
#  '06561',
#  '77652',
#  '00373',
#  '02193',
#  '07488',
#  '28792',
#  '08285',
#  '05447',
#  '23554',
#  '25588',
#  '23788',
#  '01657',
#  '04926',
#  '05991',
#  '26996',
#  '00649',
#  '13943',
#  '27561',
#  '07958',
#  '05151',
#  '10767',
#  '06994',
#  '23869',
#  '22865',
#  '01724',
#  '14098',
#  '27688',
#  '10176',
#  '08273',
#  '24393',
#  '26810',
#  '00674',
#  '05734',
#  '06613',
#  '08667',
#  '04182',
#  '04083',
#  '14305',
#  '10585',
#  '01065',
#  '08540',
#  '15207',
#  '22799',
#  '03952',
#  '08894',
#  '00370',
#  '28857',
#  '09622',
#  '25938',
#  '07191',
#  '25643',
#  '03382',
#  '02564',
#  '04365',
#  '05121',
#  '07330',
#  '08280',
#  '05266',
#  '23944',
#  '03955',
#  '06504',
#  '08988',
#  '09221',
#  '02034',
#  '03131',
#  '27055',
#  '02794',
#  '02445',
#  '04733',
#  '26999',
#  '10394',
#  '25688',
#  '24955',
#  '16332',
#  '27011',
#  '28061',
#  '00847',
#  '06523',
#  '09289',
#  '04731',
#  '02260',
#  '08073',
#  '15982',
#  '08116',
#  '03465',
#  '06547',
#  '00381',
#  '06101',
#  '04719',
#  '10383',
#  '00468',
#  '04058',
#  '06369',
#  '01812',
#  '09179',
#  '11221',
#  '01707',
#  '14043',
#  '04596',
#  '14097',
#  '10970',
#  '23004',
#  '26227',
#  '27746',
#  '04579',
#  '08036',
#  '19349',
#  '23027',
#  '23890',
#  '28225',
#  '02847',
#  '07056',
#  '24710',
#  '00140',
#  '10948',
#  '25781',
#  '11668',
#  '06119',
#  '03188',
#  '04649',
#  '01525',
#  '08478',
#  '12246',
#  '02242',
#  '10587',
#  '17133',
#  '23729',
#  '77753',
#  '08502',
#  '28079',
#  '28154',
#  '06971',
#  '08476',
#  '11475',
#  '23032',
#  '25668',
#  '03582',
#  '28160',
#  '03029',
#  '10802',
#  '27440',
#  '11728',
#  '04204',
#  '04484',
#  '08728',
#  '09224',
#  '10426',
#  '23996',
#  '06941',
#  '06135',
#  '07508',
#  '02205',
#  '07096',
#  '09547',
#  '10707',
#  '01107',
#  '05107',
#  '01703',
#  '04249',
#  '07420',
#  '22802',
#  '24875',
#  '05324',
#  '22863',
#  '05504',
#  '00474',
#  '10142',
#  '07092',
#  '27538',
#  '24132',
#  '08067',
#  '04829',
#  '05753',
#  '06877',
#  '06833',
#  '24333',
#  '09274',
#  '02500',
#  '07703',
#  '11955',
#  '28850',
#  '10208',
#  '04532',
#  '05053',
#  '03722',
#  '00495',
#  '22744',
#  '24169',
#  '26669',
#  '02255',
#  '28197',
#  '07556',
#  '08276',
#  '00580',
#  '00750',
#  '09272',
#  '01507',
#  '04062',
#  '06180',
#  '11333',
#  '01080',
#  '14378',
#  '22302',
#  '01114',
#  '11374',
#  '24561',
#  '07578',
#  '01909',
#  '23995',
#  '26247',
#  '09017',
#  '01666',
#  '04176',
#  '07223',
#  '01350',
#  '28437',
#  '07497',
#  '11496',
#  '05372',
#  '13826',
#  '04552',
#  '01928',
#  '07434',
#  '09269',
#  '13717',
#  '24079',
#  '00046',
#  '26673',
#  '06357',
#  '15191',
#  '28698',
#  '03226',
#  '24091',
#  '08256',
#  '28741',
#  '08078',
#  '00336',
#  '03857',
#  '99851',
#  '07962',
#  '02905',
#  '24778',
#  '25691',
#  '06272',
#  '01829',
#  '07123',
#  '28530',
#  '24070',
#  '02590',
#  '11614',
#  '04531',
#  '09685',
#  '26993',
#  '06875',
#  '07634',
#  '23865',
#  '04450',
#  '11372',
#  '07811',
#  '09366',
#  '00342',
#  '14366',
#  '10722',
#  '02296',
#  '14595',
#  '14692',
#  '26720',
#  '28427',
#  '02615',
#  '11050',
#  '04186',
#  '05180',
#  '24063',
#  '00830',
#  '03820',
#  '06546',
#  '03371',
#  '22183',
#  '02451',
#  '12471',
#  '27415',
#  '27611',
#  '01386',
#  '07161',
#  '00920',
#  '05417',
#  '10000',
#  '11164',
#  '01046',
#  '02927',
#  '12072',
#  '13825',
#  '03905',
#  '24605',
#  '07963',
#  '11425',
#  '14042',
#  '04643',
#  '26149',
#  '08861',
#  '00543',
#  '03080',
#  '15005',
#  '03118',
#  '03307',
#  '21809',
#  '06390',
#  '01028',
#  '18595',
#  '01279',
#  '01629',
#  '28133',
#  '10709',
#  '03476',
#  '23887',
#  '13993',
#  '26966',
#  '77751',
#  '23836',
#  '11157',
#  '14367',
#  '25849',
#  '14064',
#  '24816',
#  '07207',
#  '10196',
#  '01078',
#  '07808',
#  '00126',
#  '24549',
#  '03175',
#  '06236',
#  '14719',
#  '10743',
#  '05754',
#  '02415',
#  '08208',
#  '08971',
#  '18092',
#  '04557',
#  '06175',
#  '23564',
#  '25919',
#  '26278',
#  '09497',
#  '28802',
#  '08231',
#  '28824',
#  '05778',
#  '19566',
#  '25750',
#  '28147',
#  '03185',
#  '24671',
#  '26126',
#  '06184',
#  '03333',
#  '14062',
#  '01769',
#  '02991',
#  '03547',
#  '03198',
#  '01880',
#  '05556',
#  '09486',
#  '11535',
#  '11543',
#  '07802',
#  '25718',
#  '12046',
#  '09218',
#  '02507',
#  '06025',
#  '23538',
#  '01688',
#  '11118',
#  '07384',
#  '08149',
#  '03615',
#  '27439',
#  '28789',
#  '24015',
#  '11276',
#  '99925',
#  '28093',
#  '00282',
#  '02099',
#  '04513',
#  '04941',
#  '07680',
#  '27991',
#  '27754',
#  '02490',
#  '06625',
#  '06244',
#  '16086',
#  '00290',
#  '25894',
#  '12191',
#  '08890',
#  '08295',
#  '20332',
#  '09583',
#  '09025',
#  '03163',
#  '04460',
#  '14143',
#  '01818',
#  '00728',
#  '05179',
#  '03289',
#  '20202',
#  '23909',
#  '05544',
#  '12204',
#  '28314',
#  '26041',
#  '11592',
#  '07845',
#  '24789',
#  '02112',
#  '25806',
#  '06156',
#  '11799',
#  '01632',
#  '02017',
#  '02503',
#  '02632',
#  '04856',
#  '26112',
#  '06878',
#  '26719',
#  '04402',
#  '23717',
#  '07624',
#  '14210',
#  '24810',
#  '24659',
#  '14710',
#  '23620',
#  '09276',
#  '06400',
#  '10082',
#  '09561',
#  '13812',
#  '04410',
#  '06764',
#  '00962',
#  '05032',
#  '24668',
#  '27414',
#  '26303',
#  '27743',
#  '15009',
#  '25678',
#  '11296',
#  '28278',
#  '09037',
#  '08452',
#  '10029',
#  '00386',
#  '15181',
#  '02845',
#  '26635',
#  '05590',
#  '11446',
#  '01128',
#  '22812',
#  '14289',
#  '01410',
#  '28590',
#  '01921',
#  '03216',
#  '08678',
#  '10880',
#  '09815',
#  '10153',
#  '14341',
#  '24351',
#  '03575',
#  '10873',
#  '27476',
#  '03072',
#  '14900',
#  '28672',
#  '04549',
#  '08505',
#  '28723',
#  '15863',
#  '25036',
#  '11876',
#  '05859',
#  '24197',
#  '24933',
#  '24102',
#  '09135',
#  '08234',
#  '24496',
#  '02067',
#  '00504',
#  '10851',
#  '01330',
#  '01311',
#  '06651',
#  '01802',
#  '05729',
#  '23837',
#  '00778',
#  '07772',
#  '08921',
#  '99772',
#  '00508',
#  '03076',
#  '06716',
#  '04493',
#  '09332',
#  '00239',
#  '00672',
#  '10548',
#  '27637',
#  '27641',
#  '08386',
#  '03563',
#  '10061',
#  '02192',
#  '24119',
#  '99930',
#  '01003',
#  '08454',
#  '01859',
#  '13778',
#  '07381',
#  '25897',
#  '05731',
#  '22831',
#  '01907',
#  '06328',
#  '05474',
#  '11621',
#  '22779',
#  '10611',
#  '11854',
#  '07210',
#  '14967',
#  '04476',
#  '11338',
#  '02746',
#  '00065',
#  '10425',
#  '22763',
#  '25671',
#  '06611',
#  '25724',
#  '11237',
#  '05065',
#  '25221',
#  '08389',
#  '08754',
#  '08312',
#  '28828',
#  '10831',
#  '27646',
#  '00667',
#  '06653',
#  '08800',
#  '99880',
#  '09242',
#  '04773',
#  '24838',
#  '00756',
#  '28362',
#  '24551',
#  '00582',
#  '11132',
#  '09365',
#  '02942',
#  '03077',
#  '05375',
#  '00636',
#  '26077',
#  '26298',
#  '17901',
#  '24630',
#  '08516',
#  '25614',
#  '03680',
#  '08698',
#  '21308',
#  '10372',
#  '09386',
#  '24152',
#  '00934',
#  '06567',
#  '10735',
#  '25115',
#  '00397',
#  '26981',
#  '24117',
#  '04604',
#  '07051',
#  '26769',
#  '28620',
#  '00460',
#  '04198',
#  '05262',
#  '14133',
#  '03417',
#  '03656',
#  '25224',
#  '01681',
#  '10887',
#  '18769',
#  '05398',
#  '05415',
#  '27380',
#  '09171',
#  '13649',
#  '05471',
#  '04242',
#  '08651',
#  '08835',
#  '20007',
#  '07717',
#  '26691',
#  '07617',
#  '01902',
#  '14034',
#  '24022',
#  '10958',
#  '12065',
#  '01562',
#  '02462',
#  '02817',
#  '09350',
#  '24739',
#  '01275',
#  '09485',
#  '24251',
#  '02695',
#  '09601',
#  '07077',
#  '11578',
#  '07580',
#  '03778',
#  '04193',
#  '07753',
#  '11203',
#  '05751',
#  '03750',
#  '24535',
#  '03016',
#  '02554',
#  '07422',
#  '03694',
#  '27450',
#  '23811',
#  '25653',
#  '04491',
#  '09282',
#  '01636',
#  '02442',
#  '12451',
#  '01604',
#  '05717',
#  '03719',
#  '13957',
#  '10742',
#  '11354',
#  '07541',
#  '06601',
#  '06729',
#  '27620',
#  '02039',
#  '00560',
#  '06781',
#  '08044',
#  '03987',
#  '01103',
#  '06720',
#  '21714',
#  '08173',
#  '09104',
#  '05009',
#  '04161',
#  '09901',
#  '01958',
#  '09191',
#  '02110',
#  '07939',
#  '02635',
#  '15242',
#  '07312',
#  '03594',
#  '07468',
#  '06174',
#  '19350',
#  '01432',
#  '23874',
#  '11366',
#  '28194',
#  '00205',
#  '07489',
#  '08834',
#  '00862',
#  '03022',
#  '09457',
#  '26295',
#  '02093',
#  '04796',
#  '06408',
#  '09420',
#  '05023',
#  '03572',
#  '05358',
#  '28068',
#  '08705',
#  '08159',
#  '16663',
#  '14591',
#  '01329',
#  '08608',
#  '07944',
#  '00879',
#  '08340',
#  '26238',
#  '00557',
#  '00644',
#  '05669',
#  '77662',
#  '21440',
#  '04605',
#  '03804',
#  '02585',
#  '02403',
#  '07773',
#  '09449',
#  '03741',
#  '26918',
#  '14051',
#  '22128',
#  '16881',
#  '01710',
#  '06046',
#  '07255',
#  '24812',
#  '02012',
#  '26285',
#  '23948',
#  '26906',
#  '06084',
#  '04767',
#  '08957',
#  '09006',
#  '03222',
#  '07658',
#  '08214',
#  '10189',
#  '03847',
#  '05058',
#  '00138',
#  '01492',
#  '08055',
#  '13646',
#  '23958',
#  '27426',
#  '03149',
#  '01171',
#  '04510',
#  '07678',
#  '09433',
#  '02859',
#  '11324',
#  '09097',
#  '06103',
#  '26319',
#  '00050',
#  '04040',
#  '24913',
#  '11083',
#  '02697',
#  '28634',
#  '10141',
#  '00380',
#  '26019',
#  '03456',
#  '03102',
#  '01523',
#  '25707',
#  '11559',
#  '01972',
#  '02246',
#  '04319',
#  '14923',
#  '24689',
#  '13662',
#  '07053',
#  '10856',
#  '25727',
#  '24201',
#  '02574',
#  '04326',
#  '02430',
#  '25810',
#  '27551',
#  '27775',
#  '02274',
#  '07687',
#  '07220',
#  '11256',
#  '01006',
#  '09452',
#  '03270',
#  '05541',
#  '10098',
#  '20701',
#  '26697',
#  '04874',
#  '09334',
#  '28062',
#  '02831',
#  '02668',
#  '01645',
#  '03642',
#  '19433',
#  '18619',
#  '06237',
#  '23227',
#  '00613',
#  '02779',
#  '23587',
#  '04102',
#  '27621',
#  '23927',
#  '27054',
#  '13975',
#  '24450',
#  '01755',
#  '07107',
#  '24634',
#  '23820',
#  '09417',
#  '25735',
#  '02872',
#  '12226',
#  '11011',
#  '10019',
#  '03951',
#  '23757',
#  '05530',
#  '08662',
#  '03970',
#  '24171',
#  '05565',
#  ...}

# %% [markdown]
# เเก้ไขให้มีข้อมูลที่ถูกต้อง
#
# โดยกำหนดให้ข้อมูลที่ไม่ใช่เลข 5 หลัก เท่ากับ ข้อมูลว่าง

# %%
hospital_list['hcode'].replace({'2475x':None,'2560x':None},inplace=True)

# %%
hospital_list_drop = hospital_list.dropna() # ทำการ drop ค่าว่างออก 
hospital_list_drop # แสดงผลลัพธ์
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5     code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         อท           ATG
# ...                         ...       ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         รบ           RBR
#
# [17101 rows x 16 columns]

# %%
hospital_list_drop = hospital_list_drop[(hospital_list_drop['hcode'].astype(str).str.isdigit()) & (hospital_list_drop['hcode'].str.len() == 5 )] # เลือกข้อมูลที่เป็น 5 หลัก

# %%
hospital_list_drop
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5     code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         อท           ATG
# ...                         ...       ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         รบ           RBR
#
# [17101 rows x 16 columns]

# %% [markdown]
# ## ตาราง hospital_list หลังจัดการข้อมูลแล้ว

# %%
hospital_list_drop # ดูตาราง hospital_list หลังจัดการข้อมูลแล้ว
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5     code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         อท           ATG
# ...                         ...       ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         รบ           RBR
#
# [17101 rows x 16 columns]

# %% [markdown]
# # รวมข้อมูลทั้งสองตารางเข้าด้วยกัน
#
# ไฟล์ alldb.csv และ hospital_list.xlsx สามารถถูกเชื่อมโยงกันโดย site ในไฟล์ alldb.csv คือ hcode ในไฟล์ hospital_list.xlsx

# %%
merged = alldb_drop5.merge(hospital_list_drop,how='left',left_on='site',right_on='hcode') 
merged
# Out:
#         user                                RowKey       date       phone  \
# 0      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30  iPhone12,3
# 1      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30  iPhone14,3
# 2      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30  iPhone13,4
# 3      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29   iPhone9,4
# 4      28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402 2022-03-31  iPhone13,3
# ...      ...                                   ...        ...         ...
# 37401  26462                        ieotqfnqcq.png 2022-03-22   Vivo 1920
# 37402  26462                        cywpeqziic.png 2022-03-21   Vivo 1920
# 37403  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7 2022-03-22  iPhone13,4
# 37404  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC 2022-03-21  iPhone13,4
# 37405  26462                        vdxxgljykj.png 2022-03-21  Vivo V2050
#
#         site                time                             urine  ov  \
# 0      06307 1900-01-01 14:46:08                   ปกติ (เหลืองใส)   4
# 1      05328 1900-01-01 15:27:45                   ปกติ (เหลืองใส)   4
# 2      06302 1900-01-01 10:16:46                   ปกติ (เหลืองใส)   3
# 3      05059 1900-01-01 12:26:38                   ปกติ (เหลืองใส)   3
# 4      06334 1900-01-01 14:57:41                   ปกติ (เหลืองใส)   0
# ...      ...                 ...                               ...  ..
# 37401  11069 1900-01-01 14:03:12                   ปกติ (เหลืองใส)   1
# 37402  11069 1900-01-01 13:59:04                   ปกติ (เหลืองใส)   2
# 37403  11069 1900-01-01 13:41:47                   ปกติ (เหลืองใส)   2
# 37404  11069 1900-01-01 14:17:46                   ปกติ (เหลืองใส)   0
# 37405  11069 1900-01-01 10:54:49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1
#
#       PartitionKey   title  ... amphurcode     amphur tamboncode     tambon  \
# 0            00001  นางสาว  ...        7.0      พิชัย        2.0   บ้านดารา
# 1            00001     นาง  ...       18.0    ฆ้องชัย        3.0   โคกสะอาด
# 2            00001     นาง  ...        5.0     ฟากท่า        4.0    สองห้อง
# 3            00001     นาย  ...       10.0      นาดูน        6.0      หัวดง
# 4            00001  นางสาว  ...        9.0  ทองแสนขัน        4.0     น้ำพี้
# ...            ...     ...  ...        ...        ...        ...        ...
# 37401        11003  นางสาว  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง
# 37402        11005     นาย  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง
# 37403        11006     นาง  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง
# 37404        11007     นาง  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง
# 37405        11008     นาย  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง
#
#       code4                        name5 code9                  name10  \
# 0      18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# 1      18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# 2      18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# 3      18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# 4      18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# ...     ...                          ...   ...                     ...
# 37401   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37402   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37403   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37404   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37405   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
#
#       short_thai  short_english
# 0             อต            UTT
# 1             กส            KSN
# 2             อต            UTT
# 3             มค            MKM
# 4             อต            UTT
# ...          ...            ...
# 37401         รอ            RET
# 37402         รอ            RET
# 37403         รอ            RET
# 37404         รอ            RET
# 37405         รอ            RET
#
# [37406 rows x 27 columns]

# %% [markdown]
# ## ตรวจสอบค่า Missing

# %%
merged.isnull().any() 
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# user             False
# RowKey           False
# date             False
# phone            False
# site             False
# time             False
# urine            False
# ov               False
# PartitionKey     False
# title            False
# age              False
# hcode            False
# name             False
# zone_code        False
# zone_name        False
# provincecode     False
# province         False
# amphurcode       False
# amphur           False
# tamboncode       False
# tambon           False
# code4            False
# name5            False
# code9            False
# name10           False
# short_thai       False
# short_english    False
# dtype: bool

# %% [markdown]
# ## ใช้ .dropna ซึ่งจะใช้ตัดแถวข้อมูลที่มีค่า missing

# %%
merged_drop = merged.dropna() #ใช้ dropna เพื่อต้องการลบข้อมูลทั้งแถวออกเมื่อมีคอลัมน์ใดคอลัมน์หนึ่งเป็น NaN
merged_drop
# Out:
#         user                                RowKey       date       phone  \
# 0      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30  iPhone12,3
# 1      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30  iPhone14,3
# 2      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30  iPhone13,4
# 3      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29   iPhone9,4
# 4      28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402 2022-03-31  iPhone13,3
# ...      ...                                   ...        ...         ...
# 37401  26462                        ieotqfnqcq.png 2022-03-22   Vivo 1920
# 37402  26462                        cywpeqziic.png 2022-03-21   Vivo 1920
# 37403  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7 2022-03-22  iPhone13,4
# 37404  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC 2022-03-21  iPhone13,4
# 37405  26462                        vdxxgljykj.png 2022-03-21  Vivo V2050
#
#         site                time                             urine  ov  \
# 0      06307 1900-01-01 14:46:08                   ปกติ (เหลืองใส)   4
# 1      05328 1900-01-01 15:27:45                   ปกติ (เหลืองใส)   4
# 2      06302 1900-01-01 10:16:46                   ปกติ (เหลืองใส)   3
# 3      05059 1900-01-01 12:26:38                   ปกติ (เหลืองใส)   3
# 4      06334 1900-01-01 14:57:41                   ปกติ (เหลืองใส)   0
# ...      ...                 ...                               ...  ..
# 37401  11069 1900-01-01 14:03:12                   ปกติ (เหลืองใส)   1
# 37402  11069 1900-01-01 13:59:04                   ปกติ (เหลืองใส)   2
# 37403  11069 1900-01-01 13:41:47                   ปกติ (เหลืองใส)   2
# 37404  11069 1900-01-01 14:17:46                   ปกติ (เหลืองใส)   0
# 37405  11069 1900-01-01 10:54:49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1
#
#       PartitionKey   title  ... amphurcode     amphur tamboncode     tambon  \
# 0            00001  นางสาว  ...        7.0      พิชัย        2.0   บ้านดารา
# 1            00001     นาง  ...       18.0    ฆ้องชัย        3.0   โคกสะอาด
# 2            00001     นาง  ...        5.0     ฟากท่า        4.0    สองห้อง
# 3            00001     นาย  ...       10.0      นาดูน        6.0      หัวดง
# 4            00001  นางสาว  ...        9.0  ทองแสนขัน        4.0     น้ำพี้
# ...            ...     ...  ...        ...        ...        ...        ...
# 37401        11003  นางสาว  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง
# 37402        11005     นาย  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง
# 37403        11006     นาง  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง
# 37404        11007     นาง  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง
# 37405        11008     นาย  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง
#
#       code4                        name5 code9                  name10  \
# 0      18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# 1      18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# 2      18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# 3      18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# 4      18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# ...     ...                          ...   ...                     ...
# 37401   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37402   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37403   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37404   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37405   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
#
#       short_thai  short_english
# 0             อต            UTT
# 1             กส            KSN
# 2             อต            UTT
# 3             มค            MKM
# 4             อต            UTT
# ...          ...            ...
# 37401         รอ            RET
# 37402         รอ            RET
# 37403         รอ            RET
# 37404         รอ            RET
# 37405         รอ            RET
#
# [37406 rows x 27 columns]

# %%
merged_drop.shape #ตรวจสอบขนาดของตารางใหม่
# Out:
# (37406, 27)

# %%
removes = merged.shape[0] - merged_drop.shape[0]
print(f'size before drop = {merged.shape[0]}')
print(f'size after drop = {merged_drop.shape[0]}')
print(f'% from drop = {(removes/merged.shape[0])*100}')
 # จากการคำนวณพบว่ามีข้อมูลที่หายไปเพียงแค่ 0.195% ดังนั้น จึงสามารถใช้การ .dropna() ได ้
# Out:
# size before drop = 37406
# size after drop = 37406
# % from drop = 0.0

# %% [markdown]
# # ตารางข้อมูลที่จะนำมาใช้

# %%
merged_drop # แสดงผลลัพธ์
# Out:
#         user                                RowKey       date       phone  \
# 0      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30  iPhone12,3
# 1      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30  iPhone14,3
# 2      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30  iPhone13,4
# 3      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29   iPhone9,4
# 4      28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402 2022-03-31  iPhone13,3
# ...      ...                                   ...        ...         ...
# 37401  26462                        ieotqfnqcq.png 2022-03-22   Vivo 1920
# 37402  26462                        cywpeqziic.png 2022-03-21   Vivo 1920
# 37403  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7 2022-03-22  iPhone13,4
# 37404  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC 2022-03-21  iPhone13,4
# 37405  26462                        vdxxgljykj.png 2022-03-21  Vivo V2050
#
#         site                time                             urine  ov  \
# 0      06307 1900-01-01 14:46:08                   ปกติ (เหลืองใส)   4
# 1      05328 1900-01-01 15:27:45                   ปกติ (เหลืองใส)   4
# 2      06302 1900-01-01 10:16:46                   ปกติ (เหลืองใส)   3
# 3      05059 1900-01-01 12:26:38                   ปกติ (เหลืองใส)   3
# 4      06334 1900-01-01 14:57:41                   ปกติ (เหลืองใส)   0
# ...      ...                 ...                               ...  ..
# 37401  11069 1900-01-01 14:03:12                   ปกติ (เหลืองใส)   1
# 37402  11069 1900-01-01 13:59:04                   ปกติ (เหลืองใส)   2
# 37403  11069 1900-01-01 13:41:47                   ปกติ (เหลืองใส)   2
# 37404  11069 1900-01-01 14:17:46                   ปกติ (เหลืองใส)   0
# 37405  11069 1900-01-01 10:54:49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1
#
#       PartitionKey   title  ... amphurcode     amphur tamboncode     tambon  \
# 0            00001  นางสาว  ...        7.0      พิชัย        2.0   บ้านดารา
# 1            00001     นาง  ...       18.0    ฆ้องชัย        3.0   โคกสะอาด
# 2            00001     นาง  ...        5.0     ฟากท่า        4.0    สองห้อง
# 3            00001     นาย  ...       10.0      นาดูน        6.0      หัวดง
# 4            00001  นางสาว  ...        9.0  ทองแสนขัน        4.0     น้ำพี้
# ...            ...     ...  ...        ...        ...        ...        ...
# 37401        11003  นางสาว  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง
# 37402        11005     นาย  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง
# 37403        11006     นาง  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง
# 37404        11007     นาง  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง
# 37405        11008     นาย  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง
#
#       code4                        name5 code9                  name10  \
# 0      18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# 1      18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# 2      18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# 3      18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# 4      18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# ...     ...                          ...   ...                     ...
# 37401   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37402   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37403   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37404   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37405   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
#
#       short_thai  short_english
# 0             อต            UTT
# 1             กส            KSN
# 2             อต            UTT
# 3             มค            MKM
# 4             อต            UTT
# ...          ...            ...
# 37401         รอ            RET
# 37402         รอ            RET
# 37403         รอ            RET
# 37404         รอ            RET
# 37405         รอ            RET
#
# [37406 rows x 27 columns]

# %%
merged_drop.isnull().any()
# Out:
# user             False
# RowKey           False
# date             False
# phone            False
# site             False
# time             False
# urine            False
# ov               False
# PartitionKey     False
# title            False
# age              False
# hcode            False
# name             False
# zone_code        False
# zone_name        False
# provincecode     False
# province         False
# amphurcode       False
# amphur           False
# tamboncode       False
# tambon           False
# code4            False
# name5            False
# code9            False
# name10           False
# short_thai       False
# short_english    False
# dtype: bool

# %% [markdown]
# ## จำนวนการตรวจในแต่ละพื้นที่

# %%
Province = merged_drop.groupby('province').count()
Province
# Out:
#               user  RowKey   date  phone   site   time  urine     ov  \
# province
# กาฬสินธุ์     7814    7814   7814   7814   7814   7814   7814   7814
# ขอนแก่น       4242    4242   4242   4242   4242   4242   4242   4242
# นครพนม           5       5      5      5      5      5      5      5
# นครราชสีมา       1       1      1      1      1      1      1      1
# มหาสารคาม     8896    8896   8896   8896   8896   8896   8896   8896
# มุกดาหาร         2       2      2      2      2      2      2      2
# ร้อยเอ็ด     13656   13656  13656  13656  13656  13656  13656  13656
# ลำปาง            1       1      1      1      1      1      1      1
# ศรีสะเกษ         3       3      3      3      3      3      3      3
# สกลนคร           6       6      6      6      6      6      6      6
# อุดรธานี         1       1      1      1      1      1      1      1
# อุตรดิตถ์     2778    2778   2778   2778   2778   2778   2778   2778
# อุบลราชธานี      1       1      1      1      1      1      1      1
#
#              PartitionKey  title  ...  amphurcode  amphur  tamboncode  tambon  \
# province                          ...
# กาฬสินธุ์            7814   7814  ...        7814    7814        7814    7814
# ขอนแก่น              4242   4242  ...        4242    4242        4242    4242
# นครพนม                  5      5  ...           5       5           5       5
# นครราชสีมา              1      1  ...           1       1           1       1
# มหาสารคาม            8896   8896  ...        8896    8896        8896    8896
# มุกดาหาร                2      2  ...           2       2           2       2
# ร้อยเอ็ด            13656  13656  ...       13656   13656       13656   13656
# ลำปาง                   1      1  ...           1       1           1       1
# ศรีสะเกษ                3      3  ...           3       3           3       3
# สกลนคร                  6      6  ...           6       6           6       6
# อุดรธานี                1      1  ...           1       1           1       1
# อุตรดิตถ์            2778   2778  ...        2778    2778        2778    2778
# อุบลราชธานี             1      1  ...           1       1           1       1
#
#              code4  name5  code9  name10  short_thai  short_english
# province
# กาฬสินธุ์     7814   7814   7814    7814        7814           7814
# ขอนแก่น       4242   4242   4242    4242        4242           4242
# นครพนม           5      5      5       5           5              5
# นครราชสีมา       1      1      1       1           1              1
# มหาสารคาม     8896   8896   8896    8896        8896           8896
# มุกดาหาร         2      2      2       2           2              2
# ร้อยเอ็ด     13656  13656  13656   13656       13656          13656
# ลำปาง            1      1      1       1           1              1
# ศรีสะเกษ         3      3      3       3           3              3
# สกลนคร           6      6      6       6           6              6
# อุดรธานี         1      1      1       1           1              1
# อุตรดิตถ์     2778   2778   2778    2778        2778           2778
# อุบลราชธานี      1      1      1       1           1              1
#
# [13 rows x 26 columns]

# %%
Province_new = Province.iloc[:,:1]
Province_new
# Out:
#               user
# province
# กาฬสินธุ์     7814
# ขอนแก่น       4242
# นครพนม           5
# นครราชสีมา       1
# มหาสารคาม     8896
# มุกดาหาร         2
# ร้อยเอ็ด     13656
# ลำปาง            1
# ศรีสะเกษ         3
# สกลนคร           6
# อุดรธานี         1
# อุตรดิตถ์     2778
# อุบลราชธานี      1

# %%
P_noindex = Province_new.reset_index()
P_noindex
# Out:
#        province   user
# 0     กาฬสินธุ์   7814
# 1       ขอนแก่น   4242
# 2        นครพนม      5
# 3    นครราชสีมา      1
# 4     มหาสารคาม   8896
# 5      มุกดาหาร      2
# 6      ร้อยเอ็ด  13656
# 7         ลำปาง      1
# 8      ศรีสะเกษ      3
# 9        สกลนคร      6
# 10     อุดรธานี      1
# 11    อุตรดิตถ์   2778
# 12  อุบลราชธานี      1

# %%
pv = {'user':'จำนวนการตรวจในแต่ละพื้นที่'}
# call rename () method
P_noindex.rename(columns=pv,
          inplace=True)
P_noindex
# Out:
#        province  จำนวนการตรวจในแต่ละพื้นที่
# 0     กาฬสินธุ์                        7814
# 1       ขอนแก่น                        4242
# 2        นครพนม                           5
# 3    นครราชสีมา                           1
# 4     มหาสารคาม                        8896
# 5      มุกดาหาร                           2
# 6      ร้อยเอ็ด                       13656
# 7         ลำปาง                           1
# 8      ศรีสะเกษ                           3
# 9        สกลนคร                           6
# 10     อุดรธานี                           1
# 11    อุตรดิตถ์                        2778
# 12  อุบลราชธานี                           1

# %% [markdown]
# ## จำนวนที่พบโรค

# %% [markdown]
# ### ระดับ 0

# %%
ov_0 = merged_drop[merged_drop['ov']== 0]
ov_0
# Out:
#         user                                RowKey       date       phone  \
# 4      28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402 2022-03-31  iPhone13,3
# 8      19911  22E333B1-A8D4-4FCB-8304-7BD2C3D9C94A 2022-03-30  iPhone12,5
# 9      99771  267232EA-5B0D-4783-8449-16687A62C5B7 2022-03-22  iPhone10,6
# 13     14360  41AE352F-77A0-4D26-B39C-6A09B39576BA 2022-03-31   iPhone8,2
# 17     27096  4D1F5F3E-E557-4F64-BEB7-D4FBCADFA43F 2022-03-30  iPhone14,5
# ...      ...                                   ...        ...         ...
# 37394  26462                        vcubzchjxv.png 2022-03-21   Vivo 1920
# 37396  26462  AD576EF3-4128-4DCD-93CB-63494C69F326 2022-03-22  iPhone13,4
# 37397  26462                        qukpkgoxfp.png 2022-03-21   Vivo 1920
# 37399  26462                        dghzdcrtay.png 2022-03-21   Vivo 1920
# 37404  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC 2022-03-21  iPhone13,4
#
#         site                time            urine  ov PartitionKey   title  \
# 4      06334 1900-01-01 14:57:41  ปกติ (เหลืองใส)   0        00001  นางสาว
# 8      06319 1900-01-01 09:32:46  ปกติ (เหลืองใส)   0        00001     นาย
# 9      05396 1900-01-01 10:35:33  ปกติ (เหลืองใส)   0        00001  นางสาว
# 13     04405 1900-01-01 14:11:05  ปกติ (เหลืองใส)   0        00001  นางสาว
# 17     11160 1900-01-01 14:56:46  ปกติ (เหลืองใส)   0        00001     นาง
# ...      ...                 ...              ...  ..          ...     ...
# 37394  11069 1900-01-01 14:18:41  ปกติ (เหลืองใส)   0        10995     นาย
# 37396  11069 1900-01-01 13:39:56  ปกติ (เหลืองใส)   0        10997     นาง
# 37397  11069 1900-01-01 11:54:17  ปกติ (เหลืองใส)   0        10998     นาง
# 37399  11069 1900-01-01 11:51:32          มีตะกอน   0        11000     นาย
# 37404  11069 1900-01-01 14:17:46  ปกติ (เหลืองใส)   0        11007     นาง
#
#        ... amphurcode       amphur tamboncode     tambon code4  \
# 4      ...        9.0    ทองแสนขัน        4.0     น้ำพี้  18.0
# 8      ...        7.0        พิชัย       11.0      นายาง  18.0
# 9      ...       10.0       คำม่วง        9.0    เนินยาง  18.0
# 13     ...       15.0  หนองสองห้อง        9.0     หันโจด  18.0
# 17     ...        4.0       น้ำปาด        1.0      แสนตอ   7.0
# ...    ...        ...          ...        ...        ...   ...
# 37394  ...       10.0      เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37396  ...       10.0      เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37397  ...       10.0      เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37399  ...       10.0      เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37404  ...       10.0      เสลภูมิ       17.0  ขวัญเมือง   7.0
#
#                              name5 code9                  name10 short_thai  \
# 4      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 8      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 9      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         กส
# 13     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         ขก
# 17                  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         อต
# ...                            ...   ...                     ...        ...
# 37394               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37396               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37397               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37399               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37404               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
#
#        short_english
# 4                UTT
# 8                UTT
# 9                KSN
# 13               KKN
# 17               UTT
# ...              ...
# 37394            RET
# 37396            RET
# 37397            RET
# 37399            RET
# 37404            RET
#
# [21021 rows x 27 columns]

# %%
ov_0 = ov_0.groupby('province').count()
ov_0
# Out:
#              user  RowKey  date  phone  site  time  urine    ov  PartitionKey  \
# province
# กาฬสินธุ์    5190    5190  5190   5190  5190  5190   5190  5190          5190
# ขอนแก่น      3315    3315  3315   3315  3315  3315   3315  3315          3315
# นครพนม          2       2     2      2     2     2      2     2             2
# นครราชสีมา      1       1     1      1     1     1      1     1             1
# มหาสารคาม    3960    3960  3960   3960  3960  3960   3960  3960          3960
# มุกดาหาร        2       2     2      2     2     2      2     2             2
# ร้อยเอ็ด     7029    7029  7029   7029  7029  7029   7029  7029          7029
# ศรีสะเกษ        1       1     1      1     1     1      1     1             1
# สกลนคร          3       3     3      3     3     3      3     3             3
# อุตรดิตถ์    1517    1517  1517   1517  1517  1517   1517  1517          1517
# อุบลราชธานี     1       1     1      1     1     1      1     1             1
#
#              title  ...  amphurcode  amphur  tamboncode  tambon  code4  name5  \
# province            ...
# กาฬสินธุ์     5190  ...        5190    5190        5190    5190   5190   5190
# ขอนแก่น       3315  ...        3315    3315        3315    3315   3315   3315
# นครพนม           2  ...           2       2           2       2      2      2
# นครราชสีมา       1  ...           1       1           1       1      1      1
# มหาสารคาม     3960  ...        3960    3960        3960    3960   3960   3960
# มุกดาหาร         2  ...           2       2           2       2      2      2
# ร้อยเอ็ด      7029  ...        7029    7029        7029    7029   7029   7029
# ศรีสะเกษ         1  ...           1       1           1       1      1      1
# สกลนคร           3  ...           3       3           3       3      3      3
# อุตรดิตถ์     1517  ...        1517    1517        1517    1517   1517   1517
# อุบลราชธานี      1  ...           1       1           1       1      1      1
#
#              code9  name10  short_thai  short_english
# province
# กาฬสินธุ์     5190    5190        5190           5190
# ขอนแก่น       3315    3315        3315           3315
# นครพนม           2       2           2              2
# นครราชสีมา       1       1           1              1
# มหาสารคาม     3960    3960        3960           3960
# มุกดาหาร         2       2           2              2
# ร้อยเอ็ด      7029    7029        7029           7029
# ศรีสะเกษ         1       1           1              1
# สกลนคร           3       3           3              3
# อุตรดิตถ์     1517    1517        1517           1517
# อุบลราชธานี      1       1           1              1
#
# [11 rows x 26 columns]

# %%
ov_0_new = ov_0.iloc[:,:1]
ov_0_new
# Out:
#              user
# province
# กาฬสินธุ์    5190
# ขอนแก่น      3315
# นครพนม          2
# นครราชสีมา      1
# มหาสารคาม    3960
# มุกดาหาร        2
# ร้อยเอ็ด     7029
# ศรีสะเกษ        1
# สกลนคร          3
# อุตรดิตถ์    1517
# อุบลราชธานี     1

# %%
ov_0_noindex = ov_0_new.reset_index()
ov_0_noindex
# Out:
#        province  user
# 0     กาฬสินธุ์  5190
# 1       ขอนแก่น  3315
# 2        นครพนม     2
# 3    นครราชสีมา     1
# 4     มหาสารคาม  3960
# 5      มุกดาหาร     2
# 6      ร้อยเอ็ด  7029
# 7      ศรีสะเกษ     1
# 8        สกลนคร     3
# 9     อุตรดิตถ์  1517
# 10  อุบลราชธานี     1

# %%
o0 = {'user':'จำนวนที่พบโรค ระดับ 0'}
# call rename () method
ov_0_noindex.rename(columns=o0,
          inplace=True)
ov_0_noindex
# Out:
#        province  จำนวนที่พบโรค ระดับ 0
# 0     กาฬสินธุ์                   5190
# 1       ขอนแก่น                   3315
# 2        นครพนม                      2
# 3    นครราชสีมา                      1
# 4     มหาสารคาม                   3960
# 5      มุกดาหาร                      2
# 6      ร้อยเอ็ด                   7029
# 7      ศรีสะเกษ                      1
# 8        สกลนคร                      3
# 9     อุตรดิตถ์                   1517
# 10  อุบลราชธานี                      1

# %% [markdown]
# ### ระดับ 1

# %%
ov_1 = merged_drop[merged_drop['ov']== 1]
ov_1
# Out:
#         user                                RowKey       date       phone  \
# 15     24986  44E5D0C4-9195-47FC-82C3-CF9A711D85AB 2022-03-28  iPhone14,3
# 27     08370  6E4E96B0-5DE4-456F-8088-A1FEF6E3F468 2022-03-23  iPhone10,5
# 31     06964  7667F96F-0ACA-4111-9ABD-54BFE320009D 2022-03-29  iPhone12,1
# 34     71152  7A9B5C50-E7CC-4EF4-9E72-7D018B488040 2022-03-10  iPhone13,2
# 37     06283  83B0AD8E-AF6A-4D2F-A321-B9CF22915090 2022-03-28  iPhone13,2
# ...      ...                                   ...        ...         ...
# 37379  26462                        fvygcngevl.png 2022-03-21   Vivo 1920
# 37383  26462                        jdmhexxudc.png 2022-03-21   Vivo 1920
# 37398  26462  10CBBBC5-3BAC-4927-93B1-24918834B166 2022-03-22  iPhone13,4
# 37401  26462                        ieotqfnqcq.png 2022-03-22   Vivo 1920
# 37405  26462                        vdxxgljykj.png 2022-03-21  Vivo V2050
#
#         site                time                             urine  ov  \
# 15     06278 1900-01-01 11:49:13                   ปกติ (เหลืองใส)   1
# 27     13966 1900-01-01 10:42:14                   ปกติ (เหลืองใส)   1
# 31     06286 1900-01-01 10:58:45                   ปกติ (เหลืองใส)   1
# 34     05327 1900-01-01 11:16:06                   ปกติ (เหลืองใส)   1
# 37     06283 1900-01-01 14:29:40                   ปกติ (เหลืองใส)   1
# ...      ...                 ...                               ...  ..
# 37379  11069 1900-01-01 10:29:01                   ปกติ (เหลืองใส)   1
# 37383  11069 1900-01-01 10:54:05  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1
# 37398  11069 1900-01-01 14:01:18                   ปกติ (เหลืองใส)   1
# 37401  11069 1900-01-01 14:03:12                   ปกติ (เหลืองใส)   1
# 37405  11069 1900-01-01 10:54:49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1
#
#       PartitionKey   title  ... amphurcode    amphur tamboncode     tambon  \
# 15           00001     นาย  ...        3.0    ท่าปลา        2.0     หาดล้า
# 27           00001  นางสาว  ...       14.0  ห้วยผึ้ง        2.0    ไค้นุ่น
# 31           00001     นาง  ...        3.0    ท่าปลา        6.0     ท่าแฝก
# 34           00001     นาง  ...       18.0   ฆ้องชัย        3.0   โคกสะอาด
# 37           00001     นาย  ...        3.0    ท่าปลา        5.0    น้ำหมัน
# ...            ...     ...  ...        ...       ...        ...        ...
# 37379        10980     นาย  ...       10.0   เสลภูมิ       17.0  ขวัญเมือง
# 37383        10984     นาง  ...       10.0   เสลภูมิ       17.0  ขวัญเมือง
# 37398        10999     นาง  ...       10.0   เสลภูมิ       17.0  ขวัญเมือง
# 37401        11003  นางสาว  ...       10.0   เสลภูมิ       17.0  ขวัญเมือง
# 37405        11008     นาย  ...       10.0   เสลภูมิ       17.0  ขวัญเมือง
#
#       code4                        name5 code9                  name10  \
# 15     18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# 27     18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# 31     18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# 34     18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# 37     18.0  โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ
# ...     ...                          ...   ...                     ...
# 37379   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37383   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37398   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37401   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
# 37405   7.0               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง
#
#       short_thai  short_english
# 15            อต            UTT
# 27            กส            KSN
# 31            อต            UTT
# 34            กส            KSN
# 37            อต            UTT
# ...          ...            ...
# 37379         รอ            RET
# 37383         รอ            RET
# 37398         รอ            RET
# 37401         รอ            RET
# 37405         รอ            RET
#
# [7082 rows x 27 columns]

# %%
ov_1 = ov_1.groupby('province').count()
ov_1
# Out:
#            user  RowKey  date  phone  site  time  urine    ov  PartitionKey  \
# province
# กาฬสินธุ์   916     916   916    916   916   916    916   916           916
# ขอนแก่น     551     551   551    551   551   551    551   551           551
# นครพนม        2       2     2      2     2     2      2     2             2
# มหาสารคาม  2104    2104  2104   2104  2104  2104   2104  2104          2104
# ร้อยเอ็ด   3051    3051  3051   3051  3051  3051   3051  3051          3051
# ศรีสะเกษ      1       1     1      1     1     1      1     1             1
# สกลนคร        3       3     3      3     3     3      3     3             3
# อุดรธานี      1       1     1      1     1     1      1     1             1
# อุตรดิตถ์   453     453   453    453   453   453    453   453           453
#
#            title  ...  amphurcode  amphur  tamboncode  tambon  code4  name5  \
# province          ...
# กาฬสินธุ์    916  ...         916     916         916     916    916    916
# ขอนแก่น      551  ...         551     551         551     551    551    551
# นครพนม         2  ...           2       2           2       2      2      2
# มหาสารคาม   2104  ...        2104    2104        2104    2104   2104   2104
# ร้อยเอ็ด    3051  ...        3051    3051        3051    3051   3051   3051
# ศรีสะเกษ       1  ...           1       1           1       1      1      1
# สกลนคร         3  ...           3       3           3       3      3      3
# อุดรธานี       1  ...           1       1           1       1      1      1
# อุตรดิตถ์    453  ...         453     453         453     453    453    453
#
#            code9  name10  short_thai  short_english
# province
# กาฬสินธุ์    916     916         916            916
# ขอนแก่น      551     551         551            551
# นครพนม         2       2           2              2
# มหาสารคาม   2104    2104        2104           2104
# ร้อยเอ็ด    3051    3051        3051           3051
# ศรีสะเกษ       1       1           1              1
# สกลนคร         3       3           3              3
# อุดรธานี       1       1           1              1
# อุตรดิตถ์    453     453         453            453
#
# [9 rows x 26 columns]

# %%
ov_1_new = ov_1.iloc[:,:1]
ov_1_new
# Out:
#            user
# province
# กาฬสินธุ์   916
# ขอนแก่น     551
# นครพนม        2
# มหาสารคาม  2104
# ร้อยเอ็ด   3051
# ศรีสะเกษ      1
# สกลนคร        3
# อุดรธานี      1
# อุตรดิตถ์   453

# %%
ov_1_noindex = ov_1_new.reset_index()
ov_1_noindex
# Out:
#     province  user
# 0  กาฬสินธุ์   916
# 1    ขอนแก่น   551
# 2     นครพนม     2
# 3  มหาสารคาม  2104
# 4   ร้อยเอ็ด  3051
# 5   ศรีสะเกษ     1
# 6     สกลนคร     3
# 7   อุดรธานี     1
# 8  อุตรดิตถ์   453

# %%
o1 = {'user':'จำนวนที่พบโรค ระดับ 1'}
# call rename () method
ov_1_noindex.rename(columns=o1,
          inplace=True)
ov_1_noindex
# Out:
#     province  จำนวนที่พบโรค ระดับ 1
# 0  กาฬสินธุ์                    916
# 1    ขอนแก่น                    551
# 2     นครพนม                      2
# 3  มหาสารคาม                   2104
# 4   ร้อยเอ็ด                   3051
# 5   ศรีสะเกษ                      1
# 6     สกลนคร                      3
# 7   อุดรธานี                      1
# 8  อุตรดิตถ์                    453

# %% [markdown]
# ### ระดับ 2

# %%
ov_2 = merged_drop[merged_drop['ov']== 2]
ov_2
# Out:
#         user                                RowKey       date         phone  \
# 6      06277  1DDA8B23-D1EA-4E15-AE70-1E7FE53733B6 2022-03-25    iPhone14,3
# 12     18041  3FBB8FE8-F3EE-4307-8E01-406D7A1B2488 2022-03-28    iPhone14,3
# 19     00001  540553CD-1EAB-4252-A64E-F96A8390CE10 2022-03-28      iPad13,6
# 20     74891  594A7093-AB5F-4A64-8B74-E336ED81A444 2022-04-01    iPhone12,8
# 22     40059  5F8D255F-B0F5-4CE5-9607-7916E394173D 2022-03-18      iPad13,1
# ...      ...                                   ...        ...           ...
# 37366  26462                        wgxurysjec.png 2022-03-22  OPPO CPH1819
# 37367  26462                        vanquopswi.png 2022-03-22    Vivo V2050
# 37395  26462  3340619E-D3F4-4090-B3D0-B6CDF1D9F370 2022-03-21    iPhone13,4
# 37402  26462                        cywpeqziic.png 2022-03-21     Vivo 1920
# 37403  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7 2022-03-22    iPhone13,4
#
#         site                time            urine  ov PartitionKey title  ...  \
# 6      06277 1900-01-01 10:13:51  ปกติ (เหลืองใส)   2        00001   นาย  ...
# 12     11158 1900-01-01 10:12:10  ปกติ (เหลืองใส)   2        00001   นาง  ...
# 19     10360 1900-01-01 12:24:15  ปกติ (เหลืองใส)   2        00001   นาย  ...
# 20     05055 1900-01-01 15:15:35          มีตะกอน   2        00001   นาง  ...
# 22     05052 1900-01-01 11:36:13   ใสเป็นน้ำเปล่า   2        00001   นาง  ...
# ...      ...                 ...              ...  ..          ...   ...  ...
# 37366  11069 1900-01-01 09:13:07             ขุ่น   2        10968   นาย  ...
# 37367  11069 1900-01-01 09:48:29  ปกติ (เหลืองใส)   2        10969   นาย  ...
# 37395  11069 1900-01-01 13:58:41          มีตะกอน   2        10996   นาง  ...
# 37402  11069 1900-01-01 13:59:04  ปกติ (เหลืองใส)   2        11005   นาย  ...
# 37403  11069 1900-01-01 13:41:47  ปกติ (เหลืองใส)   2        11006   นาง  ...
#
#       amphurcode   amphur tamboncode     tambon code4  \
# 6            3.0   ท่าปลา        2.0     หาดล้า  18.0
# 12           2.0     ตรอน        2.0   บ้านแก่ง   7.0
# 19           4.0   น้ำปาด        5.0     น้ำไผ่  18.0
# 20          10.0    นาดูน        4.0      ดงบัง  18.0
# 22          10.0    นาดูน        2.0    หนองไผ่  18.0
# ...          ...      ...        ...        ...   ...
# 37366       10.0  เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37367       10.0  เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37395       10.0  เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37402       10.0  เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37403       10.0  เสลภูมิ       17.0  ขวัญเมือง   7.0
#
#                              name5 code9                  name10 short_thai  \
# 6      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 12                  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         อต
# 19     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 20     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         มค
# 22     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         มค
# ...                            ...   ...                     ...        ...
# 37366               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37367               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37395               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37402               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37403               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
#
#        short_english
# 6                UTT
# 12               UTT
# 19               UTT
# 20               MKM
# 22               MKM
# ...              ...
# 37366            RET
# 37367            RET
# 37395            RET
# 37402            RET
# 37403            RET
#
# [3520 rows x 27 columns]

# %%
ov_2 = ov_2.groupby('province').count()
ov_2
# Out:
#            user  RowKey  date  phone  site  time  urine    ov  PartitionKey  \
# province
# กาฬสินธุ์   541     541   541    541   541   541    541   541           541
# ขอนแก่น     164     164   164    164   164   164    164   164           164
# มหาสารคาม  1183    1183  1183   1183  1183  1183   1183  1183          1183
# ร้อยเอ็ด   1396    1396  1396   1396  1396  1396   1396  1396          1396
# ลำปาง         1       1     1      1     1     1      1     1             1
# ศรีสะเกษ      1       1     1      1     1     1      1     1             1
# อุตรดิตถ์   234     234   234    234   234   234    234   234           234
#
#            title  ...  amphurcode  amphur  tamboncode  tambon  code4  name5  \
# province          ...
# กาฬสินธุ์    541  ...         541     541         541     541    541    541
# ขอนแก่น      164  ...         164     164         164     164    164    164
# มหาสารคาม   1183  ...        1183    1183        1183    1183   1183   1183
# ร้อยเอ็ด    1396  ...        1396    1396        1396    1396   1396   1396
# ลำปาง          1  ...           1       1           1       1      1      1
# ศรีสะเกษ       1  ...           1       1           1       1      1      1
# อุตรดิตถ์    234  ...         234     234         234     234    234    234
#
#            code9  name10  short_thai  short_english
# province
# กาฬสินธุ์    541     541         541            541
# ขอนแก่น      164     164         164            164
# มหาสารคาม   1183    1183        1183           1183
# ร้อยเอ็ด    1396    1396        1396           1396
# ลำปาง          1       1           1              1
# ศรีสะเกษ       1       1           1              1
# อุตรดิตถ์    234     234         234            234
#
# [7 rows x 26 columns]

# %%
ov_2_new = ov_2.iloc[:,:1]
ov_2_new
# Out:
#            user
# province
# กาฬสินธุ์   541
# ขอนแก่น     164
# มหาสารคาม  1183
# ร้อยเอ็ด   1396
# ลำปาง         1
# ศรีสะเกษ      1
# อุตรดิตถ์   234

# %%
ov_2_noindex = ov_2_new.reset_index()
ov_2_noindex
# Out:
#     province  user
# 0  กาฬสินธุ์   541
# 1    ขอนแก่น   164
# 2  มหาสารคาม  1183
# 3   ร้อยเอ็ด  1396
# 4      ลำปาง     1
# 5   ศรีสะเกษ     1
# 6  อุตรดิตถ์   234

# %%
o2 = {'user':'จำนวนที่พบโรค ระดับ 2'}
# call rename () method
ov_2_noindex.rename(columns=o2,
          inplace=True)
ov_2_noindex
# Out:
#     province  จำนวนที่พบโรค ระดับ 2
# 0  กาฬสินธุ์                    541
# 1    ขอนแก่น                    164
# 2  มหาสารคาม                   1183
# 3   ร้อยเอ็ด                   1396
# 4      ลำปาง                      1
# 5   ศรีสะเกษ                      1
# 6  อุตรดิตถ์                    234

# %% [markdown]
# ### ระดับ 3

# %%
ov_3 = merged_drop[merged_drop['ov']== 3]
ov_3
# Out:
#         user                                RowKey       date       phone  \
# 2      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30  iPhone13,4
# 3      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29   iPhone9,4
# 5      41340  1C640780-7513-43C0-B1E4-4A535DA468F3 2022-03-30  iPhone14,5
# 16     16085  49A9B05F-9B2F-49B9-99D7-CC3A60836EE1 2022-03-30  iPhone13,2
# 18     60847  52421C45-3625-4E62-B681-158CF7049DC7 2022-03-28  iPhone14,3
# ...      ...                                   ...        ...         ...
# 37324  12576                        gitvjybizk.png 2022-03-09   Vivo 1938
# 37329  12576                        tanpttgcgs.png 2022-03-09   Vivo 1938
# 37346  89681  EF02B947-21AE-4F27-8B48-3B48967B3D7D 2022-03-18  iPhone13,4
# 37363  26462                        pnqumypemv.png 2022-03-22  Vivo V2050
# 37381  10982  D713CB5A-AE59-4FA7-9387-39C0B766120A 2022-03-21  iPhone13,4
#
#         site                time            urine  ov PartitionKey   title  \
# 2      06302 1900-01-01 10:16:46  ปกติ (เหลืองใส)   3        00001     นาง
# 3      05059 1900-01-01 12:26:38  ปกติ (เหลืองใส)   3        00001     นาย
# 5      06288 1900-01-01 10:28:02  ปกติ (เหลืองใส)   3        00001  นางสาว
# 16     06299 1900-01-01 13:11:51  ปกติ (เหลืองใส)   3        00001     นาง
# 18     06298 1900-01-01 10:23:45  ปกติ (เหลืองใส)   3        00001     นาย
# ...      ...                 ...              ...  ..          ...     ...
# 37324  11057 1900-01-01 15:51:03  ปกติ (เหลืองใส)   3        09016     นาย
# 37329  11057 1900-01-01 15:52:57  ปกติ (เหลืองใส)   3        09018     นาง
# 37346  11070 1900-01-01 17:40:29  ปกติ (เหลืองใส)   3        09031     นาย
# 37363  11069 1900-01-01 09:49:16  ปกติ (เหลืองใส)   3        10965  นางสาว
# 37381  11069 1900-01-01 10:30:00  ปกติ (เหลืองใส)   3        10982    น.ส.
#
#        ... amphurcode          amphur tamboncode     tambon code4  \
# 2      ...        5.0          ฟากท่า        4.0    สองห้อง  18.0
# 3      ...       10.0           นาดูน        6.0      หัวดง  18.0
# 5      ...        3.0          ท่าปลา        7.0     นางพญา  18.0
# 16     ...        5.0          ฟากท่า        2.0     สองคอน  18.0
# 18     ...        4.0          น้ำปาด        6.0   ห้วยมุ่น  18.0
# ...    ...        ...             ...        ...        ...   ...
# 37324  ...        8.0  พยัคฆภูมิพิสัย        1.0     ปะหลาน   7.0
# 37329  ...        8.0  พยัคฆภูมิพิสัย        1.0     ปะหลาน   7.0
# 37346  ...       11.0      สุวรรณภูมิ        1.0      สระคู   7.0
# 37363  ...       10.0         เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37381  ...       10.0         เสลภูมิ       17.0  ขวัญเมือง   7.0
#
#                              name5 code9                  name10 short_thai  \
# 2      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 3      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         มค
# 5      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 16     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 18     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# ...                            ...   ...                     ...        ...
# 37324               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         มค
# 37329               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         มค
# 37346               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37363               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37381               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
#
#        short_english
# 2                UTT
# 3                MKM
# 5                UTT
# 16               UTT
# 18               UTT
# ...              ...
# 37324            MKM
# 37329            MKM
# 37346            RET
# 37363            RET
# 37381            RET
#
# [2953 rows x 27 columns]

# %%
ov_3 = ov_3.groupby('province').count()
ov_3
# Out:
#            user  RowKey  date  phone  site  time  urine    ov  PartitionKey  \
# province
# กาฬสินธุ์   522     522   522    522   522   522    522   522           522
# ขอนแก่น     125     125   125    125   125   125    125   125           125
# นครพนม        1       1     1      1     1     1      1     1             1
# มหาสารคาม   884     884   884    884   884   884    884   884           884
# ร้อยเอ็ด   1163    1163  1163   1163  1163  1163   1163  1163          1163
# อุตรดิตถ์   258     258   258    258   258   258    258   258           258
#
#            title  ...  amphurcode  amphur  tamboncode  tambon  code4  name5  \
# province          ...
# กาฬสินธุ์    522  ...         522     522         522     522    522    522
# ขอนแก่น      125  ...         125     125         125     125    125    125
# นครพนม         1  ...           1       1           1       1      1      1
# มหาสารคาม    884  ...         884     884         884     884    884    884
# ร้อยเอ็ด    1163  ...        1163    1163        1163    1163   1163   1163
# อุตรดิตถ์    258  ...         258     258         258     258    258    258
#
#            code9  name10  short_thai  short_english
# province
# กาฬสินธุ์    522     522         522            522
# ขอนแก่น      125     125         125            125
# นครพนม         1       1           1              1
# มหาสารคาม    884     884         884            884
# ร้อยเอ็ด    1163    1163        1163           1163
# อุตรดิตถ์    258     258         258            258
#
# [6 rows x 26 columns]

# %%
ov_3_new = ov_3.iloc[:,:1]
ov_3_new
# Out:
#            user
# province
# กาฬสินธุ์   522
# ขอนแก่น     125
# นครพนม        1
# มหาสารคาม   884
# ร้อยเอ็ด   1163
# อุตรดิตถ์   258

# %%
ov_3_noindex = ov_3_new.reset_index()
ov_3_noindex
# Out:
#     province  user
# 0  กาฬสินธุ์   522
# 1    ขอนแก่น   125
# 2     นครพนม     1
# 3  มหาสารคาม   884
# 4   ร้อยเอ็ด  1163
# 5  อุตรดิตถ์   258

# %%
o3 = {'user':'จำนวนที่พบโรค ระดับ 3'}
# call rename () method
ov_3_noindex.rename(columns=o3,
          inplace=True)
ov_3_noindex
# Out:
#     province  จำนวนที่พบโรค ระดับ 3
# 0  กาฬสินธุ์                    522
# 1    ขอนแก่น                    125
# 2     นครพนม                      1
# 3  มหาสารคาม                    884
# 4   ร้อยเอ็ด                   1163
# 5  อุตรดิตถ์                    258

# %% [markdown]
# ### ระดับ 4

# %%
ov_4 = merged_drop[merged_drop['ov']== 4]
ov_4
# Out:
#         user                                RowKey       date         phone  \
# 0      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30    iPhone12,3
# 1      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30    iPhone14,3
# 7      22119  1FBE544D-7313-43EA-95EF-91DAD0513808 2022-04-01     iPhone8,1
# 10     89195  27A826ED-D57D-4386-8A3C-9CFD13297B8B 2022-03-30     iPhone9,3
# 11     59476  2AAA9DE2-24E6-4F41-B02E-0CB610C906C6 2022-03-25     iPhone9,4
# ...      ...                                   ...        ...           ...
# 37302  12576                        mmttpolskc.png 2022-03-09     Vivo 1938
# 37359  26462  6C55B69E-8E4C-46B0-B0D7-4754A529EE3C 2022-03-21    iPhone13,4
# 37374  26462  5CB6F5EB-324D-448C-84AD-C9D48B23684E 2022-03-22    iPhone13,4
# 37385  26462                        iwwwnyrmtz.png 2022-03-22  OPPO CPH1819
# 37400  26462                        rryhjijyje.png 2022-03-21    Vivo V2050
#
#         site                time              urine  ov PartitionKey   title  \
# 0      06307 1900-01-01 14:46:08    ปกติ (เหลืองใส)   4        00001  นางสาว
# 1      05328 1900-01-01 15:27:45    ปกติ (เหลืองใส)   4        00001     นาง
# 7      06261 1900-01-01 15:40:17    ปกติ (เหลืองใส)   4        00001     นาง
# 10     06267 1900-01-01 10:08:32    ปกติ (เหลืองใส)   4        00001     นาง
# 11     05000 1900-01-01 11:14:25  สีฟ้า หรือน้ำเงิน   4        00001     นาง
# ...      ...                 ...                ...  ..          ...     ...
# 37302  11057 1900-01-01 10:00:22               ขุ่น   4        09005     นาง
# 37359  11069 1900-01-01 10:08:34    ปกติ (เหลืองใส)   4        10961     นาง
# 37374  11069 1900-01-01 14:04:13    ปกติ (เหลืองใส)   4        10975     นาง
# 37385  11069 1900-01-01 09:32:10    ปกติ (เหลืองใส)   4        10986     นาย
# 37400  11069 1900-01-01 11:52:34     มีเม็ดเลือดแดง   4        11002    น.ส.
#
#        ... amphurcode          amphur tamboncode     tambon code4  \
# 0      ...        7.0           พิชัย        2.0   บ้านดารา  18.0
# 1      ...       18.0         ฆ้องชัย        3.0   โคกสะอาด  18.0
# 7      ...        1.0  เมืองอุตรดิตถ์        9.0    งิ้วงาม  18.0
# 10     ...        1.0  เมืองอุตรดิตถ์       13.0     วังดิน  18.0
# 11     ...        6.0           บรบือ       20.0     ดอนงัว  18.0
# ...    ...        ...             ...        ...        ...   ...
# 37302  ...        8.0  พยัคฆภูมิพิสัย        1.0     ปะหลาน   7.0
# 37359  ...       10.0         เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37374  ...       10.0         เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37385  ...       10.0         เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37400  ...       10.0         เสลภูมิ       17.0  ขวัญเมือง   7.0
#
#                              name5 code9                  name10 short_thai  \
# 0      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 1      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         กส
# 7      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 10     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 11     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         มค
# ...                            ...   ...                     ...        ...
# 37302               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         มค
# 37359               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37374               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37385               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37400               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
#
#        short_english
# 0                UTT
# 1                KSN
# 7                UTT
# 10               UTT
# 11               MKM
# ...              ...
# 37302            MKM
# 37359            RET
# 37374            RET
# 37385            RET
# 37400            RET
#
# [2830 rows x 27 columns]

# %%
ov_4 = ov_4.groupby('province').count()
ov_4_new = ov_4.iloc[:,:1]
ov_4_noindex = ov_4_new.reset_index()
ov_4_noindex
# Out:
#     province  user
# 0  กาฬสินธุ์   645
# 1    ขอนแก่น    87
# 2  มหาสารคาม   765
# 3   ร้อยเอ็ด  1017
# 4  อุตรดิตถ์   316

# %%
o4 = {'user':'จำนวนที่พบโรค ระดับ 4'}
# call rename () method
ov_4_noindex.rename(columns=o4,
          inplace=True)
ov_4_noindex
# Out:
#     province  จำนวนที่พบโรค ระดับ 4
# 0  กาฬสินธุ์                    645
# 1    ขอนแก่น                     87
# 2  มหาสารคาม                    765
# 3   ร้อยเอ็ด                   1017
# 4  อุตรดิตถ์                    316

# %% [markdown]
# ### รวมตาราง 4 ตารางเข้าด้วยกัน

# %%
ov_merge = ov_0_noindex.merge(ov_1_noindex,how='left',left_on='province',right_on='province') 
ov_merge = ov_merge.merge(ov_2_noindex,how='left',left_on='province',right_on='province') 
ov_merge = ov_merge.merge(ov_3_noindex,how='left',left_on='province',right_on='province') 
ov_merge = ov_merge.merge(ov_4_noindex,how='left',left_on='province',right_on='province') 
ov_merge
# Out:
#        province  จำนวนที่พบโรค ระดับ 0  จำนวนที่พบโรค ระดับ 1  \
# 0     กาฬสินธุ์                   5190                  916.0
# 1       ขอนแก่น                   3315                  551.0
# 2        นครพนม                      2                    2.0
# 3    นครราชสีมา                      1                    NaN
# 4     มหาสารคาม                   3960                 2104.0
# 5      มุกดาหาร                      2                    NaN
# 6      ร้อยเอ็ด                   7029                 3051.0
# 7      ศรีสะเกษ                      1                    1.0
# 8        สกลนคร                      3                    3.0
# 9     อุตรดิตถ์                   1517                  453.0
# 10  อุบลราชธานี                      1                    NaN
#
#     จำนวนที่พบโรค ระดับ 2  จำนวนที่พบโรค ระดับ 3  จำนวนที่พบโรค ระดับ 4
# 0                   541.0                  522.0                  645.0
# 1                   164.0                  125.0                   87.0
# 2                     NaN                    1.0                    NaN
# 3                     NaN                    NaN                    NaN
# 4                  1183.0                  884.0                  765.0
# 5                     NaN                    NaN                    NaN
# 6                  1396.0                 1163.0                 1017.0
# 7                     1.0                    NaN                    NaN
# 8                     NaN                    NaN                    NaN
# 9                   234.0                  258.0                  316.0
# 10                    NaN                    NaN                    NaN

# %%
# เเทนค่า NaN ด้วย 0
ov_merge['จำนวนที่พบโรค ระดับ 1'] = ov_merge['จำนวนที่พบโรค ระดับ 1'].fillna(0) 
ov_merge['จำนวนที่พบโรค ระดับ 2'] = ov_merge['จำนวนที่พบโรค ระดับ 2'].fillna(0) 
ov_merge['จำนวนที่พบโรค ระดับ 3'] = ov_merge['จำนวนที่พบโรค ระดับ 3'].fillna(0) 
ov_merge['จำนวนที่พบโรค ระดับ 4'] = ov_merge['จำนวนที่พบโรค ระดับ 4'].fillna(0)

# %%
ov_merge.isnull().any()
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# province                 False
# จำนวนที่พบโรค ระดับ 0    False
# จำนวนที่พบโรค ระดับ 1    False
# จำนวนที่พบโรค ระดับ 2    False
# จำนวนที่พบโรค ระดับ 3    False
# จำนวนที่พบโรค ระดับ 4    False
# dtype: bool

# %% [markdown]
# # Dashboard 1
#
# รวมตารางระหว่างจำนวนการตรวจในแต่ละพื้นที่ กับ จำนวนที่พบโรค

# %%
data1 = P_noindex.merge(ov_merge,how='left',left_on='province',right_on='province') 
data1
# Out:
#        province  จำนวนการตรวจในแต่ละพื้นที่  จำนวนที่พบโรค ระดับ 0  \
# 0     กาฬสินธุ์                        7814                 5190.0
# 1       ขอนแก่น                        4242                 3315.0
# 2        นครพนม                           5                    2.0
# 3    นครราชสีมา                           1                    1.0
# 4     มหาสารคาม                        8896                 3960.0
# 5      มุกดาหาร                           2                    2.0
# 6      ร้อยเอ็ด                       13656                 7029.0
# 7         ลำปาง                           1                    NaN
# 8      ศรีสะเกษ                           3                    1.0
# 9        สกลนคร                           6                    3.0
# 10     อุดรธานี                           1                    NaN
# 11    อุตรดิตถ์                        2778                 1517.0
# 12  อุบลราชธานี                           1                    1.0
#
#     จำนวนที่พบโรค ระดับ 1  จำนวนที่พบโรค ระดับ 2  จำนวนที่พบโรค ระดับ 3  \
# 0                   916.0                  541.0                  522.0
# 1                   551.0                  164.0                  125.0
# 2                     2.0                    0.0                    1.0
# 3                     0.0                    0.0                    0.0
# 4                  2104.0                 1183.0                  884.0
# 5                     0.0                    0.0                    0.0
# 6                  3051.0                 1396.0                 1163.0
# 7                     NaN                    NaN                    NaN
# 8                     1.0                    1.0                    0.0
# 9                     3.0                    0.0                    0.0
# 10                    NaN                    NaN                    NaN
# 11                  453.0                  234.0                  258.0
# 12                    0.0                    0.0                    0.0
#
#     จำนวนที่พบโรค ระดับ 4
# 0                   645.0
# 1                    87.0
# 2                     0.0
# 3                     0.0
# 4                   765.0
# 5                     0.0
# 6                  1017.0
# 7                     NaN
# 8                     0.0
# 9                     0.0
# 10                    NaN
# 11                  316.0
# 12                    0.0

# %%
# เเทนค่า NaN ด้วย 0
data1['จำนวนที่พบโรค ระดับ 0'] = data1['จำนวนที่พบโรค ระดับ 0'].fillna(0) 
data1['จำนวนที่พบโรค ระดับ 1'] = data1['จำนวนที่พบโรค ระดับ 1'].fillna(0) 
data1['จำนวนที่พบโรค ระดับ 2'] = data1['จำนวนที่พบโรค ระดับ 2'].fillna(0) 
data1['จำนวนที่พบโรค ระดับ 3'] = data1['จำนวนที่พบโรค ระดับ 3'].fillna(0) 
data1['จำนวนที่พบโรค ระดับ 4'] = data1['จำนวนที่พบโรค ระดับ 4'].fillna(0)

# %%
data1.isnull().any()
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# province                      False
# จำนวนการตรวจในแต่ละพื้นที่    False
# จำนวนที่พบโรค ระดับ 0         False
# จำนวนที่พบโรค ระดับ 1         False
# จำนวนที่พบโรค ระดับ 2         False
# จำนวนที่พบโรค ระดับ 3         False
# จำนวนที่พบโรค ระดับ 4         False
# dtype: bool

# %%
data1 # แสดงข้อมูลหลังเเทน NaN ด้วย 0
# Out:
#        province  จำนวนการตรวจในแต่ละพื้นที่  จำนวนที่พบโรค ระดับ 0  \
# 0     กาฬสินธุ์                        7814                 5190.0
# 1       ขอนแก่น                        4242                 3315.0
# 2        นครพนม                           5                    2.0
# 3    นครราชสีมา                           1                    1.0
# 4     มหาสารคาม                        8896                 3960.0
# 5      มุกดาหาร                           2                    2.0
# 6      ร้อยเอ็ด                       13656                 7029.0
# 7         ลำปาง                           1                    0.0
# 8      ศรีสะเกษ                           3                    1.0
# 9        สกลนคร                           6                    3.0
# 10     อุดรธานี                           1                    0.0
# 11    อุตรดิตถ์                        2778                 1517.0
# 12  อุบลราชธานี                           1                    1.0
#
#     จำนวนที่พบโรค ระดับ 1  จำนวนที่พบโรค ระดับ 2  จำนวนที่พบโรค ระดับ 3  \
# 0                   916.0                  541.0                  522.0
# 1                   551.0                  164.0                  125.0
# 2                     2.0                    0.0                    1.0
# 3                     0.0                    0.0                    0.0
# 4                  2104.0                 1183.0                  884.0
# 5                     0.0                    0.0                    0.0
# 6                  3051.0                 1396.0                 1163.0
# 7                     0.0                    0.0                    0.0
# 8                     1.0                    1.0                    0.0
# 9                     3.0                    0.0                    0.0
# 10                    0.0                    0.0                    0.0
# 11                  453.0                  234.0                  258.0
# 12                    0.0                    0.0                    0.0
#
#     จำนวนที่พบโรค ระดับ 4
# 0                   645.0
# 1                    87.0
# 2                     0.0
# 3                     0.0
# 4                   765.0
# 5                     0.0
# 6                  1017.0
# 7                     0.0
# 8                     0.0
# 9                     0.0
# 10                    0.0
# 11                  316.0
# 12                    0.0

# %%
data1.to_csv(os.path.join(path,'data1.csv')) # save เข้า drive เพื่อนำไปทำ dashboard

# %% [markdown]
# # Dashboard 2
#
# ข้อมูลที่เหลือ
#
# * ช่วงเวลาที่ตรวจ (date ในไฟล์ alldb.csv)
# * อื่นๆที่นักศึกษาเห็นว่าเป็นประโยชน์ (phone (ชนิดโทรศัพท์ที่ใช้บันทึก), title (คำนำหน้าชื่อ), age (อายุ))

# %%
merged_use = merged_drop[['user','date','phone','site','time','urine','ov','PartitionKey','hcode','name','province','title','age']] 
merged_use
# Out:
#         user       date       phone   site                time  \
# 0      12015 2022-03-30  iPhone12,3  06307 1900-01-01 14:46:08
# 1      91811 2022-03-30  iPhone14,3  05328 1900-01-01 15:27:45
# 2      95821 2022-03-30  iPhone13,4  06302 1900-01-01 10:16:46
# 3      13361 2022-03-29   iPhone9,4  05059 1900-01-01 12:26:38
# 4      28241 2022-03-31  iPhone13,3  06334 1900-01-01 14:57:41
# ...      ...        ...         ...    ...                 ...
# 37401  26462 2022-03-22   Vivo 1920  11069 1900-01-01 14:03:12
# 37402  26462 2022-03-21   Vivo 1920  11069 1900-01-01 13:59:04
# 37403  26462 2022-03-22  iPhone13,4  11069 1900-01-01 13:41:47
# 37404  26462 2022-03-21  iPhone13,4  11069 1900-01-01 14:17:46
# 37405  26462 2022-03-21  Vivo V2050  11069 1900-01-01 10:54:49
#
#                                   urine  ov PartitionKey  hcode  \
# 0                       ปกติ (เหลืองใส)   4        00001  06307
# 1                       ปกติ (เหลืองใส)   4        00001  05328
# 2                       ปกติ (เหลืองใส)   3        00001  06302
# 3                       ปกติ (เหลืองใส)   3        00001  05059
# 4                       ปกติ (เหลืองใส)   0        00001  06334
# ...                                 ...  ..          ...    ...
# 37401                   ปกติ (เหลืองใส)   1        11003  11069
# 37402                   ปกติ (เหลืองใส)   2        11005  11069
# 37403                   ปกติ (เหลืองใส)   2        11006  11069
# 37404                   ปกติ (เหลืองใส)   0        11007  11069
# 37405  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1        11008  11069
#
#                                                     name   province   title  \
# 0      โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา  อุตรดิตถ์  นางสาว
# 1            โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์  กาฬสินธุ์     นาง
# 2                     โรงพยาบาลส่งเสริมสุขภาพตำบลสองห้อง  อุตรดิตถ์     นาง
# 3                  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านดอนดู่  มหาสารคาม     นาย
# 4                      โรงพยาบาลส่งเสริมสุขภาพตำบลน้ำพี้  อุตรดิตถ์  นางสาว
# ...                                                  ...        ...     ...
# 37401                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด  นางสาว
# 37402                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาย
# 37403                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาง
# 37404                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาง
# 37405                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาย
#
#       age
# 0      47
# 1      41
# 2      55
# 3      66
# 4      50
# ...    ..
# 37401  33
# 37402  28
# 37403  72
# 37404  48
# 37405  36
#
# [37406 rows x 13 columns]

# %%
# สำหรับแยกข้อมูลออกเป็น วัน เดือน ปี ในเเต่ละคอลัมน์
merged_use1 = pd.DataFrame(merged_use)
merged_use1['Day'] = pd.to_datetime(merged_use['date'], format = "%Y/%m/%d")
merged_use1['Month'] = merged_use['date'].dt.month
merged_use1['Year'] = merged_use['date'].dt.year
merged_use1
# Out:
#         user       date       phone   site                time  \
# 0      12015 2022-03-30  iPhone12,3  06307 1900-01-01 14:46:08
# 1      91811 2022-03-30  iPhone14,3  05328 1900-01-01 15:27:45
# 2      95821 2022-03-30  iPhone13,4  06302 1900-01-01 10:16:46
# 3      13361 2022-03-29   iPhone9,4  05059 1900-01-01 12:26:38
# 4      28241 2022-03-31  iPhone13,3  06334 1900-01-01 14:57:41
# ...      ...        ...         ...    ...                 ...
# 37401  26462 2022-03-22   Vivo 1920  11069 1900-01-01 14:03:12
# 37402  26462 2022-03-21   Vivo 1920  11069 1900-01-01 13:59:04
# 37403  26462 2022-03-22  iPhone13,4  11069 1900-01-01 13:41:47
# 37404  26462 2022-03-21  iPhone13,4  11069 1900-01-01 14:17:46
# 37405  26462 2022-03-21  Vivo V2050  11069 1900-01-01 10:54:49
#
#                                   urine  ov PartitionKey  hcode  \
# 0                       ปกติ (เหลืองใส)   4        00001  06307
# 1                       ปกติ (เหลืองใส)   4        00001  05328
# 2                       ปกติ (เหลืองใส)   3        00001  06302
# 3                       ปกติ (เหลืองใส)   3        00001  05059
# 4                       ปกติ (เหลืองใส)   0        00001  06334
# ...                                 ...  ..          ...    ...
# 37401                   ปกติ (เหลืองใส)   1        11003  11069
# 37402                   ปกติ (เหลืองใส)   2        11005  11069
# 37403                   ปกติ (เหลืองใส)   2        11006  11069
# 37404                   ปกติ (เหลืองใส)   0        11007  11069
# 37405  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1        11008  11069
#
#                                                     name   province   title  \
# 0      โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา  อุตรดิตถ์  นางสาว
# 1            โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์  กาฬสินธุ์     นาง
# 2                     โรงพยาบาลส่งเสริมสุขภาพตำบลสองห้อง  อุตรดิตถ์     นาง
# 3                  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านดอนดู่  มหาสารคาม     นาย
# 4                      โรงพยาบาลส่งเสริมสุขภาพตำบลน้ำพี้  อุตรดิตถ์  นางสาว
# ...                                                  ...        ...     ...
# 37401                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด  นางสาว
# 37402                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาย
# 37403                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาง
# 37404                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาง
# 37405                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาย
#
#       age        Day  Month  Year
# 0      47 2022-03-30      3  2022
# 1      41 2022-03-30      3  2022
# 2      55 2022-03-30      3  2022
# 3      66 2022-03-29      3  2022
# 4      50 2022-03-31      3  2022
# ...    ..        ...    ...   ...
# 37401  33 2022-03-22      3  2022
# 37402  28 2022-03-21      3  2022
# 37403  72 2022-03-22      3  2022
# 37404  48 2022-03-21      3  2022
# 37405  36 2022-03-21      3  2022
#
# [37406 rows x 16 columns]

# %%
# สำหรับแยกข้อมูลออกเป็น ชม นาที วินาที ในเเต่ละคอลัมน์
merged_use1 = pd.DataFrame(merged_use)
merged_use1['Second'] = pd.to_datetime(merged_use['time'], format = "%H:%M:%S")
merged_use1['Minute'] = merged_use['time'].dt.minute
merged_use1['Hour'] = merged_use['time'].dt.hour
merged_use1
# Out:
#         user       date       phone   site                time  \
# 0      12015 2022-03-30  iPhone12,3  06307 1900-01-01 14:46:08
# 1      91811 2022-03-30  iPhone14,3  05328 1900-01-01 15:27:45
# 2      95821 2022-03-30  iPhone13,4  06302 1900-01-01 10:16:46
# 3      13361 2022-03-29   iPhone9,4  05059 1900-01-01 12:26:38
# 4      28241 2022-03-31  iPhone13,3  06334 1900-01-01 14:57:41
# ...      ...        ...         ...    ...                 ...
# 37401  26462 2022-03-22   Vivo 1920  11069 1900-01-01 14:03:12
# 37402  26462 2022-03-21   Vivo 1920  11069 1900-01-01 13:59:04
# 37403  26462 2022-03-22  iPhone13,4  11069 1900-01-01 13:41:47
# 37404  26462 2022-03-21  iPhone13,4  11069 1900-01-01 14:17:46
# 37405  26462 2022-03-21  Vivo V2050  11069 1900-01-01 10:54:49
#
#                                   urine  ov PartitionKey  hcode  \
# 0                       ปกติ (เหลืองใส)   4        00001  06307
# 1                       ปกติ (เหลืองใส)   4        00001  05328
# 2                       ปกติ (เหลืองใส)   3        00001  06302
# 3                       ปกติ (เหลืองใส)   3        00001  05059
# 4                       ปกติ (เหลืองใส)   0        00001  06334
# ...                                 ...  ..          ...    ...
# 37401                   ปกติ (เหลืองใส)   1        11003  11069
# 37402                   ปกติ (เหลืองใส)   2        11005  11069
# 37403                   ปกติ (เหลืองใส)   2        11006  11069
# 37404                   ปกติ (เหลืองใส)   0        11007  11069
# 37405  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1        11008  11069
#
#                                                     name   province   title  \
# 0      โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา  อุตรดิตถ์  นางสาว
# 1            โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์  กาฬสินธุ์     นาง
# 2                     โรงพยาบาลส่งเสริมสุขภาพตำบลสองห้อง  อุตรดิตถ์     นาง
# 3                  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านดอนดู่  มหาสารคาม     นาย
# 4                      โรงพยาบาลส่งเสริมสุขภาพตำบลน้ำพี้  อุตรดิตถ์  นางสาว
# ...                                                  ...        ...     ...
# 37401                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด  นางสาว
# 37402                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาย
# 37403                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาง
# 37404                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาง
# 37405                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาย
#
#       age        Day  Month  Year              Second  Minute  Hour
# 0      47 2022-03-30      3  2022 1900-01-01 14:46:08      46    14
# 1      41 2022-03-30      3  2022 1900-01-01 15:27:45      27    15
# 2      55 2022-03-30      3  2022 1900-01-01 10:16:46      16    10
# 3      66 2022-03-29      3  2022 1900-01-01 12:26:38      26    12
# 4      50 2022-03-31      3  2022 1900-01-01 14:57:41      57    14
# ...    ..        ...    ...   ...                 ...     ...   ...
# 37401  33 2022-03-22      3  2022 1900-01-01 14:03:12       3    14
# 37402  28 2022-03-21      3  2022 1900-01-01 13:59:04      59    13
# 37403  72 2022-03-22      3  2022 1900-01-01 13:41:47      41    13
# 37404  48 2022-03-21      3  2022 1900-01-01 14:17:46      17    14
# 37405  36 2022-03-21      3  2022 1900-01-01 10:54:49      54    10
#
# [37406 rows x 19 columns]

# %% [markdown]
# ## เเก้ไขข้อมูลให้ถูกต้อง

# %%
merged_use['Month'].unique() # ไว้ใช้เรียกดูข้อมูล
# Out:
# array([3, 4, 2])

# %%
merged_use['title'].unique() # ไว้ใช้เรียกดูข้อมูล
# Out:
# array(['นางสาว', 'นาง', 'นาย', 'น.ส.', 'นส.', 'น.ส', 'นาย ', 'นส', 'ด.ญ.',
#        'นาง ', 'ร.ต.ต.', ' นาง', '  นาง', 'ว่าที่ ร.ต.', 'นางl',
#        'ว่าที่ร้อยตรี', 'นส. ', 'พจอ.', 'น.ส ', 'พระ', 'Mrs', 'นา่ง',
#        'นาย  ', 'น', 'ร.ต.', 'พระครุ', 'นาบ', 'นางสาว ', 'ชาย', 'ด.ต.',
#        'data is not completed', 'น่าย', 'เด็กชาย',
#        'นางสาว                   ', 'ว่าที่ ร.ท.', 'นาน', 'นาว',
#        ' นางสาว', 'ร.ต.ท.', 'นาง.', 'ด.ช.', 'เด็กหญิง', 'ืนาง', 'นาวสาว',
#        ' นาย', 'ส.อ.', 'พระปลัด', 'พลฯ', 'ร.ต.อ.'], dtype=object)

# %%
merged_use1['title'].replace({'นางสาว':'หญิง','นาง':'หญิง','นาย':'ชาย','น.ส.':'หญิง','นาย ':'ชาย','นส':'หญิง','ด.ญ.':'หญิง',
                                           'นาง ':'หญิง','ร.ต.ต.':'ไม่ปรากฏข้อมูล',' นาง':'หญิง',
                              '  นาง':'หญิง','ว่าที่ ร.ต.':'ไม่ปรากฏข้อมูล','นางl':'หญิง','ว่าที่ร้อยตรี':'ไม่ปรากฏข้อมูล',
                              'นส. ':'หญิง','พจอ.':'ไม่ปรากฏข้อมูล',
                              'น.ส ':'หญิง','พระ':'ชาย','Mrs':'หญิง','นา่ง':'หญิง',
                                           'นาย  ':'ชาย','น':'ไม่ปรากฏข้อมูล','ร.ต.':'ไม่ปรากฏข้อมูล','พระครุ':'ชาย','นาบ':'ชาย','นางสาว ':'หญิง','ชาย':'ชาย','ด.ต.':'ไม่ปรากฏข้อมูล',
                              'data is not completed':'ไม่ปรากฏข้อมูล','น่าย':'ชาย','เด็กชาย':'ชาย','นางสาว                   ':'หญิง','ว่าที่ ร.ท.':'ไม่ปรากฏข้อมูล','นาน':'ชาย','นาว':'หญิง',
                             ' นางสาว':'หญิง','ร.ต.ท.':'ไม่ปรากฏข้อมูล','นาง.':'หญิง','ด.ช.':'ชาย','เด็กหญิง':'หญิง', 'ืนาง':'หญิง','นาวสาว':'หญิง',
                               ' นาย':'ชาย','ส.อ.':'ไม่ปรากฏข้อมูล','พระปลัด':'ชาย','พลฯ':'ชาย','ร.ต.อ.':'ไม่ปรากฏข้อมูล','นส.':'หญิง','น.ส':'หญิง'}, inplace=True ) 
merged_use1['title'].unique() # ไว้ใช้เรียกดูข้อมูล
# Out:
# array(['หญิง', 'ชาย', 'ไม่ปรากฏข้อมูล'], dtype=object)

# %%
merged_use1 # แสดงผลลัพธ์
# Out:
#         user       date       phone   site                time  \
# 0      12015 2022-03-30  iPhone12,3  06307 1900-01-01 14:46:08
# 1      91811 2022-03-30  iPhone14,3  05328 1900-01-01 15:27:45
# 2      95821 2022-03-30  iPhone13,4  06302 1900-01-01 10:16:46
# 3      13361 2022-03-29   iPhone9,4  05059 1900-01-01 12:26:38
# 4      28241 2022-03-31  iPhone13,3  06334 1900-01-01 14:57:41
# ...      ...        ...         ...    ...                 ...
# 37401  26462 2022-03-22   Vivo 1920  11069 1900-01-01 14:03:12
# 37402  26462 2022-03-21   Vivo 1920  11069 1900-01-01 13:59:04
# 37403  26462 2022-03-22  iPhone13,4  11069 1900-01-01 13:41:47
# 37404  26462 2022-03-21  iPhone13,4  11069 1900-01-01 14:17:46
# 37405  26462 2022-03-21  Vivo V2050  11069 1900-01-01 10:54:49
#
#                                   urine  ov PartitionKey  hcode  \
# 0                       ปกติ (เหลืองใส)   4        00001  06307
# 1                       ปกติ (เหลืองใส)   4        00001  05328
# 2                       ปกติ (เหลืองใส)   3        00001  06302
# 3                       ปกติ (เหลืองใส)   3        00001  05059
# 4                       ปกติ (เหลืองใส)   0        00001  06334
# ...                                 ...  ..          ...    ...
# 37401                   ปกติ (เหลืองใส)   1        11003  11069
# 37402                   ปกติ (เหลืองใส)   2        11005  11069
# 37403                   ปกติ (เหลืองใส)   2        11006  11069
# 37404                   ปกติ (เหลืองใส)   0        11007  11069
# 37405  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1        11008  11069
#
#                                                     name   province title age  \
# 0      โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา  อุตรดิตถ์  หญิง  47
# 1            โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์  กาฬสินธุ์  หญิง  41
# 2                     โรงพยาบาลส่งเสริมสุขภาพตำบลสองห้อง  อุตรดิตถ์  หญิง  55
# 3                  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านดอนดู่  มหาสารคาม   ชาย  66
# 4                      โรงพยาบาลส่งเสริมสุขภาพตำบลน้ำพี้  อุตรดิตถ์  หญิง  50
# ...                                                  ...        ...   ...  ..
# 37401                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด  หญิง  33
# 37402                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด   ชาย  28
# 37403                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด  หญิง  72
# 37404                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด  หญิง  48
# 37405                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด   ชาย  36
#
#              Day  Month  Year              Second  Minute  Hour
# 0     2022-03-30      3  2022 1900-01-01 14:46:08      46    14
# 1     2022-03-30      3  2022 1900-01-01 15:27:45      27    15
# 2     2022-03-30      3  2022 1900-01-01 10:16:46      16    10
# 3     2022-03-29      3  2022 1900-01-01 12:26:38      26    12
# 4     2022-03-31      3  2022 1900-01-01 14:57:41      57    14
# ...          ...    ...   ...                 ...     ...   ...
# 37401 2022-03-22      3  2022 1900-01-01 14:03:12       3    14
# 37402 2022-03-21      3  2022 1900-01-01 13:59:04      59    13
# 37403 2022-03-22      3  2022 1900-01-01 13:41:47      41    13
# 37404 2022-03-21      3  2022 1900-01-01 14:17:46      17    14
# 37405 2022-03-21      3  2022 1900-01-01 10:54:49      54    10
#
# [37406 rows x 19 columns]

# %%
merged_use1.to_csv(os.path.join(path,'merged_use.csv')) # save เข้า drive เพื่อนำไปทำ dashboard

# %% [markdown]
# ลิงค์ Dashboard
#
# Link: https://datastudio.google.com/reporting/a76882b0-d2de-409a-a7b9-b9d4b4a6061a
